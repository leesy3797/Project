# %%
import pymupdf
from typing import Dict
import os

def load_document(file_path:str)->dict:
    if not os.path.exists(file_path):
        print(f'File Not Exists. Check the File!')
        raise ValueError
    file_name = file_path.split('\\')[-1].split('.')[0]
    # print(file_name)
    docs = pymupdf.open(file_path)
    document = []
    # print(docs.metadata)
    for page in docs:
        document.append(
            {
                "doc_content" : page.get_text(),
                "doc_id" : f"doc_{page.number + 1}",
                "doc_name" : file_name,
                "chunks" : []
            }
        )
    return document

def chunk_document(document, split_interval: int, overlap_ratio: float = 0.2) -> list[dict]:
    if not document:
        print("No document detected!!!")
        return
    
    for page in document:
        content = page['doc_content']
        
        # 'chunks' 필드가 없는 경우 초기화
        if 'chunks' not in page:
            page['chunks'] = []
        
        # 중첩 크기 계산
        overlap_size = int(split_interval * overlap_ratio)

        # 분할할 필요가 없을 때
        if split_interval >= len(content):
            chunk = content
            page['chunks'].append(
                {
                    'chunk_content': chunk,
                    'chunk_id': page['doc_id'] + '_chunk_1'
                }
            )
        else:
            i = 0
            start_idx = 0
            end_idx = split_interval
            
            while start_idx < len(content):
                chunk = content[start_idx:end_idx]
                page['chunks'].append(
                    {
                        'chunk_content': chunk,
                        'chunk_id': page['doc_id'] + f'_chunk_{i + 1}'
                    }
                )
                
                # 다음 청크의 시작 위치와 끝 위치를 중첩 크기를 반영하여 설정
                start_idx = end_idx - overlap_size
                end_idx = start_idx + split_interval
                
                i += 1

    return document

# %%
file_path = r'..\crawler\downloads\attachments\samilpwc_ai-business-use-cases.pdf'
document = load_document(file_path)
chunk_doc = chunk_document(document, split_interval=400)
# for doc in chunk_doc:
#     for chunk in doc['chunks']:
#         print('#'* 10)
#         print(f'{chunk}\n')

# %%
doc_count = 0
chunk_count = 0
for doc in chunk_doc:
    doc_count += 1
    for chunk in doc['chunks']:
        chunk_count += 1
print(f'Document 페이지 수 : {doc_count} // Chunk 수 : {chunk_count}')
# Out:
# Document 페이지 수 : 69 // Chunk 수 : 312

# %%
import os
import pickle
import json
import numpy as np
from google import generativeai as genai
from typing import List, Dict, Any
from tqdm import tqdm
import time
import google

class ContextualVectorDB:
    def __init__(self, name: str,  google_api_key=None):
        self.name = name
        self.embeddings = []
        self.metadata = []
        self.query_cache = {}
        self.db_path = f"./sample/{name}/contextual_vector_db.pkl"
        self.google_api_key = os.environ['GOOGLE_API_KEY']
        genai.configure(api_key=self.google_api_key)

    def situate_context(self, doc:str, chunk:str)->tuple[str, Any]:
        DOCUMENT_CONTEXT_PROMPT = """
        <document>
        {doc_content}
        </document>
        """

        CHUNK_CONTEXT_PROMPT = """
        Here is the chunk we want to situate within the whole document
        <chunk>
        {chunk_content}
        </chunk>

        Please give a short succint context to situate this chunk within the overall document for the purposes of improving search retrieval of the chunk.
        Answer only with the succint context in Korean(한국어) and nothing else.
        Remember the Answer should be in Korean(Hangul)
        """
        model_name = "gemini-1.5-flash"        
        model = genai.GenerativeModel(model_name)
        try:
            response = model.generate_content(
                f"""
                {DOCUMENT_CONTEXT_PROMPT.format(doc_content=doc)}\n
                {CHUNK_CONTEXT_PROMPT.format(chunk_content=chunk)}
                """
            )
            return response.text
        except google.api_core.exceptions.ResourceExhausted as re:
            time.sleep(60)
            try:
                response = model.generate_content(
                    f"""
                    {DOCUMENT_CONTEXT_PROMPT.format(doc_content=doc)}\n
                    {CHUNK_CONTEXT_PROMPT.format(chunk_content=chunk)}
                    """
                )
                return response.text
            except:
                return "No Contextual Information"
        except ValueError as ve:
            return 'No Contextual Information'
        
    def load_data(self, dataset: List[Dict[str, Any]], parallel_threads: int = 1):
        if self.embeddings and self.metadata:
            print("Vector database is already loaded. Skipping data loading.")
            return
        if os.path.exists(self.db_path):
            print("Loading vector database from disk.")
            self.load_db()
            return

        texts_to_embed = []
        metadata = []
        total_chunks = sum(len(doc['chunks']) for doc in dataset)
        
        def process_chunk(doc, chunk):
            contextual_text = self.situate_context(doc['doc_content'], chunk['chunk_content'])
            return {
                'texts_to_embed' : f"{chunk['chunk_content']} \n\n{contextual_text}",
                "metadata" : {
                    "doc_id" : doc['doc_id'],
                    "chunk_id" : chunk['chunk_id'],
                    "chunk_content" : chunk['chunk_content'],
                    "contextualized_content" : contextual_text
                }
            }
        
        futures = []
        with tqdm(total=total_chunks, desc="Generating Contextual") as pba:
            for doc in dataset:
                for chunk in doc['chunks']:
                    futures.append(process_chunk(doc, chunk))
                    pba.update(1)
        
        for future in tqdm(futures, total=total_chunks, desc = 'Processing Chunks'):
            texts_to_embed.append(future['texts_to_embed'])
            metadata.append(future['metadata'])

        self._embed_and_store(texts_to_embed, metadata)
        self.save_db()

    def _embed_and_store(self, texts: List[str], data: List[Dict[str, Any]]):
        batch_size = 10
        with tqdm(total = len(texts), desc = 'Embedding Contextual Chunks') as pbar:
            result = []
            for i in range(0, len(texts), batch_size):
                batch = texts[i:i+batch_size]
                batch_result = genai.embed_content(
                    model = 'models/text-embedding-004',
                    content = batch
                )
                result.extend(batch_result['embedding'])
                pbar.update(len(batch))
        self.embeddings = result
        self.metadata = data

    def search(self, query: str, k: int = 20) -> List[Dict[str, Any]]:
        if query in self.query_cache:
            query_embedding = self.query_cache[query]
        else:
            try:
                query_embedding = genai.embed_content(
                    model = 'models/text-embedding-004',
                    content = query
                )['embedding']
            except:
                time.sleep(60)
                print(f'Time Sleep for 1 minute (Query Embedding)')
                query_embedding = genai.embed_content(
                    model = 'models/text-embedding-004',
                    content = query
                )['embedding']
            self.query_cache[query] = query_embedding

        if not self.embeddings:
            raise ValueError("No data loaded in the vector database.")
        similarities = np.dot(self.embeddings, query_embedding)
        top_indices = np.argsort(similarities)[::-1][:k]
        
        top_results = []
        for idx in top_indices:
            result = {
                "metadata": self.metadata[idx],
                "similarity": float(similarities[idx]),
            }
            top_results.append(result)
        return top_results

    def save_db(self):
        data = {
            "embeddings": self.embeddings,
            "metadata": self.metadata,
            "query_cache": json.dumps(self.query_cache),
        }
        os.makedirs(os.path.dirname(self.db_path), exist_ok=True)
        with open(self.db_path, "wb") as file:
            pickle.dump(data, file)
        print("Successfully Save Contextual VectorDB")

    def load_db(self):
        if not os.path.exists(self.db_path):
            raise ValueError("Vector database file not found. Use load_data to create a new database.")
        with open(self.db_path, "rb") as file:
            data = pickle.load(file)
        self.embeddings = data["embeddings"]
        self.metadata = data["metadata"] 
        self.query_cache = json.loads(data["query_cache"])

# %%
contextual_db = ContextualVectorDB('test_2')
contextual_db.load_data(chunk_doc)
# Out:
# Loading vector database from disk.

# %%
# with open('./sample/test_1/contextual_vector_db.pkl', 'rb') as file:
#     data = pickle.load(file)

# %%
len(contextual_db.metadata)
# Out:
# 312

# %%
import os
import json
from typing import List, Dict, Any
from tqdm import tqdm
from elasticsearch import Elasticsearch
from elasticsearch.helpers import bulk

## Docker 네트워크 생성 (Optional) ##
# docker network create elastic

## Elasticsearch Docker 이미지 Pull ##
# docker pull docker.elastic.co/elasticsearch/elasticsearch:8.15.3

## Elasticsearch container 생성 및 시작 ##
# docker run -d --name elasticsearch -p 9200:9200 -p 9300:9300 -e "discovery.type=single-node" -e "xpack.security.enabled=false" elasticsearch:8.8.0

## Docker 재시작 ##
# docker container restart elasticsearch

class ElasticsearchBM25:
    def __init__(self, index_name: str = "contextual_bm25_index_pwc"):
        self.es_client = Elasticsearch("http://localhost:9200")
        self.index_name = index_name
        # self.delete_index()
        self.create_index()

    def create_index(self):
        index_settings = {
            "settings": {
                "analysis": {"analyzer": {"my_nori": {"type": "custom","tokenizer": "nori_tokenizer","decompound_mode": "mixed"}}},
                "similarity": {"default": {"type": "BM25"}},
                "index.queries.cache.enabled": False  # Disable query cache
            },
            "mappings": {
                "properties": {
                    "chunk_content": {"type": "text", "analyzer": "my_nori"},
                    "contextualized_content": {"type": "text", "analyzer": "my_nori"},
                    "doc_id": {"type": "keyword", "index": False},
                    "chunk_id": {"type": "keyword", "index": False}
                }
            },
        }
        if not self.es_client.indices.exists(index=self.index_name):
            self.es_client.indices.create(index=self.index_name, body=index_settings)
            print(f"Created index: {self.index_name}")

    def delete_index(self):    
        if self.es_client.indices.exists(index=self.index_name):
            self.es_client.indices.delete(index=self.index_name)
            print(f"Deleted Elasticsearch index: {self.index_name}")

    def index_documents(self, documents: List[Dict[str, Any]]):
        actions = [
            {
                "_index": self.index_name,
                "_source": {
                    "chunk_content": doc["chunk_content"],
                    "contextualized_content": doc["contextualized_content"],
                    "doc_id": doc["doc_id"],
                    "chunk_id": doc["chunk_id"],
                },
            }
            for doc in documents
        ]
        success, _ = bulk(self.es_client, actions)
        self.es_client.indices.refresh(index=self.index_name)
        return success

    def search(self, query: str, k: int = 20) -> List[Dict[str, Any]]:
        self.es_client.indices.refresh(index=self.index_name)  # Force refresh before each search
        search_body = {
            "query": {
                "multi_match": {
                    "query": query,
                    "fields": ["chunk_content", "contextualized_content"],
                }
            },
            "size": k,
        }
        response = self.es_client.search(index=self.index_name, body=search_body)
        return [
            {
                "doc_id": hit["_source"]["doc_id"],
                "chunk_id": hit["_source"]["chunk_id"],
                "chunk_content": hit["_source"]["chunk_content"],
                "contextualized_content": hit["_source"]["contextualized_content"],
                "score": hit["_score"],
            }
            for hit in response["hits"]["hits"]
        ]
    
def create_elasticsearch_bm25_index(db: ContextualVectorDB):
    es_bm25 = ElasticsearchBM25()
    es_bm25.index_documents(db.metadata)
    return es_bm25

def retrieve_advanced(query: str, db: ContextualVectorDB, es_bm25: ElasticsearchBM25, k: int, semantic_weight: float = 0.8, bm25_weight: float = 0.2):
    num_chunks_to_recall = 150

    semantic_results = db.search(query, k=num_chunks_to_recall)
    ranked_chunk_ids = [result['metadata']['chunk_id'] for result in semantic_results]

    bm25_results = es_bm25.search(query, k=num_chunks_to_recall)
    ranked_bm25_chunk_ids = [result['chunk_id'] for result in bm25_results]

    chunk_ids = list(set(ranked_chunk_ids + ranked_bm25_chunk_ids))
    
    chunk_id_to_score = {}
    
    for chunk_id in chunk_ids:
        score = 0
        if chunk_id in ranked_chunk_ids:
            index = ranked_chunk_ids.index(chunk_id)
            score += semantic_weight * (1 / (index + 1))  # Weighted 1/n scoring for semantic
        if chunk_id in ranked_bm25_chunk_ids:
            index = ranked_bm25_chunk_ids.index(chunk_id)
            score += bm25_weight * (1 / (index + 1))  # Weighted 1/n scoring for BM25
        chunk_id_to_score[chunk_id] = score

    # Sort chunk IDs by their scores in descending order
    sorted_chunk_ids = sorted(
        chunk_id_to_score.keys(), key=lambda x: (chunk_id_to_score[x], x[0], x[1]), reverse=True
    )

    # Assign new scores based on the sorted order
    for index, chunk_id in enumerate(sorted_chunk_ids):
        chunk_id_to_score[chunk_id] = 1 / (index + 1)

    # Prepare the final results
    final_results = []
    
    for chunk_id in sorted_chunk_ids[:k]:
        chunk_metadata = [chunk for chunk in db.metadata if chunk['chunk_id'] == chunk_id]
        is_from_semantic = chunk_id in ranked_chunk_ids
        is_from_bm25 = chunk_id in ranked_bm25_chunk_ids
        final_results.append({
            'chunk': chunk_metadata,
            'score': chunk_id_to_score[chunk_id],
            'from_semantic': is_from_semantic,
            'from_bm25': is_from_bm25
        })

    return final_results

# %%
es_bm25 = create_elasticsearch_bm25_index(contextual_db)

# %%
es = Elasticsearch("http://localhost:9200")
es.indices.refresh(index=es_bm25.index_name)
elasticsearch_results = es.search(
    index= es_bm25.index_name,
    
    body={
        "query": {
            "multi_match":
                    {
                        "query": "금융권에서 생성형AI가 활용되는 사례에 대해서 설명해줘",
                        "fields": ["chunk_content", "contextualized_content"]
                    }
                    },
        "size" : 5
        }
        )
elastic_rag = []

for id, result in enumerate(elasticsearch_results.body['hits']['hits']):
    print('#' * 25 + f' {id+1}번째 청크 ' + '#' * 25)
    print(f'{result['_source']['chunk_content']}')
    elastic_rag.append(result['_source']['chunk_content'])
# Out:
# ######################### 1번째 청크 #########################
# 계와 가치사슬을 집중 조명하였으며, 10개 산업별로
# 구체적인 비즈니스 활용 사례들을 정리하는 데 중점을 두었다. 특히, 금융분야의 JP 모건 사례,
# 헬스케어의 Roche 사례, 화학 분야의 BASF 사례, 물류산업의 DHL 사례는 눈여겨 볼 만 하다.
# 생성형 AI 도입이 초기 단계인 만큼, 사례가 제한적인 점, 그리고 적용사례의 성공여부가 아직
# 판명되지 않은 점 등 제약적인 상황이지만 기업들이 어떻게 대응하고 있는지를 소개함으로써 AI의
# 도입을 검토하고 있는 후발주자들에게 길라잡이가 되었으면 한다. 동시에 ‘game changer’로서의
# 생성형 AI로 인해 기업들의 비즈니스 모델이 향후 얼마나 변해 있을지에 대해 이 보고서를 통해서 각자
# 상상을 펼쳐볼 수 있으면 좋겠다.
# 들어가며
#
# ######################### 2번째 청크 #########################
# 계와 가치사슬을 집중 조명하였으며, 10개 산업별로
# 구체적인 비즈니스 활용 사례들을 정리하는 데 중점을 두었다. 특히, 금융분야의 JP 모건 사례,
# 헬스케어의 Roche 사례, 화학 분야의 BASF 사례, 물류산업의 DHL 사례는 눈여겨 볼 만 하다.
# 생성형 AI 도입이 초기 단계인 만큼, 사례가 제한적인 점, 그리고 적용사례의 성공여부가 아직
# 판명되지 않은 점 등 제약적인 상황이지만 기업들이 어떻게 대응하고 있는지를 소개함으로써 AI의
# 도입을 검토하고 있는 후발주자들에게 길라잡이가 되었으면 한다. 동시에 ‘game changer’로서의
# 생성형 AI로 인해 기업들의 비즈니스 모델이 향후 얼마나 변해 있을지에 대해 이 보고서를 통해서 각자
# 상상을 펼쳐볼 수 있으면 좋겠다.
# 들어가며
#
# ######################### 3번째 청크 #########################
# 계와 가치사슬을 집중 조명하였으며, 10개 산업별로
# 구체적인 비즈니스 활용 사례들을 정리하는 데 중점을 두었다. 특히, 금융분야의 JP 모건 사례,
# 헬스케어의 Roche 사례, 화학 분야의 BASF 사례, 물류산업의 DHL 사례는 눈여겨 볼 만 하다.
# 생성형 AI 도입이 초기 단계인 만큼, 사례가 제한적인 점, 그리고 적용사례의 성공여부가 아직
# 판명되지 않은 점 등 제약적인 상황이지만 기업들이 어떻게 대응하고 있는지를 소개함으로써 AI의
# 도입을 검토하고 있는 후발주자들에게 길라잡이가 되었으면 한다. 동시에 ‘game changer’로서의
# 생성형 AI로 인해 기업들의 비즈니스 모델이 향후 얼마나 변해 있을지에 대해 이 보고서를 통해서 각자
# 상상을 펼쳐볼 수 있으면 좋겠다.
# 들어가며
#
# ######################### 4번째 청크 #########################
# 42%의 여행자들이 AI가 생성해준 여행 일정을 선호한다고 조사되었다.
# 현재 AI는 ① 빅데이터 분석 기반의 여행지, 항공 및 호텔 예약과, ② 실시간 정보 탐색을 통한 맞춤 여행
# 일정(타임라인) 제안, 그리고 ③ 여행 경험을 실시간으로 지원(정보 업데이트, 번역 등)하는 챗봇 기능
# 중심으로 집중 활용되고 있다.
# [관광 산업 밸류체인 -AI 적용 예시]
# ※ 한국문화관광연구원, 삼일PwC경영연구원
# 정보탐색/준비
# 예약
# 교통수단
# 숙박
# • 여행자 과거 데이터
# 수집 및 분석
# • 예약 일정 개인화
# • 호텔 및 항공료 예측
# 분석, 가격 최적화
# • 여행 상품 탐색
# • 실시간 날씨, 로컬
# 행사 등 데이터 분석
# • 맞춤 여행 설계
# • 렌터카 서비스 자동화
# • 택시/차량 호출
# • 맞춤 교통 루트 제공
# • 언어 번역
# ######################### 5번째 청크 #########################
# 42%의 여행자들이 AI가 생성해준 여행 일정을 선호한다고 조사되었다.
# 현재 AI는 ① 빅데이터 분석 기반의 여행지, 항공 및 호텔 예약과, ② 실시간 정보 탐색을 통한 맞춤 여행
# 일정(타임라인) 제안, 그리고 ③ 여행 경험을 실시간으로 지원(정보 업데이트, 번역 등)하는 챗봇 기능
# 중심으로 집중 활용되고 있다.
# [관광 산업 밸류체인 -AI 적용 예시]
# ※ 한국문화관광연구원, 삼일PwC경영연구원
# 정보탐색/준비
# 예약
# 교통수단
# 숙박
# • 여행자 과거 데이터
# 수집 및 분석
# • 예약 일정 개인화
# • 호텔 및 항공료 예측
# 분석, 가격 최적화
# • 여행 상품 탐색
# • 실시간 날씨, 로컬
# 행사 등 데이터 분석
# • 맞춤 여행 설계
# • 렌터카 서비스 자동화
# • 택시/차량 호출
# • 맞춤 교통 루트 제공
# • 언어 번역

# %%
# contextual_db = ContextualVectorDB('test_1')
# contextual_db.load_data(document)
contextual_results = contextual_db.search("금융권에서 생성형AI가 활용되는 사례에 대해서 설명해줘", k=5)
contextual_rag = []

for id, result in enumerate(contextual_results):
    print('#' * 25 + f' {id+1}번째 청크 ' + '#' * 25)
    print(f'{result['metadata']['chunk_content']}')
    contextual_rag.append(result['metadata']['chunk_content'])
# Out:
# ######################### 1번째 청크 #########################
# 클라우드
# 컴퓨팅 하드웨어
#
# ######################### 2번째 청크 #########################
# 변수에 대응이 가능하고, 농가의 생산성과 에너지 효율을 극대화
#
# ######################### 3번째 청크 #########################
# 업들의 비즈니스 모델이 향후 얼마나 변해 있을지에 대해 이 보고서를 통해서 각자
# 상상을 펼쳐볼 수 있으면 좋겠다.
# 들어가며
#
# ######################### 4번째 청크 #########################
# 결함, 오염 또는 불규칙성을 감지하여 고품질의 제품만 출시
# •
# 풍미 및 레시피 최적화: 소비자 선호도와 트렌드를 분석하여 음식의 맛과 레시피를 최적화
# •
# 레스토랑의 메뉴 맞춤화: 고객의 선호도, 식단 제한, 과거 주문 데이터를 기반으로 메뉴를 개인화, 식사 경험
# 및 고객 만족도 개선
#
# ######################### 5번째 청크 #########################
# 반 조기 진단, 환자
# 경험 개선
# 이용료
# AI
# 솔루션/
# 플랫폼
# 바이오테크 기업
# AI/클라우드 플랫폼
# 신약
# 개발
# 고객 세그먼트
# 의료 기관
# (병원, 진료소, 약국)
# 실험실
# (병원, 진료소)
# 의약품,
# 진단기기 판매
# 제품 구매
# 의료 데이터 제공

# %%
model = genai.GenerativeModel(
    model_name='gemini-1.5-flash-latest'
)
query_embedding = genai.embed_content(
    model = 'models/text-embedding-004',
    content = "금융권에서 생성형AI가 활용되는 사례에 대해서 설명해줘"
)['embedding']

# %%
sim = np.dot(contextual_db.embeddings, query_embedding)
for sim_id in sim.argsort()[::-1][:10]:
    print(f'[{sim[sim_id]:.4f}] {contextual_db.metadata[sim_id]['chunk_content']}')
    print("#" * 20)
# Out:
# [0.9558] 클라우드
# 컴퓨팅 하드웨어
#
# ####################
# [0.9165] 변수에 대응이 가능하고, 농가의 생산성과 에너지 효율을 극대화
#
# ####################
# [0.9066] 업들의 비즈니스 모델이 향후 얼마나 변해 있을지에 대해 이 보고서를 통해서 각자
# 상상을 펼쳐볼 수 있으면 좋겠다.
# 들어가며
#
# ####################
# [0.8843] 결함, 오염 또는 불규칙성을 감지하여 고품질의 제품만 출시
# •
# 풍미 및 레시피 최적화: 소비자 선호도와 트렌드를 분석하여 음식의 맛과 레시피를 최적화
# •
# 레스토랑의 메뉴 맞춤화: 고객의 선호도, 식단 제한, 과거 주문 데이터를 기반으로 메뉴를 개인화, 식사 경험
# 및 고객 만족도 개선
#
# ####################
# [0.8769] 반 조기 진단, 환자
# 경험 개선
# 이용료
# AI
# 솔루션/
# 플랫폼
# 바이오테크 기업
# AI/클라우드 플랫폼
# 신약
# 개발
# 고객 세그먼트
# 의료 기관
# (병원, 진료소, 약국)
# 실험실
# (병원, 진료소)
# 의약품,
# 진단기기 판매
# 제품 구매
# 의료 데이터 제공
#
# ####################
# [0.8761] 률
# 효율화
# 고객 경험
# •
# 행정 업무 및 서류 검토 자동화 중심으로 활용 증
# •
# 각종 문서 작성 및 고객 응대 서비스를 위해 AI 활용 검토 단계
# *각 산업별 ’AI 도입 및 활용 수준’은 타 산업 대비 상대적 비교 기준
# 신약개발
# 기타 의료
# 산업 전반
# AI 활용 수준 下
# 자동화/챗봇
# 맞춤 서비스
# 전체 평균 AI 도입 수준
#
# ####################
# [0.8730]  건강하게 생산할 수 있도록 지원
# •
# 토양 건강 모니터링: 화학적 토양 분석을 수행하고 누락된 영양소를 정확하게 추정
# •
# 농작물 보호: 식물의 상태를 모니터링하여 질병을 발견 및 예측, 잡초를 식별 및 제거
# •
# 지능형 살포: 잡초나 해충 방제를 자동화. 농작물의 이력, 토양 상태 또는 작물 유형에 대한 데이터 분석을
# 기반으로 각 밭에 필요한 농약의 양을 계산
# •
# 챗봇: 농부와 고객 또는 유통업체 간의 소통 지원(제품에 대한 질문, 주문, 재고 확인 등)
#
# ####################
# [0.8510] 격, 고객 수요를 분석해 최적의 가격 전략 수립
# •
# 재고 관리 및 수요 예측: 수요 패턴, 계절적 변동, 트렌드를 예측하여 재고 수준 최적화 지원
# •
# 고객 서비스용 챗봇: 고객 문의를 처리, 즉각적인 지원을 제공, 주문 추적을 지원
# •
# 시각적 검색 및 이미지 인식: AI 기반 시각적 검색 기술을 활용하여 고객이 텍스트가 아닌 이미지를
# 사용하여 제품을 검색(자동 제품 태그 지정, 카탈로그 관리 간소화, 검색 정확도 향상 등 기능에 활용)
# 푸드테크
# •
# 공급망 최적화: 수요를 예측하고 재고를 관리하며 물류를 개선하여 식품 공급망을 최적화
# •
# 품질 관리 및 검사: 식품의 결함, 오염 또는 불규칙성을 감지하여 고품질의 제품만 출시
# •
# 풍미 및 레시피 최적화: 소비자 선호도와 트렌드를 분석하여 음식의 맛과 레시피를
# ####################
# [0.8475] 
# 헬스케어 산업의 경우 안전성과 더불어 의료 데이터 활용 및 권한을 둘러싼 규제적 제한으로 인해 AI
# 기반 혁신이 더딘 상황이며, 제조 산업 역시 인력의 전문성에 의존하는 업계 특성상 데이터화가
# 상당히 어려운 편으로이에대한 방안이 절실
# 
# 콘텐츠 창작을 기반으로 하는 미디어/광고 산업은 이미 비용 절감 효과를 보고 있는 한편, 생성형 AI
# 적용에 따른 경쟁이 심화되어 차별화된 콘텐츠 생성 전략이 필요할 것
# 기업
# 너도나도 생성형 AI 도입 중, 더 이상 AI 도입만으로는 비즈니스 차별화를 실현하기 어려움
# 
# 오픈소스 커뮤니티, 구독 서비스, 거래 기반 서비스 등 기업들은 AI 기술에 접근할 수 있는 방법에 대해
# 그 어느 때보다 더 많은 선택권을 갖게 되었음. 수많은 AI 기술 중에서도 모방이 어렵거
# ####################
# [0.8471]
#
# ####################

# %%
retrieve_results = retrieve_advanced(
    query = "금융권에서 생성형AI가 활용되는 사례에 대해서 설명해줘",
    db = contextual_db, 
    es_bm25=es_bm25,
    k = 5,
    semantic_weight=0.5,
    bm25_weight=0.5)

hybrid_rag = []
for id, result in enumerate(retrieve_results):
    print('#' * 25 + f' {id+1}번째 청크 ' + '#' * 25)
    print(f'{result['chunk'][0]['chunk_content']}')
    hybrid_rag.append(result['chunk'][0]['chunk_content'])
# Out:
# ######################### 1번째 청크 #########################
# 계와 가치사슬을 집중 조명하였으며, 10개 산업별로
# 구체적인 비즈니스 활용 사례들을 정리하는 데 중점을 두었다. 특히, 금융분야의 JP 모건 사례,
# 헬스케어의 Roche 사례, 화학 분야의 BASF 사례, 물류산업의 DHL 사례는 눈여겨 볼 만 하다.
# 생성형 AI 도입이 초기 단계인 만큼, 사례가 제한적인 점, 그리고 적용사례의 성공여부가 아직
# 판명되지 않은 점 등 제약적인 상황이지만 기업들이 어떻게 대응하고 있는지를 소개함으로써 AI의
# 도입을 검토하고 있는 후발주자들에게 길라잡이가 되었으면 한다. 동시에 ‘game changer’로서의
# 생성형 AI로 인해 기업들의 비즈니스 모델이 향후 얼마나 변해 있을지에 대해 이 보고서를 통해서 각자
# 상상을 펼쳐볼 수 있으면 좋겠다.
# 들어가며
#
# ######################### 2번째 청크 #########################
# 클라우드
# 컴퓨팅 하드웨어
#
# ######################### 3번째 청크 #########################
# 변수에 대응이 가능하고, 농가의 생산성과 에너지 효율을 극대화
#
# ######################### 4번째 청크 #########################
# 업들의 비즈니스 모델이 향후 얼마나 변해 있을지에 대해 이 보고서를 통해서 각자
# 상상을 펼쳐볼 수 있으면 좋겠다.
# 들어가며
#
# ######################### 5번째 청크 #########################
# 42%의 여행자들이 AI가 생성해준 여행 일정을 선호한다고 조사되었다.
# 현재 AI는 ① 빅데이터 분석 기반의 여행지, 항공 및 호텔 예약과, ② 실시간 정보 탐색을 통한 맞춤 여행
# 일정(타임라인) 제안, 그리고 ③ 여행 경험을 실시간으로 지원(정보 업데이트, 번역 등)하는 챗봇 기능
# 중심으로 집중 활용되고 있다.
# [관광 산업 밸류체인 -AI 적용 예시]
# ※ 한국문화관광연구원, 삼일PwC경영연구원
# 정보탐색/준비
# 예약
# 교통수단
# 숙박
# • 여행자 과거 데이터
# 수집 및 분석
# • 예약 일정 개인화
# • 호텔 및 항공료 예측
# 분석, 가격 최적화
# • 여행 상품 탐색
# • 실시간 날씨, 로컬
# 행사 등 데이터 분석
# • 맞춤 여행 설계
# • 렌터카 서비스 자동화
# • 택시/차량 호출
# • 맞춤 교통 루트 제공
# • 언어 번역

# %%
def compare_rag_performance(query):
    contextual_results = contextual_db.search(query, k=5)
    contextual_rag = []
    for id, result in enumerate(contextual_results):
        # print('#' * 25 + f'{id+1}번째 청크' + '#' * 25)
        # print(f'{result['metadata']['chunk_content']}')
        contextual_rag.append(result['metadata']['chunk_content'])

    es = Elasticsearch("http://localhost:9200")
    es.indices.refresh(index=es_bm25.index_name)
    elasticsearch_results = es.search(
        index= es_bm25.index_name,
        body={"query": {"multi_match":
                        {"query": query,
                        "fields": ["chunk_content", "contextualized_content"]}
                        }})
    elastic_rag = []

    for id, result in enumerate(elasticsearch_results.body['hits']['hits']):
        # print('#' * 25 + f'{id+1}번째 청크' + '#' * 25)
        # print(f'{result['_source']['chunk_content']}')
        elastic_rag.append(result['_source']['chunk_content'])

    retrieve_results = retrieve_advanced(
        query = query,
        db = contextual_db, 
        es_bm25=es_bm25,
        k = 5,
        semantic_weight=0.5,
        bm25_weight=0.5)

    hybrid_rag = []
    for id, result in enumerate(retrieve_results):
        # print('#' * 25 + f'{id+1}번째 청크' + '#' * 25)
        # print(f'{result['chunk'][0]['chunk_content']}')
        hybrid_rag.append(result['chunk'][0]['chunk_content'])

    contextual_rag_context = "\n\n".join(contextual_rag)
    elastric_rag_context = "\n\n".join(elastic_rag)
    hybrid_rag_context = "\n\n".join(hybrid_rag)

    check_rag_list = [contextual_rag_context, elastric_rag_context, hybrid_rag_context]
    rag_list = ["Contextual Retrieval", "ElasticSearch Retrieval", "Hybrid Retrieval"]

    for rag, context in zip(rag_list, check_rag_list):
        prompt = f""" 
        Using only the CONTEXT below, provide an accurate answer to the QUESTION in Korean (Hangul).

        Only use information provided in the CONTEXT for your answer.
        Do not reference or incorporate any external information.
        If the answer cannot be determined based on the CONTEXT, respond with "답변이 어렵습니다."
        CONTEXT: {context}

        QUESTION: {query}

        ANSWER:
        """
        client = genai.GenerativeModel(
            model_name='gemini-1.5-flash-latest'
        )
        response = client.generate_content(contents=prompt).text
        print("#" * 40)
        print(f"{rag}를 통한 RAG 결과")
        print("-" * 40)
        print(f"답변 : {response}\n")

# %%
compare_rag_performance("금융권에서 생성형AI가 활용되는 사례에 대해서 설명해줘")
# Out:
# ########################################
# Contextual Retrieval를 통한 RAG 결과
# ----------------------------------------
# 답변 : 답변이 어렵습니다.
#
#
# ########################################
# ElasticSearch Retrieval를 통한 RAG 결과
# ----------------------------------------
# 답변 : 답변이 어렵습니다.
#
#
# ########################################
# Hybrid Retrieval를 통한 RAG 결과
# ----------------------------------------
# 답변 : 답변이 어렵습니다.

# %%
contextual_db.metadata
# Out:
# [{'doc_id': 'doc_1',
#   'chunk_id': 'doc_1_chunk_1',
#   'chunk_content': 'Samil PwC  l  Samil Insight\n0\n',
#   'contextualized_content': '삼일 PwC와 삼일 인사이트의 제목입니다. \n'},
#  {'doc_id': 'doc_2',
#   'chunk_id': 'doc_2_chunk_1',
#   'chunk_content': 'Samil PwC  l  Samil Insight\n1\n2022년 11월 OpenAI의 ChatGPT 출시 이후 엄청난 속도로 생성형 AI 산업이 전방위적으로 \n확장되고 있으며, 생성형 AI의 기능, 한계, 그에 대한 대책 등 다양한 분석이 이어지고 있다.\n다만, 총론적인 보고서들은 이미 많이 발표되고 있지만 산업별, 기업별로 AI가 구체적으로 어떻게 \n활용되고 있는지에 대한 적용 사례에 대한 보고는 아직 미진하다. 아마도 생성형 AI의 초기 단계이기 \n때문에 매일 다양한 시도가 나타났다 사라지고 있고 적용사례의 성공여부도 판가름하기 어려워 이를 \n체계적으로 정리하기가 만만치 않은 점이 한 이유일 수 있을 것이다. 하지만, 각 기업들은 AI를 도입할 \n것인가? 어느 정도 도입할 것인가? 어떤 방식으로 도입할 ',
#   'contextualized_content': '이 텍스트는 보고서의 서론 부분으로 생성형 AI 산업의 급속한 성장과 더불어 이 보고서의 목적과 필요성을 설명하고 있습니다. \n'},
#  {'doc_id': 'doc_2',
#   'chunk_id': 'doc_2_chunk_2',
#   'chunk_content': ' 만만치 않은 점이 한 이유일 수 있을 것이다. 하지만, 각 기업들은 AI를 도입할 \n것인가? 어느 정도 도입할 것인가? 어떤 방식으로 도입할 것인가? 등에 대한 의사결정을 할 수 밖에 \n없는 단계에 있으며 이러한 결정에 앞서 동종업계든 이종업계든 다른 기업들이 어떻게 이를 시도하고 \n적용하고 있는지를 아는 것은 매우 유익할 것이다.\n이러한 관점에서 이 보고서의 주요 목적은 ‘산업별로 AI를 어떻게 활용하여 비즈니스 성과를 내고 \n있는지’를 구체적인 국내외 사례들을 통해 알아보고자 하는 것이다. 이를 위하여 보고서는 AI의 \n공급자와 수요자를 중심으로 이루어지는 생태계와 가치사슬을 집중 조명하였으며, 10개 산업별로 \n구체적인 비즈니스 활용 사례들을 정리하는 데 중점을 두었다. 특히, 금융분야의 JP 모건 ',
#   'contextualized_content': '생성형 AI 도입 초기 단계에 다양한 시도가 이루어지고 있지만, 성공 여부 판단은 어렵다는 내용과 함께 이 보고서의 목적이 산업별 AI 활용 사례를 통해 기업의 의사결정에 도움을 주는 것이라는 설명입니다. \n'},
#  {'doc_id': 'doc_2',
#   'chunk_id': 'doc_2_chunk_3',
#   'chunk_content': '계와 가치사슬을 집중 조명하였으며, 10개 산업별로 \n구체적인 비즈니스 활용 사례들을 정리하는 데 중점을 두었다. 특히, 금융분야의 JP 모건 사례,\n헬스케어의 Roche 사례, 화학 분야의 BASF 사례, 물류산업의 DHL 사례는 눈여겨 볼 만 하다.\n생성형 AI 도입이 초기 단계인 만큼, 사례가 제한적인 점, 그리고 적용사례의 성공여부가 아직 \n판명되지 않은 점 등 제약적인 상황이지만 기업들이 어떻게 대응하고 있는지를 소개함으로써 AI의 \n도입을 검토하고 있는 후발주자들에게 길라잡이가 되었으면 한다. 동시에 ‘game changer’로서의 \n생성형 AI로 인해 기업들의 비즈니스 모델이 향후 얼마나 변해 있을지에 대해 이 보고서를 통해서 각자 \n상상을 펼쳐볼 수 있으면 좋겠다.\n들어가며\n',
#   'contextualized_content': '본 보고서는 생성형 AI가 산업별로 어떻게 활용되고 있는지 구체적인 국내외 사례를 통해 분석하고, 그를 통해 기업들이 AI를 도입하는 데 있어 도움을 주는 것을 목표로 합니다. \n'},
#  {'doc_id': 'doc_2',
#   'chunk_id': 'doc_2_chunk_4',
#   'chunk_content': '업들의 비즈니스 모델이 향후 얼마나 변해 있을지에 대해 이 보고서를 통해서 각자 \n상상을 펼쳐볼 수 있으면 좋겠다.\n들어가며\n',
#   'contextualized_content': '본 보고서는 생성형 AI가 산업별로 어떻게 활용되어 비즈니스 성과를 창출하는지 구체적인 국내외 사례를 통해 분석하며, 이를 통해 기업들이 생성형 AI 도입을 검토하는 데 도움을 주고자 한다. 특히, 보고서는 생성형 AI로 인해 기업의 비즈니스 모델이 앞으로 얼마나 변화할지에 대한 상상을 펼쳐볼 수 있도록 돕는다. \n'},
#  {'doc_id': 'doc_3',
#   'chunk_id': 'doc_3_chunk_1',
#   'chunk_content': 'Contents\nI\n생성형 AI 생태계 구조: 공급자 측면\n3\nII\n생성형 AI 시장 전망 및 도입 현황: 수요자 측면\n10\nIII\n산업별 비즈니스 AI 활용 현황\n10개 산업(금융, 헬스케어, 제조(자동차, 화학) 등)으로 본 AI 활용사례\n14\nIV\n결론: 시사점\n61\n',
#   'contextualized_content': '본 텍스트는 생성형 AI 관련 문서의 목차입니다. \n'},
#  {'doc_id': 'doc_4',
#   'chunk_id': 'doc_4_chunk_1',
#   'chunk_content': 'Samil PwC  l  Samil Insight\n3\nI.\n생성형 AI 생태계 구조:  \n공급자 측면\n',
#   'contextualized_content': '본 텍스트는 삼일PwC와 삼일인사이트에서 발행한 문서의 첫 번째 장(I)의 제목이며 생성형 AI 생태계의 구조를 설명하는 내용을 담고 있습니다.  특히 공급자 측면에 초점을 맞추어 다룹니다. \n'},
#  {'doc_id': 'doc_5',
#   'chunk_id': 'doc_5_chunk_1',
#   'chunk_content': 'Samil PwC  l  Samil Insight\n4\n[AI 산업의 생태계 : 공급자와 수요자]\n1. 생성형 AI 산업의 이해\nI. 생성형 AI 생태계 구조: 공급자 측면\n\uf06cAI 산업은 관련 기술을 개발하거나 AI를 활용한 제품 및 서비스를 생산·유통·활용하는 등의 과정에서 \n가치를 창출하는 산업을 일컫는다.   \n*후방산업:AI학습 및 활용을 위한 데이터 수집,구매,구축 컨설팅,분석 등과 연계된 생태계 \n*전방산업:AI를 활용하여 제품 및 서비스를 생산하고 제공하는 영역(본 보고서의 주요 포커스)\n\uf06c현재까지 AI 산업에 있어서 주력은 공급자(AI 기술 관련 기업) 시장이었으나향후에는 점차 수요자 \n(전방산업) 중심의 시장으로  변화될 것으로 예상된다.\n※ 통계청, 삼일PwC경영연구원\n공급자\n후방 산업\n기타',
#   'contextualized_content': '본 텍스트는 AI 산업의 생태계를 설명하는 보고서의 서론 부분입니다. 특히, 생성형 AI 산업의 생태계 구조 중 공급자 측면을 소개하고 있습니다. \n'},
#  {'doc_id': 'doc_5',
#   'chunk_id': 'doc_5_chunk_2',
#   'chunk_content': '시장이었으나향후에는 점차 수요자 \n(전방산업) 중심의 시장으로  변화될 것으로 예상된다.\n※ 통계청, 삼일PwC경영연구원\n공급자\n후방 산업\n기타 데이터 산업\n데이터 구축을 \n위한 컨설팅/ \n데이터 거래및 \n분석\n데이터 전처리\n자체 데이터\n가공\n데이터 가공\n아웃소싱\n전방 산업\n금융\n소비재\n공공\n통신\n제조\n유통\nAI 산업\n소프트웨어\n외부 플랫폼 도입/검증\nAI 모델 \n알고리즘 개발 \n및 검증\n클라우드 \n플랫폼 \n구축\nAI \n서\n비\n스  \n개\n발\n서비스\nAI 구축\n컨설팅\nSI 서비스\n컴퓨팅 하드웨어\nAI 연산장치 \n및 부품\n(AI 반도체)\n수요자\n수요 기업\n',
#   'contextualized_content': 'AI 산업은 공급자 중심에서 수요자 중심으로 변화될 것으로 예상되며, 그 변화와 함께 AI 산업 생태계의 구조를 설명하는 표를 보여줍니다. \n'},
#  {'doc_id': 'doc_6',
#   'chunk_id': 'doc_6_chunk_1',
#   'chunk_content': 'Samil PwC  l  Samil Insight\n5\n2. 생성형 AI 생태계 구조\nI. 생성형 AI 생태계 구조: 공급자 측면\n\uf06c생성형 AI 생태계의 기본 비즈니스 모델 구조는 크게 3가지 player(AI 모델/ AI 서비스 기업, 클라우드 기업,\nAI수요 기업)들간의 상호작용 기반으로 이루어진다.\n\uf0a7AI 모델/ AI 서비스기업: AI 모델을 자체 개발하여 클라우드 기업을 포함한 다양한 비즈니스 산업의 \n기업들을 대상으로 제품을 판매. 이들은 자사 제품을 오픈소스/ 거래 기반/ 구독 서비스 등 여러 형태로 \n제공 (Ex. OpenAI, Stability AI, Anthropic, 네이버등)\n\uf0a7클라우드 기업: AI 기술 기업과의 파트너십을 통해 고객 베이스를 갖춘 기존 플랫폼 제품에 기능을 \n전방위적으로 ',
#   'contextualized_content': '생성형 AI 생태계의 기본 비즈니스 모델 구조를 설명하는 부분입니다. 특히 AI 모델/ AI 서비스 기업, 클라우드 기업, AI 수요 기업 간의 상호작용을 중심으로 설명하고 있습니다. \n'},
#  {'doc_id': 'doc_6',
#   'chunk_id': 'doc_6_chunk_2',
#   'chunk_content': 'nthropic, 네이버등)\n\uf0a7클라우드 기업: AI 기술 기업과의 파트너십을 통해 고객 베이스를 갖춘 기존 플랫폼 제품에 기능을 \n전방위적으로 통합하고, 코파일럿* 기능 확대를 통해 고객 맞춤형 대규모언어모델(Large Language \nModel, LLM)** 플랫폼을 제공 (Ex. Microsoft, Google, Amazon 등)\n* 코파일럿(Copilot): 기존의 클라우드 서비스에 AI를 결합해 사용자가 올바로 사용할 수 있도록 돕는 서비스\n** 대규모언어모델 (LLM): 대규모의 언어 데이터를 학습해 인간의 언어를 이해하고 생성하는 AI 모델 유형\n\uf0a7AI 수요 기업: 어떤 AI 기술 기업이냐 보다 도입하는 AI 기술이 얼마나 기업 워크플로우에 원활히 \n적용되고 비즈니스 성과나 비용 감축에 기여할 ',
#   'contextualized_content': '생성형 AI 생태계 구조를 설명하는 문서에서, AI 생태계의 주요 참여자인 AI 모델/서비스 기업, 클라우드 기업, AI 수요 기업의 역할과 상호작용을 설명하는 부분입니다. \n'},
#  {'doc_id': 'doc_6',
#   'chunk_id': 'doc_6_chunk_3',
#   'chunk_content': '수요 기업: 어떤 AI 기술 기업이냐 보다 도입하는 AI 기술이 얼마나 기업 워크플로우에 원활히 \n적용되고 비즈니스 성과나 비용 감축에 기여할 수 있는지를 고려하여 제품을 선정하고 구매\n\uf06c이 3가지 Players는 각자 비용 감축 또는 매출 극대화라는 공통된 목적을 기반으로 차별화된 비즈니스 \n전략을 갖고 있다:  (AI 모델/ AI 서비스 기업)은높은 확장성 ∙ 정확성을 지닌 AI 모델 공급하고, (클라우드 \n기업)은높은 연결성 ∙ 맞춤성을 지닌 AI 플랫폼 마련하며, (AI 수요 기업)은높은 적용성 ∙ 생산성을 위한 AI \n도입 프로세스 확충하는 전략이다.\n비즈니스 모델 구조\n[AI 생태계 비즈니스 모델 관계]\n※ 삼일PwC경영연구원\nAI 모델/ AI 서비스기업\nAI 수요 기업\n클라우드 기업\n•\n다양한 ',
#   'contextualized_content': '생성형 AI 생태계의 공급자 측면에서 AI 모델/AI 서비스 기업, 클라우드 기업, AI 수요 기업의 역할과 비즈니스 전략을 설명하는 부분입니다. \n'},
#  {'doc_id': 'doc_6',
#   'chunk_id': 'doc_6_chunk_4',
#   'chunk_content': '스 모델 구조\n[AI 생태계 비즈니스 모델 관계]\n※ 삼일PwC경영연구원\nAI 모델/ AI 서비스기업\nAI 수요 기업\n클라우드 기업\n•\n다양한 비즈니스에 적용가능한 확장성 \n있는 AI 모델 구축\n•\n많은 사용자를 보유한 기업 제품과 협업\n하여 기술 확대 공급 (기업형 LLM 플랫폼)\n•\n도입하는 AI 기술의 비즈니스 성과 및 비용 \n감축 효과 초점\n•\n기존 사용 기업 플랫폼내 사용 가능 여부 \n고려\n•\n기존 제품에 AI 기능을 통합해 연결성 있는 \n업무 경험 제공\n•\n코파일럿 기능 확대로 과금 영역 확대 및 \n제품 경쟁력 강화\nEx) Microsoft, Google, Amazon\n직접 구매 및 활용\n기존 사용  \n비즈니스 플랫폼 및 \n워크프로세스에 적용\n생성형 AI 모델 탑재해 \n클라우드 서비스 \n기능 확대',
#   'contextualized_content': '본 텍스트는 생성형 AI 생태계 구조를 설명하는 문서의 일부로, AI 모델/ AI 서비스 기업, 클라우드 기업, AI 수요 기업 간의 상호작용을 비즈니스 모델 관점에서 보여주는 표와 설명입니다. \n'},
#  {'doc_id': 'doc_6',
#   'chunk_id': 'doc_6_chunk_5',
#   'chunk_content': ' Amazon\n직접 구매 및 활용\n기존 사용  \n비즈니스 플랫폼 및 \n워크프로세스에 적용\n생성형 AI 모델 탑재해 \n클라우드 서비스 \n기능 확대\nEx) OpenAI, Stability AI, Anthropic, 네이버\n비즈니스 전략\n',
#   'contextualized_content': '본 텍스트는 "클라우드 기업"의 비즈니스 전략을 설명하는 부분으로, "Amazon"을 예시로 들어 클라우드 서비스 기능 확대를 위한 생성형 AI 모델 탑재 전략을 보여줍니다. \n'},
#  {'doc_id': 'doc_7',
#   'chunk_id': 'doc_7_chunk_1',
#   'chunk_content': 'Samil PwC  l  Samil Insight\n6\n3. 생성형 AI 산업의 공급자 구성\nI. 생성형 AI 생태계 구조: 공급자 측면\n\uf06c사용자의 요구에 따라 아웃풋을 빠르게 ‘창조’해낼 수 있는 생성형 AI(Generative AI)는 기업의 업무 자동화 \n및 효율화를 극대화하며 새로운 게임 체인저로서 산업 지형에 혁신을 일으키는 중이다.\n\uf0a7기업 비즈니스를 성장시키고 시장 점유율을 확보하기 위해 다양한 글로벌 기업들이 앞다퉈 생성형 AI를\n직접 개발 또는 서비스에 적용 중이나, 생성형 AI 기술의 성숙도 측면에 있어서는 대부분 기업이 아직은 \n초기 단계이기 때문에생성형 AI 기술경쟁은 앞으로 더욱 치열해질 전망이다.\n※생성형 AI 및 ‘챗GPT’에 대한 상세 내용은 삼일PwC경영연구원의 보고서를 확인:\n‘',
#   'contextualized_content': '생성형 AI 산업의 공급자 구성에 대한 삼일 PwC의 보고서에서 생성형 AI가 산업에 미치는 영향과 기술 경쟁의 치열함을 언급하는 부분입니다. \n'},
#  {'doc_id': 'doc_7',
#   'chunk_id': 'doc_7_chunk_2',
#   'chunk_content': '성형 AI 기술경쟁은 앞으로 더욱 치열해질 전망이다.\n※생성형 AI 및 ‘챗GPT’에 대한 상세 내용은 삼일PwC경영연구원의 보고서를 확인:\n‘챗GPT, 기회인가 위협인가’ or  ‘2024년 주목해야 할 산업’\n\uf06c공급자 측면에서의 생성형 AI의비즈니스 생태계는 크게 ① 컴퓨팅 하드웨어(AI 반도체), ② 클라우드, ③ \nAI 모델, ④ AI 서비스(애플리케이션)의 4가지로 구분될 수 있으며, 기술력 및 자금력 등을 고려 시 신규 \n진출이 어려운 영역은 ①, ②>③ >④ 순이다.\n①컴퓨팅 하드웨어:AI서비스 구현에 필요한 대규모 연산을 초고속으로 처리하는 AI반도체 영역\n②클라우드:생성형 AI워크로드 실행, 컴퓨터 하드웨어로의 접근을 위한 포괄적 플랫폼 영역\n③AI모델:생성형 AI의 기반이자 서비스를 구동하',
#   'contextualized_content': '생성형 AI 산업의 공급자 구성에 대한 설명 중, 생성형 AI의 비즈니스 생태계를 4가지 영역(컴퓨팅 하드웨어, 클라우드, AI 모델, AI 서비스)으로 구분하고 각 영역에 대한 설명을 시작하는 부분입니다. \n'},
#  {'doc_id': 'doc_7',
#   'chunk_id': 'doc_7_chunk_3',
#   'chunk_content': '영역\n②클라우드:생성형 AI워크로드 실행, 컴퓨터 하드웨어로의 접근을 위한 포괄적 플랫폼 영역\n③AI모델:생성형 AI의 기반이자 서비스를 구동하게 하는 중심 모델 영역\n④AI 서비스: 자체보유AI 모델 없이 OpenAI의 GPT-4 같은 파운데이션 모델* 을 API로 호출해 사용\n* 파운데이션 모델(foundation model): 대규모 데이터셋을 사용하여 사전에 학습되어 있는 일종의 반 제품 형태(일종의 원재료); \n어플리케이션 기업들에게 AI 서비스 구축을 위한 API를 제공하는 비즈니스 모델 추구 \n\uf06cNVIDIA, Google, OpenAI 등 빅테크들은 압도적인 컴퓨팅 파워와 대규모 자본을 토대로 생성형 AI\n인프라(컴퓨팅 하드웨어, 클라우드)와 AI 모델 선점을 위해 역량을 쌓는 중이며, 스타트업',
#   'contextualized_content': '본 텍스트는 생성형 AI 비즈니스 생태계를 공급자 관점에서 설명하는 부분으로, 클라우드, AI 모델, AI 서비스의 구조와 역할을 상세히 설명하고 있습니다. \n'},
#  {'doc_id': 'doc_7',
#   'chunk_id': 'doc_7_chunk_4',
#   'chunk_content': '적인 컴퓨팅 파워와 대규모 자본을 토대로 생성형 AI\n인프라(컴퓨팅 하드웨어, 클라우드)와 AI 모델 선점을 위해 역량을 쌓는 중이며, 스타트업들은 대체로 자체 \n개발 또는 타사 개발 AI 모델을 이용해 다양한 AI서비스를 출시하며 경쟁력을 확보하고자 한다.\n[공급자: 생성형 AI 비즈니스 생태계 구조]\n※ 언론종합, 삼성증권, 삼일PwC경영연구원\n스타트업 집중 영역\n대기업 집중 영역\nAI 서비스\nAI 모델\n클라우드\n컴퓨팅 하드웨어\nEnd-to-End \n애플리케이션\n자체 보유 모델 기반 \n애플리케이션 \n개발 및 운영\nex. ChatGPT, Midjourney등\n응용애플리케이션\n자체 보유 AI 모델 없이 OpenAI GPT-4 같은 파운데이션 모델을 API로 호출해 사용  \nex. Duolingo, Jaspe',
#   'contextualized_content': '생성형 AI 비즈니스 생태계 구조에서 대기업과 스타트업의 역할과 전략을 설명하는 부분입니다. \n'},
#  {'doc_id': 'doc_7',
#   'chunk_id': 'doc_7_chunk_5',
#   'chunk_content': '플리케이션\n자체 보유 AI 모델 없이 OpenAI GPT-4 같은 파운데이션 모델을 API로 호출해 사용  \nex. Duolingo, Jasper 등\n클로즈드 소스 기반 파운데이션 \n모델\nex. GPT-4, Gemini 등\n모델 플랫폼/허브\nex. Hugging Face 등\n오픈 소스 파운데이션 모델\nex. Alpaca, Pythia 등\n클라우드 플랫폼 ex. AWS, Azure, Google Cloud 등\nAI 반도체 ex. GPU, TPU 등\n인프라 공급(Model layer)\n공급자의 생성형 AI 생태계는 AI 반도체, 클라우드, AI 모델, AI 서비스로 구분\n',
#   'contextualized_content': '생성형 AI 비즈니스 생태계 구조에서 공급자 측면의 4가지 영역 (컴퓨팅 하드웨어, 클라우드, AI 모델, AI 서비스)에 대한 구체적인 예시와 설명을 제공하고 있다. \n'},
#  {'doc_id': 'doc_7',
#   'chunk_id': 'doc_7_chunk_6',
#   'chunk_content': '\n',
#   'contextualized_content': '생성형 AI 비즈니스 생태계 구조를 설명하는 부분에서 공급자 측면의 4가지 영역(컴퓨팅 하드웨어, 클라우드, AI 모델, AI 서비스)을 자세히 소개하고 있다. \n'},
#  {'doc_id': 'doc_8',
#   'chunk_id': 'doc_8_chunk_1',
#   'chunk_content': 'Samil PwC  l  Samil Insight\n7\n3. 생성형 AI 산업의 공급자 구성\nI. 생성형 AI 생태계 구조: 공급자 측면\n공급자의 생성형 AI 생태계는 AI 반도체, 클라우드, AI 모델, AI 서비스로 구분\n\uf06c공급자측면에서의 생성형 AI 생태계는 단기적으로 현존하는 big player(빅테크, 대기업)들이 대부분 \n시장을 선점할 것으로 보이나, AI 서비스 시장 중심으로 새로운 진입자(중소기업, 스타트업 등) 모두\n에게 상당한 가치 창출의 기회를 제공할 것으로 예상된다.\n\uf0a7AI 모델을 구축하는데 상당한 시간과 비용이 든 만큼, 기존 출시된 대규모언어모델(LLM)을 활용한 \n다양한 AI 서비스/애플리케이션들이 향후 더 많이 출시될 전망이며, 이로써 LLM모델을 개발한 기업 \n입장에서는 수익성이',
#   'contextualized_content': '생성형 AI 산업의 공급자 구성에 대한 설명 중, 공급자 측면에서의 생성형 AI 생태계 구조가 AI 반도체, 클라우드, AI 모델, AI 서비스로 구분된다는 내용을 설명하는 부분입니다. \n'},
#  {'doc_id': 'doc_8',
#   'chunk_id': 'doc_8_chunk_2',
#   'chunk_content': "델(LLM)을 활용한 \n다양한 AI 서비스/애플리케이션들이 향후 더 많이 출시될 전망이며, 이로써 LLM모델을 개발한 기업 \n입장에서는 수익성이 급격하게 증가할 가능성이 높다.\n\uf06c한편, 생성형 AI 시장 성장으로 인해클라우드 기업들이 AI 기술을 구독 방식으로 사용하는 ‘AIaaS\n(서비스형 AI)’ 모델 중심으로 AI 시장에 본격 참여하고 있고AI 기술 업체 수가 급격히 증가하는 등, 시장 \n선점을 위한 또는 뒤쳐지지 않기 위한 경쟁은 치열해질 전망이다.\n생태계 구분\n영역 구분\n주요 기업\n사업 내용\nAI 서비스\n스타트업 \n집중 영역\n•\nJasper\n•\nStability AI\n•\nGithub\n•\n광고 문구 생성 AI 플랫폼 '재스퍼AI’ 운영. 기업 가치 15억 \n달러(’23년 기준)\n•\n이미지 생성(Tex",
#   'contextualized_content': '생성형 AI 생태계에서 공급자 측면의 시장 구조와 주요 기업들을 설명하고, AI 서비스 시장의 성장과 경쟁 심화에 대한 전망을 다룬 부분입니다. \n'},
#  {'doc_id': 'doc_8',
#   'chunk_id': 'doc_8_chunk_3',
#   'chunk_content': "ty AI\n•\nGithub\n•\n광고 문구 생성 AI 플랫폼 '재스퍼AI’ 운영. 기업 가치 15억 \n달러(’23년 기준)\n•\n이미지 생성(Text-to-Image) AI 모델 ‘스테이블 디퓨전’ \n개발. 기업 가치 10억 달러(’23년 기준)\n•\n코드 완성 AI 도구 ‘코파일럿(Copilot)’ 출시\nAI 모델\n대기업/빅테크 \n집중 영역\n•\nOpenAI\n•\nAnthropic\n•\n네이버\n•\nAPI 기반 범용 AI 모델(GPT 시리즈, DALL-E, Codex)을 \n기업에 유료로 제공\n•\n자연어 기반 생성형 AI 모델(Claude, Claude Instant)을 \n유료로 제공\n•\n생성형 AI 모델 '하이퍼클로바X’ 개발 및 다양한 AI 서비스\n(클로바X, 큐:) 공개\n클라우드\n•\nMicrosoft\n•\nAmazo",
#   'contextualized_content': '생성형 AI 산업의 공급자 구성을 다루는 문서에서, AI 서비스, AI 모델, 클라우드 영역의 주요 기업과 사업 내용을 설명하는 부분입니다. \n'},
#  {'doc_id': 'doc_8',
#   'chunk_id': 'doc_8_chunk_4',
#   'chunk_content': " 제공\n•\n생성형 AI 모델 '하이퍼클로바X’ 개발 및 다양한 AI 서비스\n(클로바X, 큐:) 공개\n클라우드\n•\nMicrosoft\n•\nAmazon\n•\nGoogle\n•\nAzure 중심으로 챗GPT 기반 코파일럿 기술을 클라우드로 \n통합 제공\n•\nAWS 사용자가 AI 모델을 통해 소프트웨어 성능을 향상할 \n수 있는 클라우드 서비스 ‘베드록’ 출시\n•\n자사 클라우드 서비스를 활용해 소프트웨어 개발자들에게 \n자사 언어모델 'PaLM' 유료로 제공\n컴퓨팅 \n하드웨어\n•\nNVIDIA\n•\nAMD\n•\n삼성전자\n•\n신형 AI 반도체 ‘H200’ 공개 (GPT4를 훈련하는데 사용된 \nH100의 업그레이드 버전)\n•\n최첨단 AI 반도체 'MI300X’ 출시, ’23년 4분기부터 AI 전용 \n반도체 생산 증가\n•\nAI 산업용 차",
#   'contextualized_content': '생성형 AI 생태계를 구성하는 주요 공급자(빅테크, 대기업)들의 사업 내용을 구체적으로 소개하는 부분입니다. \n'},
#  {'doc_id': 'doc_8',
#   'chunk_id': 'doc_8_chunk_5',
#   'chunk_content': "H100의 업그레이드 버전)\n•\n최첨단 AI 반도체 'MI300X’ 출시, ’23년 4분기부터 AI 전용 \n반도체 생산 증가\n•\nAI 산업용 차세대 메모리 반도체 2종 공개\n(고대역폭메모리(HBM)-프로세싱인메모리(PIM)와 저전력 \n더블데이터레이트 (LPDDR)-PIM)\n[AI 비즈니스 현황 상세]\n",
#   'contextualized_content': "본 텍스트는 생성형 AI 산업의 공급자 생태계를 설명하는 문서의 '컴퓨팅 하드웨어' 영역에 속하며, NVIDIA, AMD, 삼성전자 등 주요 기업들의 AI 반도체 개발 및 출시 현황을 보여줍니다. \n"},
#  {'doc_id': 'doc_9',
#   'chunk_id': 'doc_9_chunk_1',
#   'chunk_content': 'Samil PwC  l  Samil Insight\n8\n4. 생성형 AI 공급 기업에 대한 투자 현황\nI. 생성형 AI 생태계 구조: 공급자 측면\nAI에 대한 투자 대부분은 모델에 집중\n\uf06c현재까지는 대부분의 AI에 대한 투자는 주로 대규모언어모델(LLM)을 구축하는AI 파운데이션 모델 \n스타트업에 집중되었다.전체 투자금액 중 60%가 넘는 약 170억 달러가 투입된 것으로 조사된다.\n\uf06c그렇다면 이러한 투자 추세는 지속될 것인가? 향후에는 그 추세가 좀 달라질 것으로 예상된다. 현재\n까지 고작 투자금액의 17%만 투입되었던 AI 서비스 시장으로의 투자집행이 증가할 것으로 보인다. 이는 AI \n생태계에서 일반 기업이 돈을 벌 수 있는 기회는 AI 서비스가 유일하기도 하고, 해당 영역의 성장은 이제 \n시작에 불과하',
#   'contextualized_content': '생성형 AI 생태계 구조: 공급자 측면에서, AI 투자 현황을 살펴보는 부분입니다. 현재 AI 투자의 대부분이 AI 파운데이션 모델에 집중되어 있으나, 향후 AI 서비스 시장으로 투자가 집중될 것으로 예상하는 내용입니다. \n'},
#  {'doc_id': 'doc_9',
#   'chunk_id': 'doc_9_chunk_2',
#   'chunk_content': ' 보인다. 이는 AI \n생태계에서 일반 기업이 돈을 벌 수 있는 기회는 AI 서비스가 유일하기도 하고, 해당 영역의 성장은 이제 \n시작에 불과하기 때문에 기회요인이 많다는 이유이다. 한편 컴퓨팅 하드웨어 (GPU, TPU 등) 및 클라우드 \n플랫폼 역시 지속 성장이 예상되는 것은 두말할 나위가 없다.\n[AI 투자 현황 –AI 모델에 60% 이상 집중 투자]\n생태계 구분\n주요 스타트업\n총 투자 금액\n투자비중\nAI 서비스\nCharacter.ai, Replit\n~ $5 bil.\n17%\nAI \n모델\nAI 파운데이션모델\nOpenAI, Anthropic\n~$17 bil.\n60%\nAI Ops*\nHugging Face, Weights & Biases\n~$1 bil.\n4%\n클라우드\nDatabricks, Lambda\n~$4 ',
#   'contextualized_content': '생성형 AI 분야 투자는 현재 AI 모델에 집중되어 있지만, 앞으로는 AI 서비스 시장으로 투자 흐름이 바뀔 것이라고 예상되는 내용입니다.  특히 AI 서비스는 일반 기업이 수익을 창출할 수 있는 유일한 분야이며, 성장 가능성이 높다고 설명합니다. \n'},
#  {'doc_id': 'doc_9',
#   'chunk_id': 'doc_9_chunk_3',
#   'chunk_content': '\nAI Ops*\nHugging Face, Weights & Biases\n~$1 bil.\n4%\n클라우드\nDatabricks, Lambda\n~$4 bil.\n13%\n컴퓨팅 하드웨어\nSambaNova Systems, Cerebras System\n~$2 bil.\n6%\n*AI Ops: 인공지능(AI)과 운영(Ops)을 결합한 용어로, IT 운영 관리 간소화 및 문제해결 자동화하는 데이터 관리 기술\n※ Coatue, 삼일PwC경영연구원\n\uf06c장기적 관점에서는 AI 발전 형태가 AI 모델에 한정되지 않고 인프라부터 최종 AI 서비스까지 전분야에 걸친 \n혁신을 기대해볼 수 있다. 다만 이를 위해서는 각 생태계의 역할과 밸류체인 내 상호작용에 대한 이해가  \n필요하다.\n[플랫폼/하드웨어 –AI 모델 –애플리케이션으로 이어지는 A',
#   'contextualized_content': '생성형 AI 공급 기업에 대한 투자 현황을 다루는 문서에서 AI 모델 외에 다른 분야의 투자 현황을 설명하는 부분입니다. 특히 AI Ops, 클라우드, 컴퓨팅 하드웨어 분야에 대한 투자 현황과 대표적인 스타트업을 언급합니다. \n'},
#  {'doc_id': 'doc_9',
#   'chunk_id': 'doc_9_chunk_4',
#   'chunk_content': '이를 위해서는 각 생태계의 역할과 밸류체인 내 상호작용에 대한 이해가  \n필요하다.\n[플랫폼/하드웨어 –AI 모델 –애플리케이션으로 이어지는 AI 생태계의 역학 관계]\n애플리케이션\n모델\n인프라\nEnd-to-End \n애플리케이션\n응용애플리케이션\n클로즈드 소스 기반 \n파운데이션 모델\n모델 플랫폼/허브\n오픈 소스 파운데이션 모델\n클라우드플랫폼\nAI 반도체\n사용자\n인프라 공급(Model layer)\n모델 학습 및 미세조정 등을 \n위한 컴퓨팅 리소스 제공\nAI 서비스 개발을 위한 \n파운데이션 모델 공급\nAI 개발을 위한 하드웨어 GPU, \nTPU 제공\nAI 서비스\nAI 모델\n클라우드\n컴퓨팅 하드웨어\n',
#   'contextualized_content': '본문은 생성형 AI 생태계의 구조와 투자 현황을 설명하는 내용이며, 특히 AI 모델뿐 아니라 인프라, 애플리케이션까지 포함하는 전체 생태계의 밸류체인에 대한 이해가 중요하다고 강조하고 있습니다. \n'},
#  {'doc_id': 'doc_9',
#   'chunk_id': 'doc_9_chunk_5',
#   'chunk_content': '클라우드\n컴퓨팅 하드웨어\n',
#   'contextualized_content': 'AI 생태계 내 하드웨어 및 인프라 부분을 설명하는 그림의 맨 아래에 위치하는 부분입니다. \n'},
#  {'doc_id': 'doc_10',
#   'chunk_id': 'doc_10_chunk_1',
#   'chunk_content': 'Samil PwC  l  Samil Insight\n9\n5. Open AI(AI모델)의 비즈니스 모델 사례\nI. 생성형 AI 생태계 구조: 공급자 측면\n\uf06cChatGPT 모델을 개발한 OpenAI의 경우 비영리 연구기관으로 출발하였으나, 현재는 영리법인으로 \n확장해 생성형 AI 모델을 상용화하는 비즈니스 모델을 구축해 수익화를 도모 중이다. 특히 OpenAI는 \nMicrosoft와 파트너십 체결로 그 기술력을 입증했으며자연어 처리, 이미지 생성, 음성인식 등 생성형 AI \nAPI를 고객사에 제공하여 데이터셋 학습과 이를 뒷받침하는 컴퓨팅 자원 기반으로 지속적으로 성능을 개선 \n시키는 등 파운데이션 모델로서의 지위가 더욱 견고해지고 있다.\n주요 서비스\nChatGPT(자연어 기반 대화형 AI), Codex(자연어 ',
#   'contextualized_content': 'OpenAI의 비즈니스 모델 사례를 소개하는 문서의 서론 부분입니다. OpenAI의 배경, 주요 서비스 및 수익 모델에 대한 내용을 다룹니다. \n'},
#  {'doc_id': 'doc_10',
#   'chunk_id': 'doc_10_chunk_2',
#   'chunk_content': '개선 \n시키는 등 파운데이션 모델로서의 지위가 더욱 견고해지고 있다.\n주요 서비스\nChatGPT(자연어 기반 대화형 AI), Codex(자연어 기반 프로그래밍 코드 생성 AI), \nDALL-E(자연어 기반 이미지 생성 AI), Whisper(자동 음성인식 AI)\n수익 모델\n① ChatGPT Plus 구독: 월 $22(부가세 포함)\n② AI 모델 API를 제공, 해당 모델을 사용한 만큼 비용 청구\n모델별 비용 예시: \n- DALL-E 2: 이미지 당 $0.02(1024*1024 해상도), $0.018(512*512), $0.016(256*256)\n- 언어모델(기본): 1백만 토큰 당 $0.40(Babbage 모델), $2.00(Davinci 모델)\n*토큰은 분석을 위한 단어 조각 단위로1천 토큰은 약 750단',
#   'contextualized_content': 'OpenAI의 비즈니스 모델 설명, OpenAI가 제공하는 주요 서비스, OpenAI 수익 모델에 대한 정보가 포함된 부분입니다. \n'},
#  {'doc_id': 'doc_10',
#   'chunk_id': 'doc_10_chunk_3',
#   'chunk_content': '1백만 토큰 당 $0.40(Babbage 모델), $2.00(Davinci 모델)\n*토큰은 분석을 위한 단어 조각 단위로1천 토큰은 약 750단어\n매출 성과\n’22년 $2,800만 → ’23년 $16억 → ’24년 $50억(추정)\n※ OpenAI, 언론종합, 삼일PwC경영연구원\n※ 로아인텔리전스, 삼일PwC경영연구원\nAI 기술의 기반이 되는 OpenAI와 같은 파운데이션 모델을 개발하려는 글로벌 빅테크 기업들이 많다. 그러나 미국 \n스탠퍼드대 인간중심인공지능연구소(HAI) 보고서에 따르면 아쉽게도 ’23년 한국기업 중에는 파운데이션 모델 \n개발에 성공한 기업이 한군데도 없다. 대만, 스위스, 스웨덴 등 한국보다 GDP 규모가 작은 국가들도 성공한 것에 \n비하면, 초라한 성적표이다. 물론 네이버의 하이퍼클로바',
#   'contextualized_content': 'OpenAI의 주요 수익 모델 중 하나인 AI 모델 API 제공에 대한 설명과 함께 1백만 토큰 당 비용을 예시로 제시하고 있습니다. 또한 OpenAI의 매출 성과를 언급하며 한국의 파운데이션 모델 개발 현황과 비교 분석하고 있습니다. \n'},
#  {'doc_id': 'doc_10',
#   'chunk_id': 'doc_10_chunk_4',
#   'chunk_content': '도 없다. 대만, 스위스, 스웨덴 등 한국보다 GDP 규모가 작은 국가들도 성공한 것에 \n비하면, 초라한 성적표이다. 물론 네이버의 하이퍼클로바x 등이 있다고 하나 그동안의 AI투자규모를 감안하면 \n여전히 한국은 기반기술에 대한 투자는 약한 실정이다.\nOpen AI\nAPI 기반 범용 AI 모델 제공\nChatGPT\n초거대 자연어 모델 기반 대화\nCodex\n자연어 기반 코딩 자동화\nDALL-E\n텍스트 기반 이미지 생성\nWhisper\n다국어 자동 음성인식\nMicrosoft Azure 클라우드\n호스팅 및 GPU 등 컴퓨팅 \n파워 리소스 제공\n검색 엔진 고도화 및 \n클라우드 서비스 확대\n개인\nAI 서비스\n기업\n질의응답 및 대화\n자연어 → 쿼리생성\n코드 → 자연어 해석\n개발 언어 간 번역\n코드 버그 수정\n이미지 생성\n',
#   'contextualized_content': '한국은 아직 파운데이션 모델 개발에 성공한 기업이 없으며, 기반기술에 대한 투자는 미흡한 실정이라는 내용을 설명하고 OpenAI의 서비스 및 비즈니스 모델을 소개합니다. \n'},
#  {'doc_id': 'doc_10',
#   'chunk_id': 'doc_10_chunk_5',
#   'chunk_content': '서비스 확대\n개인\nAI 서비스\n기업\n질의응답 및 대화\n자연어 → 쿼리생성\n코드 → 자연어 해석\n개발 언어 간 번역\n코드 버그 수정\n이미지 생성\n번역 및 교정\n창작 및 요약\n텍스트 → 표\n…\n고성능 AI 모델\n이용료\n고성능 AI 모델\n이용료\nAI 기반 응용 \n서비스 제공\nAI 수요 \n기업\nF\no\nc\nu\ns\n[OpenAI 서비스 및 성과]\n[OpenAI 비즈니스 매커니즘 이해]\n',
#   'contextualized_content': 'OpenAI의 주요 서비스인 ChatGPT, Codex, DALL-E, Whisper와 같은 생성형 AI 모델을 통해 개인 및 기업에 제공되는 다양한 AI 서비스들을 설명하고 있습니다. \n'},
#  {'doc_id': 'doc_11',
#   'chunk_id': 'doc_11_chunk_1',
#   'chunk_content': 'Samil PwC  l  Samil Insight\n10\nII.\n생성형 AI 시장 전망 및 도입 현황: \n수요자 측면\n',
#   'contextualized_content': '본 텍스트는 "생성형 AI 시장 전망 및 도입 현황" 보고서의 2장(II)의 제목이며, 수요자 측면을 다룹니다. \n'},
#  {'doc_id': 'doc_12',
#   'chunk_id': 'doc_12_chunk_1',
#   'chunk_content': 'Samil PwC  l  Samil Insight\n11\n1. 생성형 AI 활용 시장 전망\nII. 생성형 AI 시장 전망 및 도입 현황: 수요자 측면\n현재 AI 활용 초기 단계, 향후 기업의 AI 도입률 증가 전망\n\uf06c이제부터는 개발된 생성형 AI를 도입하여 활용하는 수요자 측면에서의 시장을 살펴보고자 한다. 생성형 \nAI의 범용적인 활용은 아직 초기 단계이나, 기업이 AI를 적극 도입하면서 새로운 비즈니스 모델 및 가치가 \n지속 창출될 것으로 전망됨에 따라 생성형 AI시장의 성장세는 상당히 유망할전망이다.\n\uf0a7Coatue(’23): CEO의 60% 이상이 생성형 AI를 도입할 의향을 보인 한편, 오직 9%만이 AI를 완전히 채택. \n약 60~75%가 아직 파일럿 테스트 또는 초기 검증 단계인 것으로 나타남\n* ',
#   'contextualized_content': "본 텍스트는 삼일PwC가 작성한 '생성형 AI 활용 시장 전망' 보고서의 일부이며, 생성형 AI 도입 현황 및 시장 전망을 다루는 2장의 시작 부분입니다. \n"},
#  {'doc_id': 'doc_12',
#   'chunk_id': 'doc_12_chunk_2',
#   'chunk_content': '도입할 의향을 보인 한편, 오직 9%만이 AI를 완전히 채택. \n약 60~75%가 아직 파일럿 테스트 또는 초기 검증 단계인 것으로 나타남\n* CEO 600명 대상 설문조사 결과\n\uf06c’24년부터는 온디바이스 AI(스마트폰, PC, 가전 등에AI 탑재), 자율주행, 보안, 금융, 로봇, 헬스케어 등 전 \n산업 응용처로 확대되며 생성형 AI 시장 규모가 급성장할 전망이다. Bloomberg(’23)예상치를 보더라도\n생성형 AI 시장 규모는 ’23년 670억 달러에서 ’32년 1.3조 달러로 CAGR 40% 수준의 급격한 성장을 \n전망하고 있다.\n\uf06c뿐만 아니라 전세계 CEO 대부분은 생성형 AI를 통해 기업 효율성 및 수익성 향상에 크게 기여할 수 있을 \n것이라 주장하고 있어,향후 기업의 생성형 AI도입률은 크게 ',
#   'contextualized_content': '생성형 AI 도입 현황과 향후 전망에 대한 내용입니다. 특히 기업의 AI 도입률이 아직 초기 단계임을 강조하며, 2024년부터 다양한 산업 분야에서 생성형 AI 활용이 확대될 것으로 예상하고 있습니다. \n'},
#  {'doc_id': 'doc_12',
#   'chunk_id': 'doc_12_chunk_3',
#   'chunk_content': ' 대부분은 생성형 AI를 통해 기업 효율성 및 수익성 향상에 크게 기여할 수 있을 \n것이라 주장하고 있어,향후 기업의 생성형 AI도입률은 크게 증가할 것으로 기대된다.(*Appendix1참고)\n\uf0a7Deloitte(’23): CEO의 79%는 생성형 AI가 효율성을 높일 것으로 기대, 52%는 생성형 AI가 성장 기회를 \n늘릴 것으로 주장 \n* Fortune 500, Global 500 CEO 143명 대상 설문조사 결과\n\uf0a7PwC(’23): CEO의60%는 생성형 AI를 통해 자사 제품 및 서비스의 품질을 향상시킬 수 있을 것으로 기대 \n* CEO 4,702명 대상 설문조사 결과\n[기업의 AI 도입 현황 분석] \n※ Coatue (’23 survey), 삼일PwC경영연구원\n(단위: %)\n9\n6\n9\n33\n20\n2',
#   'contextualized_content': '생성형 AI 도입으로 기업 효율성 및 수익성 향상에 대한 CEO들의 기대와 실제 도입 현황을 보여주는 부분입니다. \n'},
#  {'doc_id': 'doc_12',
#   'chunk_id': 'doc_12_chunk_4',
#   'chunk_content': '조사 결과\n[기업의 AI 도입 현황 분석] \n※ Coatue (’23 survey), 삼일PwC경영연구원\n(단위: %)\n9\n6\n9\n33\n20\n26\n22\n25\n21\n35\n49\n43\n0\n20\n40\n60\n80\n100\n120\n기존 제품에 AI 기능 적용\n새로운 AI 제품 도입\n개인맞춤형 AI 활용\nFully adopted(완전히 채택)\nIn prod./Scale rollout(생산중/확장 출시)\nEarly testing(초기테스트)/MVP(최소기능제품)\nPOC or earlier(검증 또는 이전단계)\n60~75% \n초기 단계에 \n머물러 있음\n',
#   'contextualized_content': '본 텍스트는 생성형 AI 도입 현황을 분석한 결과를 보여주는 표와 함께 기업의 AI 도입 현황에 대한 설명을 담고 있습니다. \n'},
#  {'doc_id': 'doc_13',
#   'chunk_id': 'doc_13_chunk_1',
#   'chunk_content': 'Samil PwC  l  Samil Insight\n12\nAppendix 1. PwC, Deloitte CEO Survey: AI 도입에 대해 긍정적 \nII. 생성형 AI 시장 전망 및 도입 현황: 수요자 측면\n\uf06c[PwC] CEO들은 생성형 AI를 도입하는 기업들이 빠르게 증가하고 있다고 판단하고 있으며, 생성형 AI가 \n기업에 미칠 영향력이 상당할 것으로 전망하고 있다. 전반적으로 CEO들은 생성형 AI가 기업의 제품 품질,\n고객 신뢰, 효율성, 수익성에 긍정적인 영향을 미칠 것으로 기대하며, 리스크 보다는 기회 요인으로 \n평가하고 있다.\n\uf0a760% 이상의 CEO들이 생성형 AI를 통해 인력의 작업 효율도가 5% 이상으로 개선될 것으로 보며, 절반 \n가까이 되는 CEO들이 생성형 AI가 기업 이익 증가에도 기',
#   'contextualized_content': 'PwC와 Deloitte의 CEO 설문 조사 결과, 생성형 AI 도입에 대한 기업 CEO들의 긍정적인 전망과 기대를 다룬 부분입니다. \n'},
#  {'doc_id': 'doc_13',
#   'chunk_id': 'doc_13_chunk_2',
#   'chunk_content': "생성형 AI를 통해 인력의 작업 효율도가 5% 이상으로 개선될 것으로 보며, 절반 \n가까이 되는 CEO들이 생성형 AI가 기업 이익 증가에도 기여할 것으로 기대\n[PwC Survey('23) –생성형 AI의 기업 영향]\n※ PwC’s 27th Annual Global CEO Survey, 삼일PwC경영연구원 \nQ: 생성형 AI가 향후 1년간 다음 사항에 대해 어느 정도로 증가/감소시킬 것이라 생각하십니까?\n\uf06c[Deloitte] 생성형 AI 도입으로 CEO는 기업 운영 효율성(79%), 운영 자동화(75%), 운영비용 감축 \n(65%) 등 실질적 도움을 받을 것으로 기대하고 있다.\n[Deloitte Survey('23) –생성형 AI의 효용성}\n※ Summer 2023 Fortune/Deloitte CEO S",
#   'contextualized_content': '본 텍스트는 PwC와 Deloitte에서 실시한 CEO 설문조사 결과를 바탕으로 생성형 AI 도입에 대한 기업 CEO들의 긍정적인 전망을 보여줍니다. 특히 PwC 설문조사에서는 CEO들이 생성형 AI가 인력의 작업 효율성과 기업 이익 증가에 기여할 것으로 예상하는 비율이 높게 나타났으며, Deloitte 설문조사에서는 생성형 AI가 기업 운영 효율성, 자동화, 비용 감축 등에 실질적인 도움을 줄 것으로 기대하고 있습니다. \n'},
#  {'doc_id': 'doc_13',
#   'chunk_id': 'doc_13_chunk_3',
#   'chunk_content': "대하고 있다.\n[Deloitte Survey('23) –생성형 AI의 효용성}\n※ Summer 2023 Fortune/Deloitte CEO Survey, 삼일PwC경영연구원 \nQ: 생성형 AI가 기업 경영 측면에 있어 얼마나 도움이 될 것이라 생각하십니까?\n4%\n3%\n3%\n2%\n28%\n34%\n47%\n52%\n64%\n59%\n46%\n41%\n인력의 작업 효율도\n본인(CEO)의 작업 효율도\n이익\n매출\n감소(5% 또는 그 이상)\n변화 없거나 약간의 변화(5% 내외)\n증가(5% 또는 그 이상)\n79%\n75%\n65%\n61%\n52%\n31%\n13%\n20%\n27%\n30%\n37%\n50%\n8%\n5%\n8%\n8%\n11%\n19%\n효율성 증대\n운영 자동화\n운영비용 감축\n신규 데이터 확보 개선\n성장기회 증대\n위기관리 개선\n높음\n보통\n낮음",
#   'contextualized_content': '삼일PwC 경영연구원의 딜로이트 CEO 설문조사 결과, 생성형 AI가 기업 운영 효율성, 운영 자동화, 운영 비용 감축 등에 큰 도움이 될 것으로 예상된다는 내용입니다. \n'},
#  {'doc_id': 'doc_13',
#   'chunk_id': 'doc_13_chunk_4',
#   'chunk_content': '\n8%\n5%\n8%\n8%\n11%\n19%\n효율성 증대\n운영 자동화\n운영비용 감축\n신규 데이터 확보 개선\n성장기회 증대\n위기관리 개선\n높음\n보통\n낮음\n',
#   'contextualized_content': 'Deloitte의 CEO 설문조사 결과를 보여주는 표입니다. 설문조사에서 생성형 AI가 기업 경영에 미치는 영향에 대한 CEO들의 의견을 수치로 나타내고 있습니다. \n'},
#  {'doc_id': 'doc_14',
#   'chunk_id': 'doc_14_chunk_1',
#   'chunk_content': 'Samil PwC  l  Samil Insight\n13\n2. 생성형 AI의 비즈니스 도입 현황\nII. 생성형 AI 시장 전망 및 도입 현황: 수요자 측면\n이제부터 기업들은 AI의 본격적 도입 및 수익 창출에 집중\n\uf06c전 산업에 걸쳐 글로벌 800여개 기업(은행, 제약, 공공, 자동차등)의 주요 의사결정권자(CEO, CSO, CFO\n등) 중 75%가 생성형 AI를비즈니스 경쟁 우위와 직결되는 요소로 판단하며 높은 투자의향을 보이고 있다.\n이러한 이유로 향후 선도 기업들의 성공적인 생성형 AI 도입 사례가 전파되면서 도입 속도가 전 산업에 걸쳐 \n크게 증가할 것으로 전망되며, MWC 2024에서 NTT data가 발표한 자료에 따르면 기업들의 생성형 AI\n투자 규모는 연평균 17%증가할 것으로 보고 있다.\n\uf06cAI',
#   'contextualized_content': "본 텍스트는 삼일PwC 경영연구원의 보고서 '생성형 AI의 비즈니스 도입 현황' 중 'II. 생성형 AI 시장 전망 및 도입 현황: 수요자 측면'의 일부분입니다.  특히, 기업들의 생성형 AI 투자 의향이 높다는 것을 설명하는 부분입니다. \n"},
#  {'doc_id': 'doc_14',
#   'chunk_id': 'doc_14_chunk_2',
#   'chunk_content': '며, MWC 2024에서 NTT data가 발표한 자료에 따르면 기업들의 생성형 AI\n투자 규모는 연평균 17%증가할 것으로 보고 있다.\n\uf06cAI 기술 수준이 발전함에 따라 사용처가 다양하게 확대될 것이며, 산업 전방위적 AI 도입 추세에 힘입어 \n투자는 가속화될 전망이다.이에 기업들은 생성형 AI기반 비즈니스 모델 구축과 더불어 본격 수익화 전략에 \n돌입할 것으로 예상된다.\n\uf06c’23년에는 기업들이 생성형AI 개발 및 안정화에 집중했다면, ’24년부터는 생성형 AI의 대중적인 보급과 \n본격적 도입에 따른 생산성 향상 및 수익 창출에 초점을 두어 사업을 전개해 나갈 것으로 예상된다. 동시에 \n각 산업별로는 단순 생성형 AI 도입을 넘어 차별화를 통한 수익화에 대한 깊은 고민이 병행될 것으로 보인다.\n[글로벌 의',
#   'contextualized_content': '생성형 AI 도입 현황과 관련하여 글로벌 기업들의 투자 규모 증가 및 산업 전반의 AI 도입 가속화 전망에 대한 내용입니다. \n'},
#  {'doc_id': 'doc_14',
#   'chunk_id': 'doc_14_chunk_3',
#   'chunk_content': '로 예상된다. 동시에 \n각 산업별로는 단순 생성형 AI 도입을 넘어 차별화를 통한 수익화에 대한 깊은 고민이 병행될 것으로 보인다.\n[글로벌 의사결정권자 75% AI 투자 의향 –금융 및 헬스케어 분야 적극적]\n업종\n설문 참여 기업 수\n투자의향 (%)\n은행\n233\n80\n보험\n110\n79\n헬스케어\n96\n77\n제약\n53\n77\n유틸리티\n90\n74\n공공\n138\n72\n자동차\n51\n71\n유통\n85\n65\n합계\n856\n75\n금융기관의 경우 대출심사, 고객 현금흐름 \n분석 등 에 AI 적용하기 시작. 투자 적극적\n헬스케어 및 제약 업종은 신약 개발 소요기간 \n단축을 위해 AI 투자에 적극적\n향후 유틸리티, 자동차, IT, 유통 등에서도 \n생산 효율화 및 자동화를 위한 AI 투자와 도입 \n속도 빨라질 것\n※ NTT data,',
#   'contextualized_content': '생성형 AI 도입 현황과 전망, 글로벌 기업들의 AI 투자 의향 및 주요 업종별 도입 현황을 보여주는 표와 함께 설명하는 부분입니다. \n'},
#  {'doc_id': 'doc_14',
#   'chunk_id': 'doc_14_chunk_4',
#   'chunk_content': ' 적극적\n향후 유틸리티, 자동차, IT, 유통 등에서도 \n생산 효율화 및 자동화를 위한 AI 투자와 도입 \n속도 빨라질 것\n※ NTT data, MWC, KB증권, 삼일PwC경영연구원\n[주요 업종별 AI 영향 및 도입 전망]\n※ NTT data, MWC, KB증권, 삼일PwC경영연구원\n업종\nAI 영향\n도입 전망\n유틸리티\n생산 최적화\n’26년까지 40%의 유틸리티 기업의 AI 도입, ‘27년까지 50% 도입\n생명과학\n생산방식 변화\n’25년까지 30%의 제약/바이오 기업 임상 과정에 AI 사용\n제조업\nAI/자동화 적용 확대\n’25년까지 30% 제조사 AI 사용, 다품종 소량 생산\n에너지\n지속가능성 규제 대응\n’26년까지 40%의 제조사 AI 투자하여 약 30% 생산성 개선\n',
#   'contextualized_content': '생성형 AI에 대한 금융, 헬스케어, 유틸리티, 자동차, IT, 유통 등 다양한 산업 분야의 투자 의향과 도입 전망을 제시하는 부분입니다. \n'},
#  {'doc_id': 'doc_14',
#   'chunk_id': 'doc_14_chunk_5',
#   'chunk_content': '소량 생산\n에너지\n지속가능성 규제 대응\n’26년까지 40%의 제조사 AI 투자하여 약 30% 생산성 개선\n',
#   'contextualized_content': '본 텍스트는 생성형 AI 시장 전망 및 도입 현황에서 주요 업종별 AI 영향 및 도입 전망을 제시하는 표의 일부입니다. 특히 에너지 업종의 경우 지속가능성 규제 대응을 위해 AI 투자가 활발할 것으로 예상되며, 이를 통해 2026년까지 40%의 제조사가 AI에 투자하여 약 30%의 생산성 향상을 기대할 수 있다고 설명합니다. \n'},
#  {'doc_id': 'doc_15',
#   'chunk_id': 'doc_15_chunk_1',
#   'chunk_content': 'Samil PwC  l  Samil Insight\n14\nIII.\n산업별 \n비즈니스 AI 활용 현황\n',
#   'contextualized_content': '본 텍스트는 삼일 PwC & 삼일 인사이트가 작성한 문서의 "산업별 비즈니스 AI 활용 현황" 챕터의 제목과 페이지 번호입니다. \n'},
#  {'doc_id': 'doc_16',
#   'chunk_id': 'doc_16_chunk_1',
#   'chunk_content': 'Samil PwC  l  Samil Insight\n15\n[Outline] 산업별 비즈니스 AI 활용 현황(1)\nIII. 산업별 비즈니스 AI 활용 현황\n\uf06cAI는 방대한 데이터에 기반해 의사결정을 지원하고 복잡한 작업을 높은 정확도와 속도로 수행하는 능력을 지녀,\n시간과 비용을 절감하고 업무 효율성과 생산성을 높일 수 있는 획기적인 기술로 부상하고 있다.\n\uf06c이에 AI는 챗봇과 같은 소비자 지향 솔루션부터 제조 장비 예측보수와 같은 전문적인 기능까지 다양하게 \n활용되어 수많은 산업 분야에 혁신을 일으키는 중이다.전 산업에 걸친 AI의 혁신적 결과를 기대하며 산업별로 \n추진중인 AI활용의 사례를 간단하게 정리하면 다음과 같다.\n산업 구분\nAI 활용 예시\n금융\n•\n사기 탐지 및 예방: 거래 패턴을 분석, 이상 징후',
#   'contextualized_content': '본 텍스트는 PwC 삼일회계법인에서 발행한 "산업별 비즈니스 AI 활용 현황(1)" 보고서의 일부이며, AI가 금융 산업에서 어떻게 활용될 수 있는지에 대한 개요를 제공합니다. 특히, AI를 활용한 사기 탐지 및 예방에 대한 설명을 포함하고 있습니다. \n'},
#  {'doc_id': 'doc_16',
#   'chunk_id': 'doc_16_chunk_2',
#   'chunk_content': '진중인 AI활용의 사례를 간단하게 정리하면 다음과 같다.\n산업 구분\nAI 활용 예시\n금융\n•\n사기 탐지 및 예방: 거래 패턴을 분석, 이상 징후 식별, 실시간 사기 탐지\n•\n신용 점수 및 위험 평가: 데이터 분석으로 개인과 기업의 신용도를 평가하는 정확도를 높임\n•\n챗봇: 문의에 즉각적인 응답을 제공, 계좌 조회를 지원, 개인화된 금융 조언을 제공\n•\n로보 어드바이저: 시장 동향 분석, 투자 포트폴리오 최적화, 자산 관리 서비스 지원\n•\n자금세탁방지(AML) 규정 준수: 잠재적 자금 세탁 활동 식별/감지하여 규제 요건 준수 지원\n헬스케어\n•\n의료 영상: X-ray와 CT 스캔을 정확하게 분석하여 질병의 진단 속도와 정확도 향상\n•\n개인 맞춤형 치료: 환자 데이터, 유전 정보, 라이프스타일 요인을 활용하여맞춤',
#   'contextualized_content': '본 문서는 산업별 AI 활용 현황을 다루고 있으며, 이 텍스트는 금융 및 헬스케어 산업에서 AI가 활용되는 구체적인 사례를 제시하는 부분입니다. \n'},
#  {'doc_id': 'doc_16',
#   'chunk_id': 'doc_16_chunk_3',
#   'chunk_content': 'CT 스캔을 정확하게 분석하여 질병의 진단 속도와 정확도 향상\n•\n개인 맞춤형 치료: 환자 데이터, 유전 정보, 라이프스타일 요인을 활용하여맞춤형 치료 계획 수립\n•\n전자 건강 기록(EHR): EHR 데이터를 분석하여 패턴과 추세를 파악, 개인화된 예방 전략을 지원\n•\n사기 탐지: 방대한 의료 데이터를 조사하여 불규칙한 패턴 감지, 과다 청구, 불필요한 시술 등 식별\n•\n가상 어시스턴트 및 챗봇: 원격으로 환자를 안내(진료 예약, 약물 정보 제공 등), 개인화된 조언 제공\n•\n신약 개발: AI로 신약으로 전환될 가능성이 있는 새로운 약물 분자를 개발/ 테스트\n제조\n(자동차 포함 \n제조 전반)\n•\n결함 감지: 실시간으로 이상 징후와 편차를 신속하게 감지하여 오경보와 수동 검사를 줄임\n•\n조립 라인 통합: 조립',
#   'contextualized_content': 'AI 활용 사례로서 헬스케어 산업에서의 AI 활용 현황을 설명하는 부분입니다. \n'},
#  {'doc_id': 'doc_16',
#   'chunk_id': 'doc_16_chunk_4',
#   'chunk_content': '자동차 포함 \n제조 전반)\n•\n결함 감지: 실시간으로 이상 징후와 편차를 신속하게 감지하여 오경보와 수동 검사를 줄임\n•\n조립 라인 통합: 조립 프로세스를 간소화하여 사람의 개입을 최소화, 효율적이고 일관된 생산 보장\n•\n예측 분석: 센서 데이터와 유지보수 기록을 분석하여 다운타임 최소화, 유지보수 비용 절감, 생산 가동 \n시간 최적화\n•\n실시간 모니터링 및 분석: 다양한 소스에서 데이터를 수집하여 생산 라인을 실시간으로 모니터링\n•\n프로세스 최적화: 생산 데이터 기반으로 사이클 시간, 에너지 소비, 자재 사용 등 비효율적인 부분을 파악\n하여 제조 공정을 최적화\n제조(화학)\n•\nR&D 가속화: 분자 발견 및 인식, 공식화 등을 지원하며 R&D 프로세스의 속도 및 정확도 높임\n•\n예측분석: 화학 물질 생산에 ',
#   'contextualized_content': '본 텍스트는 "산업별 비즈니스 AI 활용 현황" 문서의 제조 부분으로 자동차를 포함한 제조 전반과 화학 제조 분야에서 AI가 활용되는 구체적인 사례들을 설명하고 있다. \n'},
#  {'doc_id': 'doc_16',
#   'chunk_id': 'doc_16_chunk_5',
#   'chunk_content': '(화학)\n•\nR&D 가속화: 분자 발견 및 인식, 공식화 등을 지원하며 R&D 프로세스의 속도 및 정확도 높임\n•\n예측분석: 화학 물질 생산에 필요한 원료량 예측, 재료의 가격 예측 등으로 생산 공정을 조정\n•\n생산 품질 보증: 저품질 생산 사례를 감지, 제품 라인에서 사고 예방, 향후 효율적 해결 방안 마련\n•\n운영 효율화: AI 자동화를 통해 비즈니스 운영에 필요한 인풋(에너지, 인력 등) 감소, 비용 절감 \n농업\n•\n시장 수요 분석: 농부들이 재배하거나 판매하기에 가장 적합한 작물을 선택하는 데 지원\n•\n종자 육종: 식물 성장에 대한 데이터를 수집하여 작물을 더 건강하게 생산할 수 있도록 지원\n•\n토양 건강 모니터링: 화학적 토양 분석을 수행하고 누락된 영양소를 정확하게 추정\n•\n농작물 보호: 식물의 ',
#   'contextualized_content': '본 텍스트는 다양한 산업 분야에서 인공지능(AI) 활용 사례를 소개하는 문서의 일부분으로, 화학 및 농업 분야에서 AI가 어떻게 활용되는지 구체적인 예시를 제시하고 있습니다. \n'},
#  {'doc_id': 'doc_16',
#   'chunk_id': 'doc_16_chunk_6',
#   'chunk_content': ' 건강하게 생산할 수 있도록 지원\n•\n토양 건강 모니터링: 화학적 토양 분석을 수행하고 누락된 영양소를 정확하게 추정\n•\n농작물 보호: 식물의 상태를 모니터링하여 질병을 발견 및 예측, 잡초를 식별 및 제거\n•\n지능형 살포: 잡초나 해충 방제를 자동화. 농작물의 이력, 토양 상태 또는 작물 유형에 대한 데이터 분석을 \n기반으로 각 밭에 필요한 농약의 양을 계산\n•\n챗봇: 농부와 고객 또는 유통업체 간의 소통 지원(제품에 대한 질문, 주문, 재고 확인 등)\n',
#   'contextualized_content': '본 텍스트는 농업 분야에서 AI 활용 사례를 설명하는 부분입니다. \n'},
#  {'doc_id': 'doc_17',
#   'chunk_id': 'doc_17_chunk_1',
#   'chunk_content': 'Samil PwC  l  Samil Insight\n16\n[Outline] 산업별 비즈니스 AI 활용 현황(2)\nIII. 산업별 비즈니스 AI 활용 현황\n산업 구분\nAI 활용 예시\n물류\n•\n창고 공간 활용도 최적화: 제품 수요와 재고 수준에 대한 데이터를 분석하여 창고 운영 효율성 향상\n•\n배송 추적 및 모니터링: 배송을 효율적으로 실시간으로 추적하고 모니터링하여 지연이나 문제 방지 \n•\n실시간 교통 관리: 실시간 교통 상황을 지속적으로 모니터링하여 경로를 최적화, 지연을 최소화\n•\n자동화된 재고 관리: 재고 수준을 정밀하게 모니터링하고 보충 프로토콜을 자동화\n•\n리소스 관리: 주문량과 처리 시간 등의 워크로드 데이터를 분석하여 작업자 간의 업무 배분 최적화\n관광/여행\n•\n개인 맞춤형 여정: AI를 통해 개인',
#   'contextualized_content': '본 텍스트는 삼일PwC와 삼일인사이트가 작성한 "산업별 비즈니스 AI 활용 현황(2)" 보고서의 일부이며, 물류 및 관광/여행 산업에서 AI가 활용되는 다양한 예시를 소개하고 있습니다. \n'},
#  {'doc_id': 'doc_17',
#   'chunk_id': 'doc_17_chunk_2',
#   'chunk_content': '스 관리: 주문량과 처리 시간 등의 워크로드 데이터를 분석하여 작업자 간의 업무 배분 최적화\n관광/여행\n•\n개인 맞춤형 여정: AI를 통해 개인의 선호도에 따라 맞춤형 여행 일정을 제공\n•\n실시간 여행 업데이트 및 추천: 실시간 업데이트와 위치 및 선호도에 따른 맞춤형 추천을 제공\n•\n챗봇: 예약 과정에서 여행자의 문의 지원, 가격에 대한 세부 정보를 제공하고 옵션을 비교\n•\n스마트한 쇼핑: 여행자가 가격, 평점, 편의시설과 같은 중요한 요소를 손쉽게 비교할 수 있도록 지원\n미디어/\n엔터테인먼트\n•\n음악 추천: 청취 기록, 선호도를 포함한 사용자 데이터를 활용해 장르, 아티스트 등 개인 맞춤형 추천\n•\n게임 디자인: 비플레이어 캐릭터(NPC), 메커니즘 등 개선하여 게임 디자인을 및 사용자 경험 향상\n•\n스',
#   'contextualized_content': '본 텍스트는 "산업별 비즈니스 AI 활용 현황" 문서의 일부이며, 물류 산업에서의 AI 활용 예시와 이어서 관광/여행, 미디어/엔터테인먼트 산업에서의 AI 활용 예시를 소개하고 있습니다. \n'},
#  {'doc_id': 'doc_17',
#   'chunk_id': 'doc_17_chunk_3',
#   'chunk_content': ', 아티스트 등 개인 맞춤형 추천\n•\n게임 디자인: 비플레이어 캐릭터(NPC), 메커니즘 등 개선하여 게임 디자인을 및 사용자 경험 향상\n•\n스토리텔링: 콘텐츠 제작과 전달을 강화하여 스토리텔링에 기여. 방대한 데이터 세트를 분석해 캐릭터 \n개발과 플롯 구조에 대한 인사이트를 제공\n•\n영화 편집: 영향력이 큰 장면을 식별하여 영화 예고편 제작하고 장편 영화를 편집\n법률\n•\n계약서 분석: 주요 조항의 검토 및 추출 자동화, 법률 문서 검토의 효율성을 높여 계약서 분석 간소화\n•\n법률 연구: 방대한 법률 텍스트, 판례, 판례를 분석하여 법률 연구를 지원, 전문가 의사 결정을 지원\n•\n전자증거개시: 대량의 전자 문서, 이메일, 디지털 증거를 효율적으로 분석, 분류하여 전자증거개시\n•\n위험 평가 및 규정 준수: 법',
#   'contextualized_content': '미디어/엔터테인먼트 산업에서의 AI 활용 예시를 설명하는 부분입니다. \n'},
#  {'doc_id': 'doc_17',
#   'chunk_id': 'doc_17_chunk_4',
#   'chunk_content': '정을 지원\n•\n전자증거개시: 대량의 전자 문서, 이메일, 디지털 증거를 효율적으로 분석, 분류하여 전자증거개시\n•\n위험 평가 및 규정 준수: 법적 위험 식별 및 평가, 규정 준수를 모니터링하며위험 완화 조언 제공\n•\n챗봇 및 가상 비서: 일반적인 법률 문의에 즉각적으로 응답, 법률 절차 지원, 고객과의 소통 개선\n•\n문서 자동화: 법률 문서 작성시 오류 감소, 시간 절약, 문서 일관성 보장, 문서 생성 프로세스 간소화\n리테일 \n이커머스\n•\n개인화된 쇼핑 경험: 고객의 행동, 선호도, 구매 이력을 분석해 맞춤형 상품 제안\n•\n가격 최적화: 실시간 시장 상황, 경쟁사 가격, 고객 수요를 분석해 최적의 가격 전략 수립\n•\n재고 관리 및 수요 예측: 수요 패턴, 계절적 변동, 트렌드를 예측하여 재고 수준 최적화 지',
#   'contextualized_content': '본 텍스트는 문서의 "III. 산업별 비즈니스 AI 활용 현황" 섹션의 "법률"과 "리테일 이커머스" 산업에서 AI가 어떻게 활용되는지 설명하는 부분입니다. \n'},
#  {'doc_id': 'doc_17',
#   'chunk_id': 'doc_17_chunk_5',
#   'chunk_content': '격, 고객 수요를 분석해 최적의 가격 전략 수립\n•\n재고 관리 및 수요 예측: 수요 패턴, 계절적 변동, 트렌드를 예측하여 재고 수준 최적화 지원\n•\n고객 서비스용 챗봇: 고객 문의를 처리, 즉각적인 지원을 제공, 주문 추적을 지원\n•\n시각적 검색 및 이미지 인식: AI 기반 시각적 검색 기술을 활용하여 고객이 텍스트가 아닌 이미지를 \n사용하여 제품을 검색(자동 제품 태그 지정, 카탈로그 관리 간소화, 검색 정확도 향상 등 기능에 활용)\n푸드테크\n•\n공급망 최적화: 수요를 예측하고 재고를 관리하며 물류를 개선하여 식품 공급망을 최적화\n•\n품질 관리 및 검사: 식품의 결함, 오염 또는 불규칙성을 감지하여 고품질의 제품만 출시\n•\n풍미 및 레시피 최적화: 소비자 선호도와 트렌드를 분석하여 음식의 맛과 레시피를 ',
#   'contextualized_content': '본 텍스트는 리테일 및 이커머스 산업에서 비즈니스 AI가 활용되는 다양한 사례들을 보여주는 문서의 일부입니다. \n'},
#  {'doc_id': 'doc_17',
#   'chunk_id': 'doc_17_chunk_6',
#   'chunk_content': '결함, 오염 또는 불규칙성을 감지하여 고품질의 제품만 출시\n•\n풍미 및 레시피 최적화: 소비자 선호도와 트렌드를 분석하여 음식의 맛과 레시피를 최적화\n•\n레스토랑의 메뉴 맞춤화: 고객의 선호도, 식단 제한, 과거 주문 데이터를 기반으로 메뉴를 개인화, 식사 경험 \n및 고객 만족도 개선\n',
#   'contextualized_content': '푸드테크 산업에서 AI 활용 예시 중 품질 관리, 풍미 및 레시피 최적화, 메뉴 맞춤화에 대한 설명입니다. \n'},
#  {'doc_id': 'doc_18',
#   'chunk_id': 'doc_18_chunk_1',
#   'chunk_content': 'Samil PwC  l  Samil Insight\n17\n1-1. 금융: 비즈니스 AI 활용 현황\nIII. 산업별 비즈니스 AI 활용 현황\n\uf06c금융업은 헬스케어,자동차 산업에 이어 AI영향력이 큰 업종 중 하나로,금융권의 수치,재무 등 방대한 정형 \n데이터를 기반으로 강력한 AI비즈니스 창출이 가능한 산업이다.\n\uf06c특히 ① 신속한 고객 문의 대응을 위한 챗봇/상담봇, ② 투자성향, 리스크 수준, 기대 수익률 등 자산관리 및 \n상품추천 정보를 제공하는 로보어드바이저(Robo-advisor), ③ 각종 서류를 자동으로 분석/분류하는 등 \n프로세스를 개선해주는 로봇 프로세스 자동화(Robotic Process Automation, RPA) 기능에 \n금융기관들은 주목하고 있다.\n\uf06c현재 국내외 금융기관들의 생성형 AI 도',
#   'contextualized_content': '본 텍스트는 "Samil PwC l Samil Insight" 보고서의 "III. 산업별 비즈니스 AI 활용 현황" 섹션의 "1-1. 금융: 비즈니스 AI 활용 현황" 부분입니다. 금융 산업에서 AI 적용 현황과 특징을 설명하는 부분입니다. \n'},
#  {'doc_id': 'doc_18',
#   'chunk_id': 'doc_18_chunk_2',
#   'chunk_content': '동화(Robotic Process Automation, RPA) 기능에 \n금융기관들은 주목하고 있다.\n\uf06c현재 국내외 금융기관들의 생성형 AI 도입 및 활용 방향성을 비추어 봤을때 특히 ‘마케팅/영업’과 \n‘고객관리’와 같이 개별 고객에 대한 정밀한 분석 기반의 1대1 맞춤형 서비스가 요구되는 영역을 중심으로 \n보다 고도화된 생성형 AI기술을 활용하고자 하는 니즈가 높아지고 있다.\n[금융 산업 밸류체인 -AI 적용 예시]\n마케팅, 영업\n상품, 서비스\n고객관리\n운영 관리\n리스크 관리\n• 초개인화 고객 분석\n• 시장 분석/예측\n• 원격 지원\n• 잠재 고객 발굴\n• 챗봇\n• 고객 segment별 \n특화된 맞춤상품 추천\n• 신원인식(얼굴, 음성)\n• 컨설팅(투자, 보험, \n절세 등)\n• 금융/비금융 연계 \n종합 플랫',
#   'contextualized_content': '본 문서에서 해당 텍스트는 금융 산업에서 인공지능(AI) 활용 현황을 설명하며, 특히 챗봇, 로보어드바이저, RPA 기능이 주목받고 있음을 강조하는 부분입니다. 이어서 국내외 금융기관들의 AI 도입 현황과 향후 생성형 AI 기술 활용 방향에 대한 설명으로 이어집니다. \n'},
#  {'doc_id': 'doc_18',
#   'chunk_id': 'doc_18_chunk_3',
#   'chunk_content': ' 고객 segment별 \n특화된 맞춤상품 추천\n• 신원인식(얼굴, 음성)\n• 컨설팅(투자, 보험, \n절세 등)\n• 금융/비금융 연계 \n종합 플랫폼 제공\n• 식별/인증\n• 데이터 분석\n• 프로세스 자동화 \n(RPA) 적용\n• 지급 결제 관리 및 \n각종 보고서 작성\n• 자동심사(대출, 보험)\n• 고객 판별\n• 자금변동 및 거래 \n니즈 기반 상품 추천\n• 실시간 비대면 상품 \n추천\n• 신용등급 산정/조정\n• 로보어드바이저\n• 이상거래 및 사기 감지\n• 연체 예측 및 기업 진단 \n• 새로운 규제환경 대응 \n및 준수\n• 자금세탁방지\n현재 AI 집중 적용 영역 –챗봇, 로보어드바이저, RPA 중심으로 활용 중\n\uf06c그러나 현실은 국내외 금융기관 모두 생성형 AI 도입 초기 수준으로 전략적 파트너십 체결, 파일럿 단계 \n등',
#   'contextualized_content': '본 텍스트는 금융 산업에서 AI 적용 가능한 분야를 예시로 제시하고 있으며, 특히 고객 세분화를 통한 맞춤형 상품 추천, 신원 인식, 컨설팅, 데이터 분석 및 프로세스 자동화 등 다양한 AI 활용 사례를 소개하고 있습니다. 또한, AI 집중 적용 영역으로 챗봇, 로보어드바이저, RPA를 언급하며 현재 국내외 금융기관의 생성형 AI 도입 현황을 간략하게 설명하고 있습니다. \n'},
#  {'doc_id': 'doc_18',
#   'chunk_id': 'doc_18_chunk_4',
#   'chunk_content': '바이저, RPA 중심으로 활용 중\n\uf06c그러나 현실은 국내외 금융기관 모두 생성형 AI 도입 초기 수준으로 전략적 파트너십 체결, 파일럿 단계 \n등에 머물러 있는 수준이다. 다만 좀 더 정확하게는 국내 금융기관의 경우는 대체로 RPA, 고객 불만 처리,\n정보 제공, 시스템 구축 등 기본 운영 관리에 필요한 AI 기능을 도입한 수준에 머물러 있는 것으로 판단되는 \n반면, 해외의 경우는 좀 더 나아가 ‘개별 고객 접점 구축에 초점을 둔 맞춤형 서비스’ 마련에 상대적으로 더 \n적극적인 모습을 보이고 있다.\n\uf0a7해외 금융사들 중에서는 JP Morgan이 AI 성숙도가 가장 높은 것으로 평가받고 있으며, 데이터 분석용 \nAI 서비스에서 나아가 지금은언어모델에 기반한 금융자문 서비스 ‘IndexGPT’를 준비 중이다. 또한',
#   'contextualized_content': '금융 산업에서 인공지능(AI) 활용 현황을 설명하는 부분입니다. 특히 국내외 금융기관의 AI 도입 수준과 차이점, 대표적인 사례(JP Morgan)를 소개하고 있습니다. \n'},
#  {'doc_id': 'doc_18',
#   'chunk_id': 'doc_18_chunk_5',
#   'chunk_content': '것으로 평가받고 있으며, 데이터 분석용 \nAI 서비스에서 나아가 지금은언어모델에 기반한 금융자문 서비스 ‘IndexGPT’를 준비 중이다. 또한 \n내부 전문 IT 및 혁신 조직(Technological Infrastructure, Innovation Centers, AI team 등)과 외부 \n파트너십을 통해 AI서비스 개발도 적극적으로 추진 중이다.\n',
#   'contextualized_content': '해외 금융기관 중 JP Morgan의 AI 활용 사례를 설명하는 부분입니다. \n'},
#  {'doc_id': 'doc_19',
#   'chunk_id': 'doc_19_chunk_1',
#   'chunk_content': 'Samil PwC  l  Samil Insight\n18\n1-2. 금융:  해외 기업  AI 적용 사례\nIII. 산업별 비즈니스 AI 활용 현황\n[해외 금융 기업의 AI 적용 사례]\n기업명\nAI 비즈니스 적용 사례\nMorgan Stanley\n•\nOpenAI와 협업하여 미국 은행 최초로 GPT4 기반의 챗봇 서비스를 직원에게 제공(’23)\n-자산관리 자문업무를 수행하는 Relationship Manager들이 활용\n-10만 개의 보고서로 구성된 은행의 knowledge DB를 활용해 다양한 질의응답을 수행\n-회의 내용 자동 요약, 후속으로 이메일을 생성하는 Debrief라는 도구 개발, 테스트 중\nNatwest\n•\nIBM의 Watson X를 활용해 Cora+라는 AI 가상 비서 출시(’23)\n-상품/서비스 정보',
#   'contextualized_content': '본 텍스트는 삼일PwC와 삼일인사이트가 작성한 보고서의 "III. 산업별 비즈니스 AI 활용 현황" 섹션 중 "1-2. 금융: 해외 기업 AI 적용 사례" 부분입니다. 특히, 해외 금융 기업 중 모건스탠리와 내트웨스트의 AI 활용 사례를 소개하고 있습니다. \n'},
#  {'doc_id': 'doc_19',
#   'chunk_id': 'doc_19_chunk_2',
#   'chunk_content': '라는 도구 개발, 테스트 중\nNatwest\n•\nIBM의 Watson X를 활용해 Cora+라는 AI 가상 비서 출시(’23)\n-상품/서비스 정보뿐만 아니라 은행의 기본 정보, 취업기회 등 다양한 정보와 기능을 제공\n•\nAWS와 협업하여 ’27년 말까지 사기 탐지, 맞춤형 금융 솔루션 제공, 고객지원 강화, 데이터 보안 등의 \n분야에 AI 솔루션을 개발할 계획\nJP Morgan \nChase\n•\n머신러닝과 자연어 처리 기반으로 후속 주식 오퍼링에 가장 적합한 고객을 식별하는 ‘Emerging \nOpportunities Engine’을 도입(’15)\n•\n법률 문서 분석, 중요 데이터 포인트 및 조항 추출 계약 인텔리전스 도구 ‘COiN’ 도입(’17)\n-기존에는 연간 12,000건의 상업 신용 계약을 수동으로 검',
#   'contextualized_content': '본 텍스트는 해외 금융 기업들의 AI 적용 사례 중 Morgan Stanley, Natwest, JP Morgan Chase의 사례를 소개하는 부분입니다. \n'},
#  {'doc_id': 'doc_19',
#   'chunk_id': 'doc_19_chunk_3',
#   'chunk_content': "중요 데이터 포인트 및 조항 추출 계약 인텔리전스 도구 ‘COiN’ 도입(’17)\n-기존에는 연간 12,000건의 상업 신용 계약을 수동으로 검토 시 약 36만 시간이 소요되었으나 \n이제 같은 양을 단 몇 초만에 검토\n•\n고객의 증권투자를 위한 금융정보 분석서비스인 'IndexGPT'를 개발 중이며, 이는 고객이 보유한 \n현재의 재정상황과 투자상품 정보를 기반으로 적절한 투자 옵션을 제안(’27년 전후 예상)\nWells Fargo\n•\nAI 벤더인 Kasisto가 구축한챗봇을 도입한 것으로 추정(’17)\n•\n스마트폰 기반 AI 예측 뱅킹 애플리케이션 출시, 사용자에게 다양한 시나리오에 따라 50가지 이상의 \n다양한 프롬프트를 제공\n-평균보다 높은 금액의 반복 청구서 결제에 대한 경고 알림, 저축 계좌로 돈 이",
#   'contextualized_content': 'JP Morgan Chase의 AI 적용 사례 중 법률 문서 분석 및 고객 맞춤형 투자 분석 서비스 개발에 대한 내용입니다. \n'},
#  {'doc_id': 'doc_19',
#   'chunk_id': 'doc_19_chunk_4',
#   'chunk_content': "다양한 시나리오에 따라 50가지 이상의 \n다양한 프롬프트를 제공\n-평균보다 높은 금액의 반복 청구서 결제에 대한 경고 알림, 저축 계좌로 돈 이체 알림, 비행기 티켓을 \n구매한 후 계좌에 여행 계획을 세우도록 유도하는 등 서비스 제공\nBank of \nAmerica\n•\n직원들을 대상으로 AI 챗봇인 'Erica’를 본격 도입(’18)\n-예측 분석으로 고객의 월 평균 지출액, 고객이 매달 구매하는 품목을 분석하여 고객의 잔액 관리, \n결제 이상 징후 감지 등 서비스 제공\n•\nAI 기반 리서치 분석 플랫폼 ‘Glass’로 시장 데이터와 은행 모델을 결합하여 업계 동향을 파악하고 \n고객 수요를 예측하여 개별화된 투자 조언을 제공\nGoldman Sachs\n•\n생성형 AI를 비즈니스에 통합하는 12개 프로젝트 진행 중",
#   'contextualized_content': "Wells Fargo의 AI 기반 뱅킹 애플리케이션과 Bank of America의 AI 챗봇 'Erica' 그리고 Goldman Sachs의 생성형 AI 적용 사례를 소개하는 부분입니다. \n"},
#  {'doc_id': 'doc_19',
#   'chunk_id': 'doc_19_chunk_5',
#   'chunk_content': '악하고 \n고객 수요를 예측하여 개별화된 투자 조언을 제공\nGoldman Sachs\n•\n생성형 AI를 비즈니스에 통합하는 12개 프로젝트 진행 중\n-코드 작성 및 문서 생성 등에 중점\nCitiBank\n•\n사기 및 자금세탁 방지 업체인 Feedzai를 비롯한 여러 AI 기업에 투자(’16)\n-Feedzai와 전략적 파트너십을 체결해 Feedzai 소프트웨어를 자사 사기 탐지 프로세스에 통합\n•\n1천 페이지 이상의 신규 자본 규정을 분석하는 데 생성형 AI를 활용. 파생상품 거래, 사기 적발, 인사 \n평가 등에도 활용하기 위해 시험 중\nMizuho\n•\n시스템 개발 및 유지관리 업무 효율화를 위해 생성형 AI 도입 중\n•\nFujitsu의 플랫폼 기술을 활용해 시스템 설계 계획, 감사 프로세스상 오류및 누락 등을 감',
#   'contextualized_content': '본 텍스트는 해외 금융 기업의 AI 적용 사례를 소개하는 문서의 일부로, Goldman Sachs, CitiBank, Mizuho 등의 기업에서 생성형 AI를 활용하는 사례를 구체적으로 설명하고 있습니다. \n'},
#  {'doc_id': 'doc_19',
#   'chunk_id': 'doc_19_chunk_6',
#   'chunk_content': '관리 업무 효율화를 위해 생성형 AI 도입 중\n•\nFujitsu의 플랫폼 기술을 활용해 시스템 설계 계획, 감사 프로세스상 오류및 누락 등을 감지하는 \n업무에 적용 중(현재 파일럿 단계)\n※ 각 사, 언론종합, 삼일PwC경영연구원\n',
#   'contextualized_content': 'Mizuho의 AI 활용 사례를 설명하는 부분입니다. \n'},
#  {'doc_id': 'doc_20',
#   'chunk_id': 'doc_20_chunk_1',
#   'chunk_content': 'Samil PwC  l  Samil Insight\n19\n1-3. 금융: 선도기업(JP Morgan) 비즈니스 모델\nIII. 산업별 비즈니스 AI 활용 현황\n\uf06cJP Morgan은 금융기관 중 대표적으로 AI를 비즈니스에 활용하고 있는 곳으로, 내부 조직과 외부 \n파트너십을 통해 생성형 AI서비스를 지속 개발하고 도입 중이며,이를 바탕으로 전사 금융 비즈니스 고도화 \n및 수익화에 기여할 뿐만 아니라 고객 경험도 개선 중이다.\n[JP Morgan AI 기반 비즈니스 모델 예시]\nJP Morgan\nAI Assets (내부 조직 및 솔루션)\n프로세스자동화\nRPA\nCOiN\nIndexGPT\nTIFIN.AI\n계약 서류 자동 검토\n투자자용 \n금융자문 서비스\n고객 데이터 기반 \n자산관리 서비스\n…\n…\nTech. Infra\nI',
#   'contextualized_content': '본 텍스트는 삼일 PwC와 삼일 인사이트에서 발간한 보고서의 일부로, 금융 분야의 선도 기업인 JP Morgan의 AI 기반 비즈니스 모델을 소개하는 내용입니다. \n'},
#  {'doc_id': 'doc_20',
#   'chunk_id': 'doc_20_chunk_2',
#   'chunk_content': 'dexGPT\nTIFIN.AI\n계약 서류 자동 검토\n투자자용 \n금융자문 서비스\n고객 데이터 기반 \n자산관리 서비스\n…\n…\nTech. Infra\nInnovation \nCenter\n기타 AI 인력\n고객 접점 채널\n대면\n(은행, \nATM 등)\n온라인 \n뱅킹\n모바일 \n앱\n챗봇\n로보어드\n바이저\n…\n수익화 채널\n…\n소비자/ 투자 금융\n자산 관리\n재무 및 증권 서비스\n상업은행\n주택담보대출\n금융 자문\nAI 기반 서비스 효율화, 수익성 극대화\nAI 집중 영역\n외부 소스\nDatamaran\nMicrosoft\nCleareye.ai\nESG 리스크 관리 \n플랫폼 활용\n블록체인 기술 채택\n디지털화, 규제 준수, \n문서 검증 및 자동화\nTIFIN\nAI 기반 자산 관리 \n서비스\n…\n협업\n AI 제품\n개발\n이용료\nAI \n솔루션/\n플랫폼\n개별',
#   'contextualized_content': 'JP Morgan의 AI 기반 비즈니스 모델 예시에서 AI 자산, 기술 인프라, 수익화 채널, 외부 소스, 협업 등을 보여주는 부분입니다. \n'},
#  {'doc_id': 'doc_20',
#   'chunk_id': 'doc_20_chunk_3',
#   'chunk_content': '화, 규제 준수, \n문서 검증 및 자동화\nTIFIN\nAI 기반 자산 관리 \n서비스\n…\n협업\n AI 제품\n개발\n이용료\nAI \n솔루션/\n플랫폼\n개별 고객 접점 \n맞춤형 서비스 영역 중심으로 \nAI 활용도 ↑ \n고객 세그먼트\n중소기업\n개인\n대기업\n투자자\n공공기관\n…\n고객 세그먼트별 \n맞춤형 서비스 제공\n고객  데이터/ 인사이트 제공\n예금, 대출 이자 등\n※ JP Morgan, 언론종합, 삼일PwC경영연구원\n',
#   'contextualized_content': 'JP Morgan의 AI 기반 비즈니스 모델에서 AI 활용 영역, 협업, 수익화 채널, 고객 세그먼트, 제공 서비스 등을 설명하는 부분입니다. \n'},
#  {'doc_id': 'doc_21',
#   'chunk_id': 'doc_21_chunk_1',
#   'chunk_content': 'Samil PwC  l  Samil Insight\n20\n1-4. 금융: 해외 금융업 AI 기술 기업/스타트업\nIII. 산업별 비즈니스 AI 활용 현황\n\uf06c글로벌 금융산업내 가장 활발하게 AI를 활용하고 있는 분야는 신용평가와 대출심사로, 신용평가 모형 개발,\n신용평가 산정 및 승인 등 관련 개인화 서비스를 개발 중인 기업들이 대다수인 것으로 조사되었다.\n\uf06c또한 금융 리스크 관리에 대한 중요성도 강조되며 이상거래 탐지, 자금세탁방지 등을 효과적으로 관리할 수 \n있는 AI기술에 대한 금융기관들의 관심이 높아지고 있는 만큼,이 분야를 개발하는 기업들도 성장세를 보일 \n것으로 전망된다.\n[해외 금융업 AI 기술 기업]\n구분\n기업명\n상세\n신용평가\nEnova\n•\n대출 플랫폼에서 AI와 머신러닝을 사용하여 고급 금융 분석',
#   'contextualized_content': '본 텍스트는 삼일 PwC 및 삼일 인사이트에서 발행한 보고서의 "금융: 해외 금융업 AI 기술 기업/스타트업" 부분으로, 금융 산업에서 활발하게 활용되는 AI 기술, 특히 신용평가 분야에 대한 개요와 해외 기업 사례를 소개하고 있습니다.  \n'},
#  {'doc_id': 'doc_21',
#   'chunk_id': 'doc_21_chunk_2',
#   'chunk_content': ' 전망된다.\n[해외 금융업 AI 기술 기업]\n구분\n기업명\n상세\n신용평가\nEnova\n•\n대출 플랫폼에서 AI와 머신러닝을 사용하여 고급 금융 분석과 신용 평가를 제공. \n중소기업을 위한 은행 대출 서비스 제공\nOcrolus\n•\n은행 명세서, 급여 명세서, 세금 서류, 모기지 양식, 송장 등을 머신러닝 및  사람 \n검증으로 분석하여 대출 자격을 결정\nScienaptic AI\n•\n은행과 신용 기관의 투명성을 높이고 손실을 줄이는 신용 인수 플랫폼을  비롯한 \n여러 금융 기반 서비스를 제공\nZest AI\n•\n기업이 신용 정보나 이력이 거의 또는 전혀 없는 대출자를 평가하는데  도움을 \n주는 AI 기반 언더라이팅 플랫폼\nUnderwrite.ai\n•\n신용 조사 기관의 수천 가지 재무 속성을 분석하여 소비자 및 중소기업',
#   'contextualized_content': '해외 금융업계에서 AI 기술을 활용하는 기업들의 사례를 소개하는 부분입니다. 특히 신용평가 분야에서 활용되는 AI 기업들의 구체적인 정보가 담겨 있습니다. \n'},
#  {'doc_id': 'doc_21',
#   'chunk_id': 'doc_21_chunk_3',
#   'chunk_content': '  도움을 \n주는 AI 기반 언더라이팅 플랫폼\nUnderwrite.ai\n•\n신용 조사 기관의 수천 가지 재무 속성을 분석하여 소비자 및 중소기업 대출 \n신청자의 신용 위험을 평가\n리스크 관리\nWorkiva\n•\n재무, 리스크 및 ESG 팀의 데이터 관리 및 보고를 위한 워크플로우를 \n간소화하도록 설계된 클라우드 플랫폼을 제공\nDerivative Path\n•\n클라우드 기반 플랫폼 Derivative Edge로 자동화된 작업과 프로세스,  맞춤형 \n워크플로우, 파생상품 포트폴리오 관리를 지원\nSimudyne\n•\n위험 관리뿐만 아니라 환경, 사회 및 거버넌스 설정을 위한 시뮬레이션 솔루션을 \n제공\nSymphony \nAyasdiAI\n•\n사기 활동을 탐지하고 자금 세탁 방지 프로세스를 지원할 수 있는 클라우드 기반 \n',
#   'contextualized_content': '해외 금융업 AI 기술 기업 중 신용평가 및 리스크 관리 분야에 활용되는 기업 목록입니다. \n'},
#  {'doc_id': 'doc_21',
#   'chunk_id': 'doc_21_chunk_4',
#   'chunk_content': "뮬레이션 솔루션을 \n제공\nSymphony \nAyasdiAI\n•\n사기 활동을 탐지하고 자금 세탁 방지 프로세스를 지원할 수 있는 클라우드 기반 \n머신 인텔리전스 솔루션을 개발\nJumio\n•\n'KYX’ 플랫폼 기반 안면 인식으로 고객 신원을 확인하고, 고객이 금융 규정을 \n준수하는지 확인하며지속적으로 리스크를 평가\n개인맞춤형 \n뱅킹 서비스\nSoFi\n•\n지능형 챗봇 기능으로 소비자 및 중소기업 대상 예금 및 저축 계좌, 대출,  학자금 \n대출 재융자, 신용 점수 인사이트 등의 서비스를 제공\nKasisto\n•\n대화형 AI 플랫폼 KAI 개발하여 고객 맞춤형 재무 서비스를 지원 \nAbe.ai\n•\nGoogle Home, Amazon의 Alexa, 웹 및 모바일과 통합되는 가상 금융 도우미로 \n개인 재무 관리, 지출 및",
#   'contextualized_content': '해외 금융업 AI 기술 기업 목록 중 리스크 관리 분야의 기업 정보입니다. \n'},
#  {'doc_id': 'doc_21',
#   'chunk_id': 'doc_21_chunk_5',
#   'chunk_content': '원 \nAbe.ai\n•\nGoogle Home, Amazon의 Alexa, 웹 및 모바일과 통합되는 가상 금융 도우미로 \n개인 재무 관리, 지출 및 예산 책정 등 서비스 제공\n※ 각 사, 언론종합, 삼일PwC경영연구원\n',
#   'contextualized_content': '해외 금융업 AI 기술 기업 중 개인 맞춤형 뱅킹 서비스를 제공하는 Abe.ai에 대한 설명입니다. \n'},
#  {'doc_id': 'doc_22',
#   'chunk_id': 'doc_22_chunk_1',
#   'chunk_content': "Samil PwC  l  Samil Insight\n21\n1-5. 금융: 국내 기업 AI 적용 사례\nIII. 산업별 비즈니스 AI 활용 현황\n[국내 금융 기업의 AI 적용 사례]\n※ 각 사, 언론종합, 삼일PwC경영연구원\n기업명\nAI 비즈니스 적용 사례\n신한은행\n•\n은행권 최초로 RPA 도입 후 전 영업점으로 확대 시행\n•\n‘AI 활용 완전판매 프로세스’ 시행하여 영업점에 AI 기술 적용 사전 인프라를 구축\n-투자상품 상담 및 판매과정에서 AI 고객 답변 인식, 실시간 AI 상담 분석, full text 자막 구현 등\nAI 기술로 불완전판매 요소를 진단∙분석하고 실시간으로 결과를 직원에게 전송\n•\nAI 음성봇 '쏠리(SOLi)’ 도입(’19) \n•\n자금세탁 위험도 측정모델도입(’20) \n•\nSACP(Shinh",
#   'contextualized_content': '본 텍스트는 삼일PwC 경영연구원에서 발행한 보고서의 "III. 산업별 비즈니스 AI 활용 현황" 섹션 중 "국내 금융 기업의 AI 적용 사례" 부분의 일부입니다. 특히 신한은행의 AI 적용 사례를 설명하는 부분입니다. \n'},
#  {'doc_id': 'doc_22',
#   'chunk_id': 'doc_22_chunk_2',
#   'chunk_content': "으로 결과를 직원에게 전송\n•\nAI 음성봇 '쏠리(SOLi)’ 도입(’19) \n•\n자금세탁 위험도 측정모델도입(’20) \n•\nSACP(Shinhan AI Core Platform) 탑재된 머신러닝 프로세스를 통해 신용평가모형 정교화\n국민은행\n•\n31개 업무에 RPA 적용\n•\n머신러닝 모형 기반의 ‘기업여신 자동심사 지원시스템(Bics : Big data CSS)’을 도입 ('22)\n•\n‘AI 보이스피싱 모니터링 시스템’ 고도화(’22) \n•\n뉴 KB 글로벌(NEW KB Global) AML시스템 도입(’22) \n•\nFCC(Future Contact Center) 챗봇 도입 ('23)\n우리은행\n•\n‘AI 기반 이상거래탐지시스템(AI-FDS) 은행권 최초 상용화(’19) \n•\n글로벌 통합 AML시스템 도입(’2",
#   'contextualized_content': '신한은행의 AI 적용 사례와 국민은행, 우리은행의 AI 적용 사례를 소개하는 부분입니다. \n'},
#  {'doc_id': 'doc_22',
#   'chunk_id': 'doc_22_chunk_3',
#   'chunk_content': " 도입 ('23)\n우리은행\n•\n‘AI 기반 이상거래탐지시스템(AI-FDS) 은행권 최초 상용화(’19) \n•\n글로벌 통합 AML시스템 도입(’20) \n•\nRPA 3단계 확대 시행(’21) \n•\n퇴직연금 상품에 로보어드바이저 업체인 파운트 ‘블루웨일’ 도입(’21) \n•\nAI 상담봇과 챗봇서비스를 포함한 AI 상담 서비스 고도화 (’22)\n하나은행\n•\nAI 기반 이상금융거래탐지시스템(FDS) 도입(’18) \n•\nAI 챗봇 서비스 하이챗봇 전면 개편(’22)\n•\nRPA 프로그램 개발 플랫폼을 구축, ‘1부서 1봇’ 프로젝트 시행(’23)\n•\n‘AML를 위한 머신러닝모형’ 자체 개발(’23) \n•\n파운트투자자문과 퇴직연금 상품의 로보어드바이저 일임서비스 도입 업무협약 체결(’24)\n- 파운트투자자문은 로보어드바이",
#   'contextualized_content': '국내 주요 은행들의 AI 활용 사례 중 우리은행과 하나은행의 사례를 소개하고 있습니다. \n'},
#  {'doc_id': 'doc_22',
#   'chunk_id': 'doc_22_chunk_4',
#   'chunk_content': " 자체 개발(’23) \n•\n파운트투자자문과 퇴직연금 상품의 로보어드바이저 일임서비스 도입 업무협약 체결(’24)\n- 파운트투자자문은 로보어드바이저 기술을 활용해 투자일임/투자자문 서비스를 제공하는 핀테크 \n기업\n한국투자증권\n•\n리서치 부문에 자체개발한 AI 활용 서비스 ‘에어(AIR·AI Research)’를 도입(’20)\n-투자 정보 중 투자자들에게 유용한 뉴스와 기업을 자동으로 분석해 최근 주가 추이, 재무 상황, \n성장성과 수익성, 배당 수준, 동일 업종 내 비교 등 다양한 정보를 리포트로 제공\n•\n개인정보 및 투자성향·투자계획·소득정보 등을 분석해 고객에게 가장 적합한 로보어드바이저\n운용 랩(WRAP) 상품을 추천해주는 서비스 ‘MY AI’ 출시(’24)\nKB증권\n•\n챗GPT 기술 기반의 'KB증권 ",
#   'contextualized_content': '하나은행의 AI 활용 사례와 한국투자증권 및 KB증권의 AI 활용 사례를 소개하는 부분입니다. \n'},
#  {'doc_id': 'doc_22',
#   'chunk_id': 'doc_22_chunk_5',
#   'chunk_content': "장 적합한 로보어드바이저\n운용 랩(WRAP) 상품을 추천해주는 서비스 ‘MY AI’ 출시(’24)\nKB증권\n•\n챗GPT 기술 기반의 'KB증권 GPT’ 출시(’24)\n-종목 랭킹, 리서치센터 추천주, 연금상품 조회 등 서비스 관련 고객 질문에 실시간 응답\n미래에셋증권\n•\n생성형 AI를 활용해 고객별 맞춤 자산관리 정보 제공(’23)\n-네이버의 LLM 하이퍼클로바를 활용한 해외주식 실시간 번역/요약 서비스 고도화 중\n",
#   'contextualized_content': '한국투자증권, KB증권, 미래에셋증권의 AI 활용 사례를 소개합니다. \n'},
#  {'doc_id': 'doc_23',
#   'chunk_id': 'doc_23_chunk_1',
#   'chunk_content': 'Samil PwC  l  Samil Insight\n22\n1-6. 금융: 국내 금융업 AI 기술 기업/스타트업\nIII. 산업별 비즈니스 AI 활용 현황\n\uf06c국내의 경우 대부분 기업들은 송금 및 결제 영역 위주의 비즈니스를 영위 중이나, AI 기반의 빅데이터 분석 \n및 개인화 서비스면에서는 신용평가와 자산관리 영역 중심으로 발전해 나가는 중이다. 국내 금융기관들이 \n좀더 고차원적 금융서비스를 위해 관심을 가질만한 금융업 AI기술기업은 다음과 같다.\n[국내 금융업 AI 기술 기업]\n※ 각 사, 언론종합, 삼일PwC경영연구원\n구분\n기업명\n상세\n신용평가/\n대출\n핀다\n•\n국내 핀테크 기업 중 최초로 AI를 도입하여 핀다 전용 챗GPT인 ‘핀다GPT’를 \n개발, 대출 중개 및 관리 서비스 제공\n어니스트펀드\n•\n대출 관련 ',
# ...
#  {'doc_id': 'doc_63',
#   'chunk_id': 'doc_63_chunk_4',
#   'chunk_content': '\n•\n자동화, 배송 추적 및 모니터링기능에 활용 중\n•\n물류 프로세스의 완전 자동화 및 지능화를 위해 AI 로봇 도입 \n활발\n관광\n개인화\n고객 경험\n•\n아직 디지털화 수준이 낮은 편으로, 데이터 수집및챗봇 \n서비스 중심으로 활용되는 중\n•\n여행자 맞춤 예약 및 일정 생성 서비스 본격 출시\n뷰티\n개인화\n고객 경험\n•\n피부 진단및챗봇 서비스 중심으로 활용 중\n•\nAI 기반 개인 맞춤형 서비스 개발 중\n미디어\n비용 절감\n고객 경험\n•\n데이터 분석 기반 맞춤형 콘텐츠 추천 기능 및 콘텐츠 제작 \n기능 중심으로 활용 중\n•\n생성형 AI 기반 광고, 게임콘텐츠 등 본격 출시\n법률\n효율화\n고객 경험\n•\n행정 업무 및 서류 검토 자동화 중심으로 활용 증\n•\n각종 문서 작성 및 고객 응대 서비스를 위해 AI 활용 검토 단계',
#   'contextualized_content': "본 텍스트는 문서 내 '산업별 AI 도입 및 활용 수준' 표의 '물류', '관광', '뷰티', '미디어', '법률' 산업에 대한 AI 도입 및 활용 현황을 설명하는 부분입니다. \n"},
#  {'doc_id': 'doc_63',
#   'chunk_id': 'doc_63_chunk_5',
#   'chunk_content': '률\n효율화\n고객 경험\n•\n행정 업무 및 서류 검토 자동화 중심으로 활용 증\n•\n각종 문서 작성 및 고객 응대 서비스를 위해 AI 활용 검토 단계\n*각 산업별 ’AI 도입 및 활용 수준’은 타 산업 대비 상대적 비교 기준\n신약개발\n기타 의료\n산업 전반 \nAI 활용 수준 下 \n자동화/챗봇\n맞춤 서비스\n전체 평균 AI 도입 수준 \n',
#   'contextualized_content': '본 텍스트 조각은 문서의 "산업별 AI 도입 및 활용 수준" 표의 "법률" 산업에 대한 설명입니다.  AI 활용 현황 진단 부분으로, 행정 업무 자동화와 고객 응대 서비스를 위한 AI 활용 검토 단계임을 보여줍니다. \n'},
#  {'doc_id': 'doc_64',
#   'chunk_id': 'doc_64_chunk_1',
#   'chunk_content': 'Samil PwC  l  Samil Insight\n63\n2. 시사점: 글로벌 활용 사례와의 비교\nIV. 결론: 시사점\n\uf06c국내 AI 활용 수준은 해외 대비 상대적으로 낮아 가시적 성과가 미미한 상황이다. 이는 인력, 공유 데이터,\n플랫폼 인프라,투자,정책적 지원 등이 부족하여 산업내 AI활성화가 더딘 것에 기인한 것으로 판단된다.\n\uf06c제조업 강국임에도 불구, 국내 제조 산업의 보수적인 특성과 전문 인력에 대한 높은 의존도로 인해 AI\n활용도가 아직 낮은 편으로 지속적인 글로벌 경쟁력을 확보하기 위해서는 관련 산업종사자들의 문제의식 \n및 적극적인 변화의 움직임이 필요해 보인다. 금융, 물류, 미디어, 법률 산업 또한 해외 대비 격차가 \n상대적으로 뚜렷한 편으로 서비스 부문에서도 변화가 절실한 상황이다.\n[산업별 ',
#   'contextualized_content': '본 텍스트는  "Samil PwC l Samil Insight" 보고서의 63페이지에 위치하며, 국내 AI 활용 수준이 해외에 비해 낮은 현황과 그 이유에 대한 분석을 제시하고 있습니다. 특히, 제조, 금융, 물류, 미디어, 법률 등 주요 산업 분야에서 AI 활용 수준이 낮은 이유와 개선 방향을 제시합니다. \n'},
#  {'doc_id': 'doc_64',
#   'chunk_id': 'doc_64_chunk_2',
#   'chunk_content': '인다. 금융, 물류, 미디어, 법률 산업 또한 해외 대비 격차가 \n상대적으로 뚜렷한 편으로 서비스 부문에서도 변화가 절실한 상황이다.\n[산업별 글로벌/국내 AI 활용 현황]\n산업\n국내 AI 활용 현황\n글로벌 AI 활용 현황\n▲ 금융\n•\nRPA, 챗봇 등 기본 운영 관리 효율화 중심으로 AI 활용 중\n•\nAI 기업들은 개인화 서비스(신용평가 산정 등) 및 금융 \n리스크 관리용 서비스 개발 중\n•\n운영 효율화를 넘어 고객 접점 구축 및 맞춤형 금융 \n서비스 제공을 위해 AI 적극 활용 중 \n•\nAI 기업들은 송금 및 결제 위주의 서비스 제공 중이나 \n개인화 서비스도 점차 개발 중 \n헬스케어\n•\nMOU 형태의 협업 방식으로 AI 기반 신약 후보 물질 탐색 \n및 임상 데이터 분석 수준\n•\n1세대 AI 기업들은 질병',
#   'contextualized_content': '본 텍스트는 국내 AI 활용 수준이 해외 대비 낮다는 점을 지적하며, 특히 금융, 물류, 미디어, 법률 산업에서의 격차가 크다는 것을 강조한다. 이어서 산업별 글로벌/국내 AI 활용 현황을 비교 분석하는 표가 제시되며, 해당 텍스트는 그 표의 첫 부분으로 금융, 헬스케어 산업의 국내외 현황을 보여준다. \n'},
#  {'doc_id': 'doc_64',
#   'chunk_id': 'doc_64_chunk_3',
#   'chunk_content': ' 개발 중 \n헬스케어\n•\nMOU 형태의 협업 방식으로 AI 기반 신약 후보 물질 탐색 \n및 임상 데이터 분석 수준\n•\n1세대 AI 기업들은 질병 진단 및 판독 보조 등 서비스 \n제공 중. 신약 개발 서비스 성장세 유망\n•\nAI 기업 인수및 플랫폼 기업 협업을 통해 신약 개발, \n임상 실험, 생산 등을 가속화 중\n•\nAI 기업들은 빅파마들의 신약 개발 과정에 적극 기여. \n데이터및 영상 분석/진단 서비스 개발 중\n▲\n제\n조\n자동차\n•\nAI를 제대로 활용하고 있는 국내 기업은 현대차가 대표적; \nAI 기반 설계-생산-서비스 체계 구축하고자 함\n•\n최첨단 AI 기술(디지털 트윈, 로봇 등)을 도입하여 제조 \n효율화 추진. 생성형 AI로 차량내 SW 기능 고도화 중\n화학\n•\nRPA, 실시간 모니터링, 데이터 수집 ',
#   'contextualized_content': '본 텍스트는 국내 AI 활용 현황을 산업별로 분석한 표의 일부분으로, 헬스케어, 제조 (자동차 및 화학) 분야의 국내 AI 활용 현황을 보여줍니다. \n'},
#  {'doc_id': 'doc_64',
#   'chunk_id': 'doc_64_chunk_4',
#   'chunk_content': ' 트윈, 로봇 등)을 도입하여 제조 \n효율화 추진. 생성형 AI로 차량내 SW 기능 고도화 중\n화학\n•\nRPA, 실시간 모니터링, 데이터 수집 등 운영 관리 \n중심으로 AI 활용 중. 품질 개선 및 생산 공정 효율화를 \n위한 AI 활용은 해외 대비 다소 늦은 편\n•\n생산 공정 프로세스 중심으로 AI를 적극 활용하여사고 \n방지, 에너지 감축 등 실현 중이며 AI 기반 R&D도 추진 중\n농업\n•\n정부 ‘27년까지 농업 생산의 30% 스마트 농업으로 \n전환 목표 설정. AI 기업들은 AI 기반 모니터링, 작물 이상 \n유무 분석, 로봇 서비스 등 개발 중\n•\nAI 스타트업은 물론 빅테크까지 합세하여 AI 기반 작물 \n데이터 수집/분석 플랫폼, 제초제 살포, 자원 최적화, 로봇 \n서비스 등 개발 중\n▲ 물류\n•\nAI',
#   'contextualized_content': '본 텍스트는 한국과 해외의 제조, 화학, 농업, 물류 산업에서 인공지능(AI) 활용 현황을 비교 분석한 내용입니다. \n'},
#  {'doc_id': 'doc_64',
#   'chunk_id': 'doc_64_chunk_5',
#   'chunk_content': ' 물론 빅테크까지 합세하여 AI 기반 작물 \n데이터 수집/분석 플랫폼, 제초제 살포, 자원 최적화, 로봇 \n서비스 등 개발 중\n▲ 물류\n•\nAI 적용을 위한 실증 데이터가 부족하여 시스템 구축이 \n더딘 편, 유통 분야 중심으로 AI 활용 중\n•\nAI 스타트업과 더불어 국내 IT 서비스 기업들이 국내 \n스마트 물류 시장 공략 중\n•\n다양한 업무 영역에 AI를 도입하여 물류 운송의 생산성 \n향상 및 원가 절감을 실현 중\n•\nAI 기업들은 AI 기반 운영 관리 시스템은 물론 물류 자동\n화를 위한 로봇 및 드론까지 개발 중\n관광\n•\nAI 기반 업무 효율화 체계 구축 중이며, 생성형 AI를 \n도입해 예약, 일정 생성 등 다양한 서비스 제공 중 \n•\n빅테크의 IT 인프라를 활용하여 업무 효율화를 조기에 \n달성. 생성형',
#   'contextualized_content': '본문은 농업과 물류, 관광 산업에서 국내와 글로벌 AI 활용 현황을 비교 분석하는 내용입니다. 특히 농업 분야에서는 AI 기반 작물 데이터 수집, 제초제 살포, 자원 최적화 등 다양한 분야에서 활용되고 있으며, 빅테크 기업들의 참여가 증가하고 있다는 내용을 담고 있습니다. \n'},
#  {'doc_id': 'doc_64',
#   'chunk_id': 'doc_64_chunk_6',
#   'chunk_content': ' 생성형 AI를 \n도입해 예약, 일정 생성 등 다양한 서비스 제공 중 \n•\n빅테크의 IT 인프라를 활용하여 업무 효율화를 조기에 \n달성. 생성형 AI를 통해 맞춤형 여행 생성 서비스 출시 중\n뷰티\n•\n고객 친화 서비스, 소비자들의 맞춤형 제품에 대한 인식 \n부족 등으로 AI 기반 맞춤형 뷰티 서비스는 아직 초기 단계\n•\nAI를 활용해 화장품 제작 및 판매하는 업체 증가 중. \n온라인 피부진단 및 데이터 중심의 맞춤 서비스를 강화 중\n▲ 미디어\n•\nAI 기술 및 인력 수준은 초기 단계, AI에 대한 투자 여력 \n부족한 편으로 해외 대비 활용도 낮음\n•\nAI 기반 빅데이터 분석, 킬러 콘텐츠 제작, 콘텐츠 추천, \n버추얼 프로덕션 등으로 비용 절감 실현\n▲법률\n•\nAI 기술 도입 및 활용 촉진을 위한 정책적 지',
#   'contextualized_content': '본 텍스트는 한국의 AI 활용 현황을 산업별로 분석한 내용이며, 해당 부분은 관광, 뷰티, 미디어, 법률 산업에서의 AI 활용 현황을 비교 분석하여 국내 현황이 해외 대비 낮은 수준임을 설명하고 있습니다. \n'},
#  {'doc_id': 'doc_64',
#   'chunk_id': 'doc_64_chunk_7',
#   'chunk_content': '터 분석, 킬러 콘텐츠 제작, 콘텐츠 추천, \n버추얼 프로덕션 등으로 비용 절감 실현\n▲법률\n•\nAI 기술 도입 및 활용 촉진을 위한 정책적 지원이 \n부족하여 리걸테크발전 동력이 부재한 상황\n•\n로펌 업무 효율화, 고객 대응 개선, 매출 증대 등을 위해 \n문서 검토 및 분석 자동화, 정밀 실사, 규정 준수 등에 AI \n기술 적극활용 중\n▲: 해외 대비 국내 경쟁력 ↓ 산업\n',
#   'contextualized_content': "본 문서의 2장 '시사점: 글로벌 활용 사례와의 비교'의 [산업별 글로벌/국내 AI 활용 현황] 테이블 내 미디어 및 법률 산업의 AI 활용 현황을 보여주는 부분입니다. \n"},
#  {'doc_id': 'doc_65',
#   'chunk_id': 'doc_65_chunk_1',
#   'chunk_content': 'Samil PwC  l  Samil Insight\n64\n3. 시사점: 정부와 산업/기업에 대한 제언\nIV. 결론: 시사점\n\uf06c국내외 AI의 도입.활용에 대한 산업별(기업) 현황에 대해 살펴본 결과, 산업과 기업의 노력 뿐 아니라 정부 \n차원의 정책 및 인프라에 대한 적극적인 역할이 요구된다.\n구분\n시사점 및 제언\n산업\n\uf06c대부분 산업 분야에서 AI를 도입하였으나, 기업의 비즈니스와조직∙운영∙생산 프로세스에 맞춰 \n얼마나 발전하고 적용됐는지를 봤을때 산업 통틀어 AI 활용 수준은 아직 초기 단계\n\uf0a7\n현재 업무 자동화(RPA)와고객 응대를 위한 챗봇 중심으로 AI가 가장 많이 적용되고 있는 것으로 \n파악되며, 산업별 특화된 기능을 수행하기 위한 AI 활용도는 전반적으로 ‘개발’ 또는 ‘파일럿’ 단계   \n\uf06c자산을 ',
#   'contextualized_content': '본 텍스트는 국내외 AI 도입 및 활용 현황을 분석하여 산업, 기업, 정부 차원의 시사점 및 제언을 제시하는 보고서의 일부입니다. 특히, 산업별 AI 도입 현황과 더불어 AI 활용 수준이 아직 초기 단계임을 강조하며 자산 데이터화 가능성, 생성형 AI 활용, 그리고 산업별 특징에 따른 AI 활용 전략을 제시하는 부분입니다. \n'},
#  {'doc_id': 'doc_65',
#   'chunk_id': 'doc_65_chunk_2',
#   'chunk_content': '이 적용되고 있는 것으로 \n파악되며, 산업별 특화된 기능을 수행하기 위한 AI 활용도는 전반적으로 ‘개발’ 또는 ‘파일럿’ 단계   \n\uf06c자산을 ‘데이터화’할 수 있는 산업이 초기 AI 경쟁력을 가질 것으로 판단되며, ‘창작’을 기반으로 \n비즈니스를 영위하는 산업은 생성형 AI를 통한 경제적 이득이 상당할 것\n\uf0a7\n상대적으로 AI 도입률이 높은 금융 및 IT 산업의 경우 기존에 보유하고 있는 데이터 규모가 방대하여 \nAI 모델을 통한 비즈니스 혁신이 용이. 현재 도입 초기 단계인 법률 산업의 경우 판례 등 데이터화가 \n가능해진다면 AI를 통한 성장세 상당할 것으로 예상\n\uf0a7\n헬스케어 산업의 경우 안전성과 더불어 의료 데이터 활용 및 권한을 둘러싼 규제적 제한으로 인해 AI \n기반 혁신이 더딘 상황이며, 제조 산업',
#   'contextualized_content': '본 텍스트는 국내외 AI 도입 및 활용 현황에 대한 산업별 분석 결과를 바탕으로 산업의 AI 활용 수준과 전망에 대한 시사점 및 제언을 제시하고 있습니다. \n'},
#  {'doc_id': 'doc_65',
#   'chunk_id': 'doc_65_chunk_3',
#   'chunk_content': '\uf0a7\n헬스케어 산업의 경우 안전성과 더불어 의료 데이터 활용 및 권한을 둘러싼 규제적 제한으로 인해 AI \n기반 혁신이 더딘 상황이며, 제조 산업 역시 인력의 전문성에 의존하는 업계 특성상 데이터화가 \n상당히 어려운 편으로이에대한 방안이 절실\n\uf0a7\n콘텐츠 창작을 기반으로 하는 미디어/광고 산업은 이미 비용 절감 효과를 보고 있는 한편, 생성형 AI \n적용에 따른 경쟁이 심화되어 차별화된 콘텐츠 생성 전략이 필요할 것\n기업\n\uf06c너도나도 생성형 AI 도입 중, 더 이상 AI 도입만으로는 비즈니스 차별화를 실현하기 어려움\n\uf0a7\n오픈소스 커뮤니티, 구독 서비스, 거래 기반 서비스 등 기업들은 AI 기술에 접근할 수 있는 방법에 대해 \n그 어느 때보다 더 많은 선택권을 갖게 되었음. 수많은 AI 기술 중에서도 모방이 어렵거',
#   'contextualized_content': '본 텍스트는 산업별 AI 도입 및 활용 현황에 대한 분석 결과를 바탕으로, 헬스케어, 제조, 미디어/광고 산업의 AI 도입 현황과 미래 전망을 제시하고, 기업들이 AI 도입을 통해 비즈니스 차별화를 달성하기 위한 전략을 강조하는 부분입니다. \n'},
#  {'doc_id': 'doc_65',
#   'chunk_id': 'doc_65_chunk_4',
#   'chunk_content': '등 기업들은 AI 기술에 접근할 수 있는 방법에 대해 \n그 어느 때보다 더 많은 선택권을 갖게 되었음. 수많은 AI 기술 중에서도 모방이 어렵거나 비공개 자원, \n상업적 사례등을 고려하여 비즈니스에 직접적인 영향을 미칠 수 있는 AI를 선별하여 도입해야\n\uf06c다만, 대부분 기업의 전반적인 AI 성숙도는 초기 단계에 머물러 있어 선도적인 기업을 제외한 \n모든 기업의 비즈니스 성과에 상당한 영향을 미치기까지는 많은 시간이 걸릴 전망\n\uf0a7\n성공적인 AI 기반 비즈니스 운영을 위해서는 DevOps 엔지니어, IT 전문가 등 내부 생성형 AI 조직 \n구축과 함께 대규모언어모델(LLM)을 안정적으로 개발, 배포및 관리하는 LLMOps(LLM + \nOperations) 기능을  내부적으로 구현하는 것을 우선시해야\n\uf06c해외 대비',
#   'contextualized_content': '기업들이 AI 기술 도입에 있어 다양한 선택권을 갖게 되었지만, 대부분 기업의 AI 성숙도는 초기 단계이며, 성공적인 AI 기반 비즈니스 운영을 위해서는 내부 AI 조직 구축과 LLMOps 기능 구현이 필요하다는 내용입니다. \n'},
#  {'doc_id': 'doc_65',
#   'chunk_id': 'doc_65_chunk_5',
#   'chunk_content': 'M)을 안정적으로 개발, 배포및 관리하는 LLMOps(LLM + \nOperations) 기능을  내부적으로 구현하는 것을 우선시해야\n\uf06c해외 대비 국내 기업들의 생성형 AI 도입이늦은 편. AI 전문 인력, IT 인프라 등에 대한 준비 \n부족으로 AI 기반 비즈니스 활성화를 위한 투자와 M&A가 적극적이지 않은 상황\n\uf0a7\n조사에 따르면 국내 기업은 생성형 AI 도입에 대해 인력(68%), 리스크·거버넌스(67%), IT \n인프라(66%), 전략(34%) 순으로 준비가 부족 (Deloitte, CIO Summit 2024)\n정부\n\uf06c인프라 강화를 위한 정책적 지원: 국내 슈퍼컴퓨터(HPC), 클라우드, 데이터센터 등 인프라가 \n해외 대비 크게 뒤처져 있는 상황\n\uf0a7\n국내 HPC 역량은 미국, 일본, 중국 등 주요 선',
#   'contextualized_content': '기업의 생성형 AI 도입 현황과 국내 기업들의 AI 활용 준비 부족, 그리고 정부 차원의 인프라 강화 및 법/제도 개선 필요성에 대한 내용입니다. \n'},
#  {'doc_id': 'doc_65',
#   'chunk_id': 'doc_65_chunk_6',
#   'chunk_content': '퍼컴퓨터(HPC), 클라우드, 데이터센터 등 인프라가 \n해외 대비 크게 뒤처져 있는 상황\n\uf0a7\n국내 HPC 역량은 미국, 일본, 중국 등 주요 선진국 대비 하위 수준이며, 클라우드 역시 서비스형 \n인프라(IaaS) 및서비스형 플랫폼(PaaS) 분야 원천 기술력이 취약\n\uf06c법/제도의 정비: 개인정보보호법과신용정보법의 규제 완화를 통해 생성형 AI 기업들의 데이터 \n활용 및 기술 개발 활동을 활성화시켜야\n\uf0a7\n엄격한 개인정보 보호 정책으로 인해 AI 기반 개인화된 맞춤형 서비스 창출이 어려운 상황으로, \n산업별 질 좋은 공공 데이터 개방을 허용하는 환경을 조성할 필요\n',
#   'contextualized_content': '정부 차원의 시사점 및 제언 중, 인프라 강화 및 법/제도 정비 필요성에 대한 구체적인 내용입니다. \n'},
#  {'doc_id': 'doc_66',
#   'chunk_id': 'doc_66_chunk_1',
#   'chunk_content': 'Samil PwC  l  Samil Insight\n65\nAuthor Contacts\n삼일PwC경영연구원 \n최형원 책임연구원\nhyungwon.choi@pwc.com\n이은영상무\neunyoung.lee@pwc.com\n삼일PwC Business Research Center\n최재영 원장\njaeyoung.j.choi@pwc.com\n',
#   'contextualized_content': '이것은 보고서의 저자 연락처 정보입니다. \n'},
#  {'doc_id': 'doc_67',
#   'chunk_id': 'doc_67_chunk_1',
#   'chunk_content': 'Samil PwC  l  Samil Insight\n66\nBusiness Contacts\nTechnology (Hardware) Sector\nAssurance\nTax\nDeals\n남 상 우 Partner\n정 재 국 Partner\n소 주 현 Partner\n최 창 대 Partner\nsang-woo.nam@pwc.com\njae-kook.jung@pwc.com\nso.juhyun@pwc.com\nchang-dae.choi@pwc.com\nPlatform (Software) Sector\nAssurance\nTax\nDeals\n한 종 엽 Partner\n이 재 혁 Partner\n김 광 수 Partner\n이 도 신 Partner\njongyup.han@pwc.com\njae-hyuk.lee@pwc.com\nkwang.soo.kim@pwc.',
#   'contextualized_content': '삼일 PwC의 기술(하드웨어) 부문 사업 연락처 목록의 일부입니다. \n'},
#  {'doc_id': 'doc_67',
#   'chunk_id': 'doc_67_chunk_2',
#   'chunk_content': 'artner\n이 도 신 Partner\njongyup.han@pwc.com\njae-hyuk.lee@pwc.com\nkwang.soo.kim@pwc.com\ndo-shin.lee@pwc.com\nTelecom Sector\nAssurance\nTax\nDeals\n한 호 성 Partner\n박 기 운 Partner\n홍 성 표 Partner\nhosung.han@pwc.com\nki-un.park@pwc.com\nsungpyo.hong@pwc.com\nConsumer Markets Sector\nAssurance\nTax\nDeals\n이 승 환 Partner\n오 종 진 Partner\n허 윤 제 Partner\n최 창 윤 Partner\nseung-whan.lee@pwc.com\njong-jin.oh@pwc.com\nyun-je.heo@pwc.co',
#   'contextualized_content': '플랫폼(소프트웨어) 부문 파트너 정보와 통신 부문 파트너 정보 사이에 위치합니다. \n'},
#  {'doc_id': 'doc_67',
#   'chunk_id': 'doc_67_chunk_3',
#   'chunk_content': 'rtner\n최 창 윤 Partner\nseung-whan.lee@pwc.com\njong-jin.oh@pwc.com\nyun-je.heo@pwc.com\nchang-yoon.choi@pwc.com\n박 영 규 Partner\nyoung-gyu.park@pwc.com\nRetail Sector (Omni Channel)\nAssurance\nTax\nDeals\nIFS\n임 영 빈 Partner\n허 윤 제  Partner\n김 준 혁 Partner\n김 동 환 Partner\nyoung-bin.yim@pwc.com\nyun-je.heo@pwc.com\njun-hyouk.kim@pwc.com\ndong-hwan.kim@pwc.com\nHealthcare Sector\nAssurance\nTax\nDeals\n서 용 범 Partner\n금 창 훈 Part',
#   'contextualized_content': '소비재 시장 부문 파트너와 연락처 정보가 담긴 부분입니다. \n'},
#  {'doc_id': 'doc_67',
#   'chunk_id': 'doc_67_chunk_4',
#   'chunk_content': '-hwan.kim@pwc.com\nHealthcare Sector\nAssurance\nTax\nDeals\n서 용 범 Partner\n금 창 훈 Partners\n윤 창 범 Partner\nyongbeom.seo@pwc.com\nchang-hun.keum@pwc.com\nchang-beom.yoon@pwc.com\nBanking, Card, Fintech Sector\nAssurance\nTax\nDeals\n유 엽 Partner\n박 수 연 Partner\n홍 영 관 \nyeob.yu@pwc.com\nsoo-yun.park@pwc.com\nyoung-kwan.hong@pwc.com\nInsurance Sector\nAssurance\nTax\nDeals\n이 유 진 Partner\n진 봉 재 Partner\n박 수 연 Partner\n김 병 국 Part',
#   'contextualized_content': '보험, 금융, 헬스케어 부문 파트너 연락처 정보입니다. \n'},
#  {'doc_id': 'doc_67',
#   'chunk_id': 'doc_67_chunk_5',
#   'chunk_content': ' Sector\nAssurance\nTax\nDeals\n이 유 진 Partner\n진 봉 재 Partner\n박 수 연 Partner\n김 병 국 Partner\neu-gene.lee@pwc.com\nbong-jae.jin@pwc.com\nsoo-yun.park@pwc.com\nbyungguk.kim@pwc.com\n',
#   'contextualized_content': '보험 부문(Insurance Sector) 파트너 연락처 정보입니다. \n'},
#  {'doc_id': 'doc_68',
#   'chunk_id': 'doc_68_chunk_1',
#   'chunk_content': 'Samil PwC  l  Samil Insight\n67\nBusiness Contacts\nSecurities, Asset Management, Capital Sector\nAssurance\nTax\nDeals\n진 선 근 Partner\n박 태 진 Partner\n김 기 은 Partner\nsungeun.jin@pwc.com\ntaejin.park@pwc.com\ngee-eun.kim@pwc.com\nEngineering& Construction Sector\nAssurance\nTax\nDeals\n전 상 범 Partner\n정 양 수 Partner\n김 홍 현 Partner\n김 재 운 Partner\nsangbum.jeon@pwc.com\nyang-soo.jeong@pwc.com\nhong-hyeon.kim@pwc.com\njae-un.k',
#   'contextualized_content': '본 텍스트는 삼일 PwC 사업 연락처 정보에서 **증권, 자산운용, 자본 시장 부문**과 **엔지니어링 및 건설 부문**의 담당 파트너 정보를 보여줍니다. \n'},
#  {'doc_id': 'doc_68',
#   'chunk_id': 'doc_68_chunk_2',
#   'chunk_content': 'tner\nsangbum.jeon@pwc.com\nyang-soo.jeong@pwc.com\nhong-hyeon.kim@pwc.com\njae-un.kim@pwc.com\nShipbuildingSector\nAssurance\nTax\nDeals\n주 대 현 Partner\n정 양 수 Partner\n박 기 운 Partner\n홍 석 형 Partner\ndaehyun.jou@pwc.com\nyang-soo.jeong@pwc.com\nki-un.park@pwc.com\nseok-hyoung.hong@pwc.com\nMobility(Hardware)Sector\nAssurance\nTax\nDeals\n신 승 일 Partner\n이정훈 Partner\n이 경 민 Partner\n곽 윤 구 Partner\nseung-il.shin@pwc.com\njeongh',
#   'contextualized_content': '엔지니어링 및 건설 분야 파트너 정보와 조선 분야 파트너 정보 사이에 위치합니다. \n'},
#  {'doc_id': 'doc_68',
#   'chunk_id': 'doc_68_chunk_3',
#   'chunk_content': '승 일 Partner\n이정훈 Partner\n이 경 민 Partner\n곽 윤 구 Partner\nseung-il.shin@pwc.com\njeonghun.lee@pwc.com\nkyungminlee@pwc.com\nyun-goo.kwak@pwc.com\n화학Sector\nAssurance\nTax\nDeals\n이 기 복 Partner\n김 승 훈Partner\n김 찬 규 Partner\n최 창 윤 Partner\nkibok.lee@pwc.com\nseung-hun.kim@pwc.com\nchan-kyu.kim@pwc.com\nchang-yoon.choi@pwc.com\n에너지/유틸리티/자원개발Sector\nAssurance\nTax\nDeals\n백 봉 준 Partner\n김 주 덕 Partner\n한 정 탁 Partner\nbong-jun.baeg',
#   'contextualized_content': '모빌리티(하드웨어) 부문 파트너 및 연락처 정보와 화학, 에너지/유틸리티/자원개발 부문 파트너 및 연락처 정보가 포함되어 있습니다. \n'},
#  {'doc_id': 'doc_68',
#   'chunk_id': 'doc_68_chunk_4',
#   'chunk_content': 'ctor\nAssurance\nTax\nDeals\n백 봉 준 Partner\n김 주 덕 Partner\n한 정 탁 Partner\nbong-jun.baeg@pwc.com\nmichael.kim@pwc.com\njungtak.han@pwc.com\nSteel& MetalsSector\nAssurance\nTax\nDeals\n최 기 혁 Partner\n이 동 복 Partner\n홍 진 오 Partner\ngi-hyuk.choi@pwc.com\ndongbok.lee@pwc.com\njino.hong@pwc.com\nTransportation & Logistics Sector\nAssurance\nTax\nDeals\n원 치 형Partner\n최 기 혁 Partner\n한 규 영 Partner\n박 치 홍 Partner\nchihyung.won@pwc.com\n',
#   'contextualized_content': '에너지/유틸리티/자원개발, 철강 및 금속, 운송 및 물류 부문의 파트너 연락처 정보입니다. \n'},
#  {'doc_id': 'doc_68',
#   'chunk_id': 'doc_68_chunk_5',
#   'chunk_content': 'als\n원 치 형Partner\n최 기 혁 Partner\n한 규 영 Partner\n박 치 홍 Partner\nchihyung.won@pwc.com\ngi-hyuk.choi@pwc.com\nkyu-young.han@pwc.com\nchihong.park@pwc.com\n',
#   'contextualized_content': '운송 및 물류 분야 파트너 연락처 \n'},
#  {'doc_id': 'doc_69',
#   'chunk_id': 'doc_69_chunk_1',
#   'chunk_content': 'www.samil.com\n삼일회계법인의 간행물은 일반적인 정보제공 및 지식전달을 위하여 제작된 것으로, 구체적인 회계이슈나 세무이슈 등에 대한 삼일회계법인의 의견이 아님을 유념하여 주시기 \n바랍니다. 본 간행물의 정보를 이용하여 문제가 발생하는 경우 삼일회계법인은 어떠한 법적 책임도 지지 아니하며, 본 간행물의 정보와 관련하여 의사결정이 필요한 경우에는, \n반드시 삼일회계법인 전문가의 자문 또는 조언을 받으시기 바랍니다.\nS/N: 2405W-RP-026\n© 2024 Samil PricewaterhouseCoopers. All rights reserved. “PricewaterhouseCoopers” refers to Samil PricewaterhouseCoopers or, as the context \nre',
#   'contextualized_content': '삼일회계법인 간행물 이용에 대한 책임 및 법적 고지 사항입니다. \n'},
#  {'doc_id': 'doc_69',
#   'chunk_id': 'doc_69_chunk_2',
#   'chunk_content': 'waterhouseCoopers” refers to Samil PricewaterhouseCoopers or, as the context \nrequires, the PricewaterhouseCoopers global network or other member firms of the network, each of which is a separate and independent legal entity.\n',
#   'contextualized_content': '삼일회계법인의 저작권 정보 및 PricewaterhouseCoopers 네트워크에 대한 설명입니다. \n'}]

# %%
from typing import List, Dict, Tuple
class LLM_Reranker:
    def __init__(self):
        self.client = genai.GenerativeModel(
            model_name = 'gemini-1.5-flash-latest'
        )

    def rerank_results(self, query: str, results: List[Dict], k: int = 5) -> List[Dict]:
        # Prepare the summaries with their indices
        summaries = []
        # print(len(results))

        for i, result in enumerate(results):
            summary = f"[{i}] Document Summary: {result['chunk'][0]['contextualized_content']}"
            summaries.append(summary)
        joined_summaries = "\n\n".join(summaries)
        
        prompt = f"""
        Query: {query}
        You are about to be given a group of documents, each preceded by its index number in square brackets. Your task is to select the only {k} most relevant documents from the list to help us answer the query.
        
        <documents>
        {joined_summaries}
        </documents>

        Output only the indices of {k} most relevant documents in order of relevance, separated by commas, enclosed in XML tags here:
        <relevant_indices>put the numbers of your indices here, seeparted by commas</relevant_indices>
        """
        try:
            try:
                response = self.client.generate_content(
                    contents=prompt,
                    generation_config=genai.GenerationConfig(
                        stop_sequences=["</relevant_indices>"],
                        temperature=0        
                    )
                ).text.strip()
            except:
                time.sleep(60)
                print(f'Time sleep for 1 Minute (Rerank)')
                response = self.client.generate_content(
                        contents=prompt,
                        generation_config=genai.GenerationConfig(
                        stop_sequences=["</relevant_indices>"],
                        temperature=0        
                    )
                ).text.strip()
            # Extract the indices from the response
            indices_str = response
            relevant_indices = []
            for idx in indices_str.split('>')[-1].split(','):
                try:
                    relevant_indices.append(int(idx.strip()))
                except ValueError:
                    continue  # Skip invalid indices
            # print(indices_str)
            # print(relevant_indices)
            # If we didn't get enough valid indices, fall back to the top k by original order
            if len(relevant_indices) == 0:
                relevant_indices = list(range(min(k, len(results))))
            
            # Ensure we don't have out-of-range indices
            relevant_indices = [idx for idx in relevant_indices if idx < len(results)]
            
            # Return the reranked results
            reranked_results = [results[idx] for idx in relevant_indices[:k]]
            # Assign descending relevance scores
            for i, result in enumerate(reranked_results):
                result['relevance_score'] = 100 - i  # Highest score is 100, decreasing by 1 for each rank
            
            return reranked_results
        
        except Exception as e:
            print(f"An error occurred during reranking: {str(e)}")
            # Fall back to returning the top k results without reranking
            return results[:k]

    def retrieve_advanced(
            self, 
            query: str, 
            contextual_db: ContextualVectorDB, 
            es_bm25 = ElasticsearchBM25, 
            k: int = 5, 
            initial_k: int = 50
            ) -> Tuple[List[Dict], str]:
        # Step 1: Get initial results
        # initial_results = db.search(query, k=initial_k)
        initial_results = retrieve_advanced(query=query, db=contextual_db, es_bm25=es_bm25, k=initial_k, semantic_weight=0.5, bm25_weight=0.5)

        # Step 2: Re-rank results
        reranked_results = self.rerank_results(query, initial_results, k=k)
        
        # Step 3: Generate new context string from re-ranked results
        new_context = ""
        for result in reranked_results:
            chunk = result['metadata']
            new_context += f"\n <document> \n {chunk['chunk_heading']}\n\n{chunk['text']} \n </document> \n"
        
        return reranked_results, new_context

    # The answer_query_advanced function remains unchanged
    def answer_query_advanced(self, query: str, db: ContextualVectorDB):
        documents, context = retrieve_advanced(query, db)
        prompt = f"""
        You have been tasked with helping us to answer the following query: 
        <query>
        {query}
        </query>
        You have access to the following documents which are meant to provide context as you answer the query:
        <documents>
        {context}
        </documents>
        Please remain faithful to the underlying context, and only deviate from it if you are 100% sure that you know the answer already. 
        Answer the question now, and avoid providing preamble such as 'Here is the answer', etc
        """
        try:
            response = self.client.generate_content(
                        contents=prompt).text
        except:
            time.sleep(60)
            print(f'Time sleep for 1 Minute')
            response = self.client.generate_content(
                        contents=prompt).text
        return response

# %%
retrieve_results = retrieve_advanced(
    query = "금융권에서 생성형AI가 활용되는 사례에 대해서 설명해줘",
    db = contextual_db, 
    es_bm25=es_bm25,
    k = 50,
    semantic_weight=0.5,
    bm25_weight=0.5)

# %%
retrieve_results
# Out:
# [{'chunk': [{'doc_id': 'doc_2',
#     'chunk_id': 'doc_2_chunk_3',
#     'chunk_content': '계와 가치사슬을 집중 조명하였으며, 10개 산업별로 \n구체적인 비즈니스 활용 사례들을 정리하는 데 중점을 두었다. 특히, 금융분야의 JP 모건 사례,\n헬스케어의 Roche 사례, 화학 분야의 BASF 사례, 물류산업의 DHL 사례는 눈여겨 볼 만 하다.\n생성형 AI 도입이 초기 단계인 만큼, 사례가 제한적인 점, 그리고 적용사례의 성공여부가 아직 \n판명되지 않은 점 등 제약적인 상황이지만 기업들이 어떻게 대응하고 있는지를 소개함으로써 AI의 \n도입을 검토하고 있는 후발주자들에게 길라잡이가 되었으면 한다. 동시에 ‘game changer’로서의 \n생성형 AI로 인해 기업들의 비즈니스 모델이 향후 얼마나 변해 있을지에 대해 이 보고서를 통해서 각자 \n상상을 펼쳐볼 수 있으면 좋겠다.\n들어가며\n',
#     'contextualized_content': '본 보고서는 생성형 AI가 산업별로 어떻게 활용되고 있는지 구체적인 국내외 사례를 통해 분석하고, 그를 통해 기업들이 AI를 도입하는 데 있어 도움을 주는 것을 목표로 합니다. \n'}],
#   'score': 1.0,
#   'from_semantic': True,
#   'from_bm25': True},
#  {'chunk': [{'doc_id': 'doc_9',
#     'chunk_id': 'doc_9_chunk_5',
#     'chunk_content': '클라우드\n컴퓨팅 하드웨어\n',
#     'contextualized_content': 'AI 생태계 내 하드웨어 및 인프라 부분을 설명하는 그림의 맨 아래에 위치하는 부분입니다. \n'}],
#   'score': 0.5,
#   'from_semantic': True,
#   'from_bm25': False},
#  {'chunk': [{'doc_id': 'doc_46',
#     'chunk_id': 'doc_46_chunk_6',
#     'chunk_content': '변수에 대응이 가능하고, 농가의 생산성과 에너지 효율을 극대화\n',
#     'contextualized_content': '크로프트는 AI 기반으로 온실 속 작물을 모니터링할 수 있는 자동 온실 제어 솔루션을 개발했으며, 머신러닝 기반의 작물 모니터링 시스템을 통해 다양한 온실 환경 변수에 대응이 가능하고, 농가의 생산성과 에너지 효율을 극대화한다. \n'}],
#   'score': 0.3333333333333333,
#   'from_semantic': True,
#   'from_bm25': False},
#  {'chunk': [{'doc_id': 'doc_2',
#     'chunk_id': 'doc_2_chunk_4',
#     'chunk_content': '업들의 비즈니스 모델이 향후 얼마나 변해 있을지에 대해 이 보고서를 통해서 각자 \n상상을 펼쳐볼 수 있으면 좋겠다.\n들어가며\n',
#     'contextualized_content': '본 보고서는 생성형 AI가 산업별로 어떻게 활용되어 비즈니스 성과를 창출하는지 구체적인 국내외 사례를 통해 분석하며, 이를 통해 기업들이 생성형 AI 도입을 검토하는 데 도움을 주고자 한다. 특히, 보고서는 생성형 AI로 인해 기업의 비즈니스 모델이 앞으로 얼마나 변화할지에 대한 상상을 펼쳐볼 수 있도록 돕는다. \n'}],
#   'score': 0.25,
#   'from_semantic': True,
#   'from_bm25': True},
#  {'chunk': [{'doc_id': 'doc_53',
#     'chunk_id': 'doc_53_chunk_3',
#     'chunk_content': '42%의 여행자들이 AI가 생성해준 여행 일정을 선호한다고 조사되었다.\n\uf06c현재 AI는 ① 빅데이터 분석 기반의 여행지, 항공 및 호텔 예약과, ② 실시간 정보 탐색을 통한 맞춤 여행 \n일정(타임라인) 제안, 그리고 ③ 여행 경험을 실시간으로 지원(정보 업데이트, 번역 등)하는 챗봇 기능 \n중심으로 집중 활용되고 있다. \n[관광 산업 밸류체인 -AI 적용 예시]\n※ 한국문화관광연구원, 삼일PwC경영연구원\n정보탐색/준비\n예약\n교통수단\n숙박\n• 여행자 과거 데이터 \n수집 및 분석\n• 예약 일정 개인화\n• 호텔 및 항공료 예측 \n분석, 가격 최적화\n• 여행 상품 탐색\n• 실시간 날씨, 로컬 \n행사 등 데이터 분석\n• 맞춤 여행 설계\n• 렌터카 서비스 자동화\n• 택시/차량 호출\n• 맞춤 교통 루트 제공\n• 언어 번역',
#     'contextualized_content': '관광 산업에서 AI가 생성해준 여행 일정에 대한 선호도가 높아짐에 따라, AI는 빅데이터 분석 기반의 예약, 맞춤형 여행 일정 제안, 챗봇 기능 중심으로 활용되고 있다는 내용입니다. \n'}],
#   'score': 0.2,
#   'from_semantic': True,
#   'from_bm25': True},
#  {'chunk': [{'doc_id': 'doc_17',
#     'chunk_id': 'doc_17_chunk_6',
#     'chunk_content': '결함, 오염 또는 불규칙성을 감지하여 고품질의 제품만 출시\n•\n풍미 및 레시피 최적화: 소비자 선호도와 트렌드를 분석하여 음식의 맛과 레시피를 최적화\n•\n레스토랑의 메뉴 맞춤화: 고객의 선호도, 식단 제한, 과거 주문 데이터를 기반으로 메뉴를 개인화, 식사 경험 \n및 고객 만족도 개선\n',
#     'contextualized_content': '푸드테크 산업에서 AI 활용 예시 중 품질 관리, 풍미 및 레시피 최적화, 메뉴 맞춤화에 대한 설명입니다. \n'}],
#   'score': 0.16666666666666666,
#   'from_semantic': True,
#   'from_bm25': False},
#  {'chunk': [{'doc_id': 'doc_27',
#     'chunk_id': 'doc_27_chunk_4',
#     'chunk_content': '반 조기 진단, 환자 \n경험 개선\n이용료\nAI \n솔루션/\n플랫폼\n바이오테크 기업\nAI/클라우드 플랫폼\n신약 \n개발\n고객 세그먼트\n의료 기관\n(병원, 진료소, 약국)\n실험실\n(병원, 진료소)\n의약품, \n진단기기 판매\n제품 구매\n의료 데이터 제공\n',
#     'contextualized_content': '로슈가 AI를 활용하여 신약 개발 및 의료 데이터 기반 사업을 하는 과정에서 여러 파트너와 협력하는 방식을 보여주는 부분입니다. \n'}],
#   'score': 0.14285714285714285,
#   'from_semantic': True,
#   'from_bm25': False},
#  {'chunk': [{'doc_id': 'doc_63',
#     'chunk_id': 'doc_63_chunk_5',
#     'chunk_content': '률\n효율화\n고객 경험\n•\n행정 업무 및 서류 검토 자동화 중심으로 활용 증\n•\n각종 문서 작성 및 고객 응대 서비스를 위해 AI 활용 검토 단계\n*각 산업별 ’AI 도입 및 활용 수준’은 타 산업 대비 상대적 비교 기준\n신약개발\n기타 의료\n산업 전반 \nAI 활용 수준 下 \n자동화/챗봇\n맞춤 서비스\n전체 평균 AI 도입 수준 \n',
#     'contextualized_content': '본 텍스트 조각은 문서의 "산업별 AI 도입 및 활용 수준" 표의 "법률" 산업에 대한 설명입니다.  AI 활용 현황 진단 부분으로, 행정 업무 자동화와 고객 응대 서비스를 위한 AI 활용 검토 단계임을 보여줍니다. \n'}],
#   'score': 0.125,
#   'from_semantic': True,
#   'from_bm25': False},
#  {'chunk': [{'doc_id': 'doc_65',
#     'chunk_id': 'doc_65_chunk_3',
#     'chunk_content': '\uf0a7\n헬스케어 산업의 경우 안전성과 더불어 의료 데이터 활용 및 권한을 둘러싼 규제적 제한으로 인해 AI \n기반 혁신이 더딘 상황이며, 제조 산업 역시 인력의 전문성에 의존하는 업계 특성상 데이터화가 \n상당히 어려운 편으로이에대한 방안이 절실\n\uf0a7\n콘텐츠 창작을 기반으로 하는 미디어/광고 산업은 이미 비용 절감 효과를 보고 있는 한편, 생성형 AI \n적용에 따른 경쟁이 심화되어 차별화된 콘텐츠 생성 전략이 필요할 것\n기업\n\uf06c너도나도 생성형 AI 도입 중, 더 이상 AI 도입만으로는 비즈니스 차별화를 실현하기 어려움\n\uf0a7\n오픈소스 커뮤니티, 구독 서비스, 거래 기반 서비스 등 기업들은 AI 기술에 접근할 수 있는 방법에 대해 \n그 어느 때보다 더 많은 선택권을 갖게 되었음. 수많은 AI 기술 중에서도 모방이 어렵거',
#     'contextualized_content': '본 텍스트는 산업별 AI 도입 및 활용 현황에 대한 분석 결과를 바탕으로, 헬스케어, 제조, 미디어/광고 산업의 AI 도입 현황과 미래 전망을 제시하고, 기업들이 AI 도입을 통해 비즈니스 차별화를 달성하기 위한 전략을 강조하는 부분입니다. \n'}],
#   'score': 0.1111111111111111,
#   'from_semantic': True,
#   'from_bm25': True},
#  {'chunk': [{'doc_id': 'doc_65',
#     'chunk_id': 'doc_65_chunk_4',
#     'chunk_content': '등 기업들은 AI 기술에 접근할 수 있는 방법에 대해 \n그 어느 때보다 더 많은 선택권을 갖게 되었음. 수많은 AI 기술 중에서도 모방이 어렵거나 비공개 자원, \n상업적 사례등을 고려하여 비즈니스에 직접적인 영향을 미칠 수 있는 AI를 선별하여 도입해야\n\uf06c다만, 대부분 기업의 전반적인 AI 성숙도는 초기 단계에 머물러 있어 선도적인 기업을 제외한 \n모든 기업의 비즈니스 성과에 상당한 영향을 미치기까지는 많은 시간이 걸릴 전망\n\uf0a7\n성공적인 AI 기반 비즈니스 운영을 위해서는 DevOps 엔지니어, IT 전문가 등 내부 생성형 AI 조직 \n구축과 함께 대규모언어모델(LLM)을 안정적으로 개발, 배포및 관리하는 LLMOps(LLM + \nOperations) 기능을  내부적으로 구현하는 것을 우선시해야\n\uf06c해외 대비',
#     'contextualized_content': '기업들이 AI 기술 도입에 있어 다양한 선택권을 갖게 되었지만, 대부분 기업의 AI 성숙도는 초기 단계이며, 성공적인 AI 기반 비즈니스 운영을 위해서는 내부 AI 조직 구축과 LLMOps 기능 구현이 필요하다는 내용입니다. \n'}],
#   'score': 0.1,
#   'from_semantic': True,
#   'from_bm25': True},
#  {'chunk': [{'doc_id': 'doc_16',
#     'chunk_id': 'doc_16_chunk_6',
#     'chunk_content': ' 건강하게 생산할 수 있도록 지원\n•\n토양 건강 모니터링: 화학적 토양 분석을 수행하고 누락된 영양소를 정확하게 추정\n•\n농작물 보호: 식물의 상태를 모니터링하여 질병을 발견 및 예측, 잡초를 식별 및 제거\n•\n지능형 살포: 잡초나 해충 방제를 자동화. 농작물의 이력, 토양 상태 또는 작물 유형에 대한 데이터 분석을 \n기반으로 각 밭에 필요한 농약의 양을 계산\n•\n챗봇: 농부와 고객 또는 유통업체 간의 소통 지원(제품에 대한 질문, 주문, 재고 확인 등)\n',
#     'contextualized_content': '본 텍스트는 농업 분야에서 AI 활용 사례를 설명하는 부분입니다. \n'}],
#   'score': 0.09090909090909091,
#   'from_semantic': True,
#   'from_bm25': False},
#  {'chunk': [{'doc_id': 'doc_17',
#     'chunk_id': 'doc_17_chunk_5',
#     'chunk_content': '격, 고객 수요를 분석해 최적의 가격 전략 수립\n•\n재고 관리 및 수요 예측: 수요 패턴, 계절적 변동, 트렌드를 예측하여 재고 수준 최적화 지원\n•\n고객 서비스용 챗봇: 고객 문의를 처리, 즉각적인 지원을 제공, 주문 추적을 지원\n•\n시각적 검색 및 이미지 인식: AI 기반 시각적 검색 기술을 활용하여 고객이 텍스트가 아닌 이미지를 \n사용하여 제품을 검색(자동 제품 태그 지정, 카탈로그 관리 간소화, 검색 정확도 향상 등 기능에 활용)\n푸드테크\n•\n공급망 최적화: 수요를 예측하고 재고를 관리하며 물류를 개선하여 식품 공급망을 최적화\n•\n품질 관리 및 검사: 식품의 결함, 오염 또는 불규칙성을 감지하여 고품질의 제품만 출시\n•\n풍미 및 레시피 최적화: 소비자 선호도와 트렌드를 분석하여 음식의 맛과 레시피를 ',
#     'contextualized_content': '본 텍스트는 리테일 및 이커머스 산업에서 비즈니스 AI가 활용되는 다양한 사례들을 보여주는 문서의 일부입니다. \n'}],
#   'score': 0.08333333333333333,
#   'from_semantic': True,
#   'from_bm25': True},
#  {'chunk': [{'doc_id': 'doc_18',
#     'chunk_id': 'doc_18_chunk_1',
#     'chunk_content': 'Samil PwC  l  Samil Insight\n17\n1-1. 금융: 비즈니스 AI 활용 현황\nIII. 산업별 비즈니스 AI 활용 현황\n\uf06c금융업은 헬스케어,자동차 산업에 이어 AI영향력이 큰 업종 중 하나로,금융권의 수치,재무 등 방대한 정형 \n데이터를 기반으로 강력한 AI비즈니스 창출이 가능한 산업이다.\n\uf06c특히 ① 신속한 고객 문의 대응을 위한 챗봇/상담봇, ② 투자성향, 리스크 수준, 기대 수익률 등 자산관리 및 \n상품추천 정보를 제공하는 로보어드바이저(Robo-advisor), ③ 각종 서류를 자동으로 분석/분류하는 등 \n프로세스를 개선해주는 로봇 프로세스 자동화(Robotic Process Automation, RPA) 기능에 \n금융기관들은 주목하고 있다.\n\uf06c현재 국내외 금융기관들의 생성형 AI 도',
#     'contextualized_content': '본 텍스트는 "Samil PwC l Samil Insight" 보고서의 "III. 산업별 비즈니스 AI 활용 현황" 섹션의 "1-1. 금융: 비즈니스 AI 활용 현황" 부분입니다. 금융 산업에서 AI 적용 현황과 특징을 설명하는 부분입니다. \n'}],
#   'score': 0.07692307692307693,
#   'from_semantic': True,
#   'from_bm25': True},
#  {'chunk': [{'doc_id': 'doc_7',
#     'chunk_id': 'doc_7_chunk_6',
#     'chunk_content': '\n',
#     'contextualized_content': '생성형 AI 비즈니스 생태계 구조를 설명하는 부분에서 공급자 측면의 4가지 영역(컴퓨팅 하드웨어, 클라우드, AI 모델, AI 서비스)을 자세히 소개하고 있다. \n'}],
#   'score': 0.07142857142857142,
#   'from_semantic': True,
#   'from_bm25': False},
#  {'chunk': [{'doc_id': 'doc_63',
#     'chunk_id': 'doc_63_chunk_4',
#     'chunk_content': '\n•\n자동화, 배송 추적 및 모니터링기능에 활용 중\n•\n물류 프로세스의 완전 자동화 및 지능화를 위해 AI 로봇 도입 \n활발\n관광\n개인화\n고객 경험\n•\n아직 디지털화 수준이 낮은 편으로, 데이터 수집및챗봇 \n서비스 중심으로 활용되는 중\n•\n여행자 맞춤 예약 및 일정 생성 서비스 본격 출시\n뷰티\n개인화\n고객 경험\n•\n피부 진단및챗봇 서비스 중심으로 활용 중\n•\nAI 기반 개인 맞춤형 서비스 개발 중\n미디어\n비용 절감\n고객 경험\n•\n데이터 분석 기반 맞춤형 콘텐츠 추천 기능 및 콘텐츠 제작 \n기능 중심으로 활용 중\n•\n생성형 AI 기반 광고, 게임콘텐츠 등 본격 출시\n법률\n효율화\n고객 경험\n•\n행정 업무 및 서류 검토 자동화 중심으로 활용 증\n•\n각종 문서 작성 및 고객 응대 서비스를 위해 AI 활용 검토 단계',
#     'contextualized_content': "본 텍스트는 문서 내 '산업별 AI 도입 및 활용 수준' 표의 '물류', '관광', '뷰티', '미디어', '법률' 산업에 대한 AI 도입 및 활용 현황을 설명하는 부분입니다. \n"}],
#   'score': 0.06666666666666667,
#   'from_semantic': True,
#   'from_bm25': False},
#  {'chunk': [{'doc_id': 'doc_14',
#     'chunk_id': 'doc_14_chunk_1',
#     'chunk_content': 'Samil PwC  l  Samil Insight\n13\n2. 생성형 AI의 비즈니스 도입 현황\nII. 생성형 AI 시장 전망 및 도입 현황: 수요자 측면\n이제부터 기업들은 AI의 본격적 도입 및 수익 창출에 집중\n\uf06c전 산업에 걸쳐 글로벌 800여개 기업(은행, 제약, 공공, 자동차등)의 주요 의사결정권자(CEO, CSO, CFO\n등) 중 75%가 생성형 AI를비즈니스 경쟁 우위와 직결되는 요소로 판단하며 높은 투자의향을 보이고 있다.\n이러한 이유로 향후 선도 기업들의 성공적인 생성형 AI 도입 사례가 전파되면서 도입 속도가 전 산업에 걸쳐 \n크게 증가할 것으로 전망되며, MWC 2024에서 NTT data가 발표한 자료에 따르면 기업들의 생성형 AI\n투자 규모는 연평균 17%증가할 것으로 보고 있다.\n\uf06cAI',
#     'contextualized_content': "본 텍스트는 삼일PwC 경영연구원의 보고서 '생성형 AI의 비즈니스 도입 현황' 중 'II. 생성형 AI 시장 전망 및 도입 현황: 수요자 측면'의 일부분입니다.  특히, 기업들의 생성형 AI 투자 의향이 높다는 것을 설명하는 부분입니다. \n"}],
#   'score': 0.0625,
#   'from_semantic': True,
#   'from_bm25': True},
#  {'chunk': [{'doc_id': 'doc_46',
#     'chunk_id': 'doc_46_chunk_5',
#     'chunk_content': "하여 수확시간을 단축\n컬티랩스\n•\n농장 재배데이터를 수집·분석하는 ‘컬티데이터’, 농장 내 작업정보와 경영정보를 수집·분석하는 \n‘컬티매니저’, 작물생육정보 수집·진단·분석하는 ‘컬티그로스’ 등의 서비스 제공\n스마프\n•\nAI를 통해 농지의 토양 성질을 파악하고, 작물 재배 정보를 실시간 분석해 제떄 필요한 물과 양분의 \n양을 자동 산출하고 공급해주는 '프로타’ 솔루션 개발\n크로프트\n•\nAI를 기반으로 온실 속 작물을 모니터링할 수 있는 자동 온실 제어 솔루션을 개발\n-머신러닝 기반의 작물 모니터링 시스템을 통해 작물 생육 데이터를 확보할 수 있어 다양한 온실 \n환경 변수에 대응이 가능하고, 농가의 생산성과 에너지 효율을 극대화\n",
#     'contextualized_content': '국내 농업 AI 기술 기업 목록 중 컬티랩스, 스마프, 크로프트 기업의 정보를 담고 있습니다. \n'}],
#   'score': 0.058823529411764705,
#   'from_semantic': True,
#   'from_bm25': False},
#  {'chunk': [{'doc_id': 'doc_17',
#     'chunk_id': 'doc_17_chunk_2',
#     'chunk_content': '스 관리: 주문량과 처리 시간 등의 워크로드 데이터를 분석하여 작업자 간의 업무 배분 최적화\n관광/여행\n•\n개인 맞춤형 여정: AI를 통해 개인의 선호도에 따라 맞춤형 여행 일정을 제공\n•\n실시간 여행 업데이트 및 추천: 실시간 업데이트와 위치 및 선호도에 따른 맞춤형 추천을 제공\n•\n챗봇: 예약 과정에서 여행자의 문의 지원, 가격에 대한 세부 정보를 제공하고 옵션을 비교\n•\n스마트한 쇼핑: 여행자가 가격, 평점, 편의시설과 같은 중요한 요소를 손쉽게 비교할 수 있도록 지원\n미디어/\n엔터테인먼트\n•\n음악 추천: 청취 기록, 선호도를 포함한 사용자 데이터를 활용해 장르, 아티스트 등 개인 맞춤형 추천\n•\n게임 디자인: 비플레이어 캐릭터(NPC), 메커니즘 등 개선하여 게임 디자인을 및 사용자 경험 향상\n•\n스',
#     'contextualized_content': '본 텍스트는 "산업별 비즈니스 AI 활용 현황" 문서의 일부이며, 물류 산업에서의 AI 활용 예시와 이어서 관광/여행, 미디어/엔터테인먼트 산업에서의 AI 활용 예시를 소개하고 있습니다. \n'}],
#   'score': 0.05555555555555555,
#   'from_semantic': True,
#   'from_bm25': False},
#  {'chunk': [{'doc_id': 'doc_64',
#     'chunk_id': 'doc_64_chunk_7',
#     'chunk_content': '터 분석, 킬러 콘텐츠 제작, 콘텐츠 추천, \n버추얼 프로덕션 등으로 비용 절감 실현\n▲법률\n•\nAI 기술 도입 및 활용 촉진을 위한 정책적 지원이 \n부족하여 리걸테크발전 동력이 부재한 상황\n•\n로펌 업무 효율화, 고객 대응 개선, 매출 증대 등을 위해 \n문서 검토 및 분석 자동화, 정밀 실사, 규정 준수 등에 AI \n기술 적극활용 중\n▲: 해외 대비 국내 경쟁력 ↓ 산업\n',
#     'contextualized_content': "본 문서의 2장 '시사점: 글로벌 활용 사례와의 비교'의 [산업별 글로벌/국내 AI 활용 현황] 테이블 내 미디어 및 법률 산업의 AI 활용 현황을 보여주는 부분입니다. \n"}],
#   'score': 0.05263157894736842,
#   'from_semantic': True,
#   'from_bm25': False},
#  {'chunk': [{'doc_id': 'doc_46',
#     'chunk_id': 'doc_46_chunk_4',
#     'chunk_content': "정보를 실시간으로 모니터링, 사용자는 \n관제 시스템으로 로봇을 제어할 수 있으며, 수집된 데이터는 시스템내 대시보드로 파악 가능\n에이아이에스\n•\nAI 기반으로 기상, 작물, 토양 등 환경 데이터를 분석해 작물 생육 부진의 원인들을 파악하고 미리 \n예측해 의사 결정을 제공\n에스앤솔루션즈\n•\nAI로 과일 및 채소 수확 적기와 상품성을 높이는 수확법을 학습한 다관절 자율주행 로봇 '로봉이’, \n'따담이’ 개발\n-‘로봉이’는 수확 전 수분량, 당도, 크기 등을 체크하여 농작물 등급을 분류하고데이터를 관제\n센터로 전송. '따담이’는 협업 알고리즘을 통해 최대 효율 경로를 분석하여 수확시간을 단축\n컬티랩스\n•\n농장 재배데이터를 수집·분석하는 ‘컬티데이터’, 농장 내 작업정보와 경영정보를 수집·분석하는 \n‘컬티매니저’,",
#     'contextualized_content': "위 텍스트는 국내 농업 AI 기술 기업들의 활동과 개발 현황을 소개하는 문서 내, '아이오크롭스'라는 기업의 AI 기반 농업 로봇 개발과 관련된 설명 뒤에 이어지는 내용입니다. \n"}],
#   'score': 0.05,
#   'from_semantic': True,
#   'from_bm25': False},
#  {'chunk': [{'doc_id': 'doc_57',
#     'chunk_id': 'doc_57_chunk_5',
#     'chunk_content': '가짜 리뷰 필터링 기술을 활용한 맛집 지도 앱과 교통 시스템 알고리즘을 적용한 오프라인 \n지하철 길찾기 앱 서비스 제공\n시정\n•\n관광지 여행 안전 및 미세 먼지 실시간 정보 서비스 앱‘날갬’ 출시. AI 카메라를 통해 실시간으로 여행지 \n상황을 전달, 실시간 비식별화 기능으로 사용자 프라이버시를 철저히 보호하면서 실시간 여행정보, \n미세먼지 상태, 기상정보 등을 제공하여 스마트한 여행 계획을 지원\n스토리시티\n•\nAI 기반 여행 일정 제작 서비스 ‘여다’ 출시. 맞춤형 여행일정 제작을 위해 이용자의 동행 정보, 여행 \n스타일, 관심사, 숙소 취향 등 8개 분야를 물어보며, 이에 대한 답변을 완료하면3분 내로 고객 맞춤형 \n여행일정을 무료로 제작해 전달\n트리플\n•\nAI 및 빅데이터를 기반으로 국내외 관광지와 맛',
#     'contextualized_content': '본 텍스트는 국내 관광 산업에서 AI 기술을 활용하는 기업과 스타트업의 사례를 소개하는 문서의 일부분으로, NUUA, 시정, 스토리시티, 트리플 등의 기업이 제공하는 AI 기반 서비스를 설명하고 있습니다. \n'}],
#   'score': 0.047619047619047616,
#   'from_semantic': True,
#   'from_bm25': False},
#  {'chunk': [{'doc_id': 'doc_14',
#     'chunk_id': 'doc_14_chunk_3',
#     'chunk_content': '로 예상된다. 동시에 \n각 산업별로는 단순 생성형 AI 도입을 넘어 차별화를 통한 수익화에 대한 깊은 고민이 병행될 것으로 보인다.\n[글로벌 의사결정권자 75% AI 투자 의향 –금융 및 헬스케어 분야 적극적]\n업종\n설문 참여 기업 수\n투자의향 (%)\n은행\n233\n80\n보험\n110\n79\n헬스케어\n96\n77\n제약\n53\n77\n유틸리티\n90\n74\n공공\n138\n72\n자동차\n51\n71\n유통\n85\n65\n합계\n856\n75\n금융기관의 경우 대출심사, 고객 현금흐름 \n분석 등 에 AI 적용하기 시작. 투자 적극적\n헬스케어 및 제약 업종은 신약 개발 소요기간 \n단축을 위해 AI 투자에 적극적\n향후 유틸리티, 자동차, IT, 유통 등에서도 \n생산 효율화 및 자동화를 위한 AI 투자와 도입 \n속도 빨라질 것\n※ NTT data,',
#     'contextualized_content': '생성형 AI 도입 현황과 전망, 글로벌 기업들의 AI 투자 의향 및 주요 업종별 도입 현황을 보여주는 표와 함께 설명하는 부분입니다. \n'}],
#   'score': 0.045454545454545456,
#   'from_semantic': True,
#   'from_bm25': True},
#  {'chunk': [{'doc_id': 'doc_47',
#     'chunk_id': 'doc_47_chunk_5',
#     'chunk_content': '리\n• 프로세스 자동화\n• 로봇/드론 자율주행\n• 실시간 모니터링\n• 상품 분류\n• 항온/항습 시스템\n• 파손 방지 체계\n• 장비 제어\n• 조명 제어\n• 통풍 제어\n• 사물 통신(M2M)\n• 스마트 검수\n• 공간 인지\n• Vision/ voice 피킹\n• 운송 관리\n• 배송 경로 최적화\n• 창고 최적화\n• 스마트 패킹 및 배치\n• 고객 관리(챗봇)\n물류 산업내 AI 활용도 높은 편 \n특히 로봇 제어, 예측 분석 및 재고 관리, 배송 경로 최적화 영역에 집중 \n',
#     'contextualized_content': '본 텍스트는 물류 산업에서의 AI 활용 사례를 보여주는 표의 일부이며, 각 단계(보관, 검수, 피킹, 입고, 출고)에서 어떻게 AI가 적용되는지 구체적인 예시를 제시하고 있습니다. \n'}],
#   'score': 0.043478260869565216,
#   'from_semantic': True,
#   'from_bm25': False},
#  {'chunk': [{'doc_id': 'doc_18',
#     'chunk_id': 'doc_18_chunk_2',
#     'chunk_content': '동화(Robotic Process Automation, RPA) 기능에 \n금융기관들은 주목하고 있다.\n\uf06c현재 국내외 금융기관들의 생성형 AI 도입 및 활용 방향성을 비추어 봤을때 특히 ‘마케팅/영업’과 \n‘고객관리’와 같이 개별 고객에 대한 정밀한 분석 기반의 1대1 맞춤형 서비스가 요구되는 영역을 중심으로 \n보다 고도화된 생성형 AI기술을 활용하고자 하는 니즈가 높아지고 있다.\n[금융 산업 밸류체인 -AI 적용 예시]\n마케팅, 영업\n상품, 서비스\n고객관리\n운영 관리\n리스크 관리\n• 초개인화 고객 분석\n• 시장 분석/예측\n• 원격 지원\n• 잠재 고객 발굴\n• 챗봇\n• 고객 segment별 \n특화된 맞춤상품 추천\n• 신원인식(얼굴, 음성)\n• 컨설팅(투자, 보험, \n절세 등)\n• 금융/비금융 연계 \n종합 플랫',
#     'contextualized_content': '본 문서에서 해당 텍스트는 금융 산업에서 인공지능(AI) 활용 현황을 설명하며, 특히 챗봇, 로보어드바이저, RPA 기능이 주목받고 있음을 강조하는 부분입니다. 이어서 국내외 금융기관들의 AI 도입 현황과 향후 생성형 AI 기술 활용 방향에 대한 설명으로 이어집니다. \n'}],
#   'score': 0.041666666666666664,
#   'from_semantic': True,
#   'from_bm25': True},
#  {'chunk': [{'doc_id': 'doc_64',
#     'chunk_id': 'doc_64_chunk_6',
#     'chunk_content': ' 생성형 AI를 \n도입해 예약, 일정 생성 등 다양한 서비스 제공 중 \n•\n빅테크의 IT 인프라를 활용하여 업무 효율화를 조기에 \n달성. 생성형 AI를 통해 맞춤형 여행 생성 서비스 출시 중\n뷰티\n•\n고객 친화 서비스, 소비자들의 맞춤형 제품에 대한 인식 \n부족 등으로 AI 기반 맞춤형 뷰티 서비스는 아직 초기 단계\n•\nAI를 활용해 화장품 제작 및 판매하는 업체 증가 중. \n온라인 피부진단 및 데이터 중심의 맞춤 서비스를 강화 중\n▲ 미디어\n•\nAI 기술 및 인력 수준은 초기 단계, AI에 대한 투자 여력 \n부족한 편으로 해외 대비 활용도 낮음\n•\nAI 기반 빅데이터 분석, 킬러 콘텐츠 제작, 콘텐츠 추천, \n버추얼 프로덕션 등으로 비용 절감 실현\n▲법률\n•\nAI 기술 도입 및 활용 촉진을 위한 정책적 지',
#     'contextualized_content': '본 텍스트는 한국의 AI 활용 현황을 산업별로 분석한 내용이며, 해당 부분은 관광, 뷰티, 미디어, 법률 산업에서의 AI 활용 현황을 비교 분석하여 국내 현황이 해외 대비 낮은 수준임을 설명하고 있습니다. \n'}],
#   'score': 0.04,
#   'from_semantic': True,
#   'from_bm25': False},
#  {'chunk': [{'doc_id': 'doc_64',
#     'chunk_id': 'doc_64_chunk_1',
#     'chunk_content': 'Samil PwC  l  Samil Insight\n63\n2. 시사점: 글로벌 활용 사례와의 비교\nIV. 결론: 시사점\n\uf06c국내 AI 활용 수준은 해외 대비 상대적으로 낮아 가시적 성과가 미미한 상황이다. 이는 인력, 공유 데이터,\n플랫폼 인프라,투자,정책적 지원 등이 부족하여 산업내 AI활성화가 더딘 것에 기인한 것으로 판단된다.\n\uf06c제조업 강국임에도 불구, 국내 제조 산업의 보수적인 특성과 전문 인력에 대한 높은 의존도로 인해 AI\n활용도가 아직 낮은 편으로 지속적인 글로벌 경쟁력을 확보하기 위해서는 관련 산업종사자들의 문제의식 \n및 적극적인 변화의 움직임이 필요해 보인다. 금융, 물류, 미디어, 법률 산업 또한 해외 대비 격차가 \n상대적으로 뚜렷한 편으로 서비스 부문에서도 변화가 절실한 상황이다.\n[산업별 ',
#     'contextualized_content': '본 텍스트는  "Samil PwC l Samil Insight" 보고서의 63페이지에 위치하며, 국내 AI 활용 수준이 해외에 비해 낮은 현황과 그 이유에 대한 분석을 제시하고 있습니다. 특히, 제조, 금융, 물류, 미디어, 법률 등 주요 산업 분야에서 AI 활용 수준이 낮은 이유와 개선 방향을 제시합니다. \n'}],
#   'score': 0.038461538461538464,
#   'from_semantic': True,
#   'from_bm25': True},
#  {'chunk': [{'doc_id': 'doc_65',
#     'chunk_id': 'doc_65_chunk_2',
#     'chunk_content': '이 적용되고 있는 것으로 \n파악되며, 산업별 특화된 기능을 수행하기 위한 AI 활용도는 전반적으로 ‘개발’ 또는 ‘파일럿’ 단계   \n\uf06c자산을 ‘데이터화’할 수 있는 산업이 초기 AI 경쟁력을 가질 것으로 판단되며, ‘창작’을 기반으로 \n비즈니스를 영위하는 산업은 생성형 AI를 통한 경제적 이득이 상당할 것\n\uf0a7\n상대적으로 AI 도입률이 높은 금융 및 IT 산업의 경우 기존에 보유하고 있는 데이터 규모가 방대하여 \nAI 모델을 통한 비즈니스 혁신이 용이. 현재 도입 초기 단계인 법률 산업의 경우 판례 등 데이터화가 \n가능해진다면 AI를 통한 성장세 상당할 것으로 예상\n\uf0a7\n헬스케어 산업의 경우 안전성과 더불어 의료 데이터 활용 및 권한을 둘러싼 규제적 제한으로 인해 AI \n기반 혁신이 더딘 상황이며, 제조 산업',
#     'contextualized_content': '본 텍스트는 국내외 AI 도입 및 활용 현황에 대한 산업별 분석 결과를 바탕으로 산업의 AI 활용 수준과 전망에 대한 시사점 및 제언을 제시하고 있습니다. \n'}],
#   'score': 0.037037037037037035,
#   'from_semantic': True,
#   'from_bm25': False},
#  {'chunk': [{'doc_id': 'doc_44',
#     'chunk_id': 'doc_44_chunk_3',
#     'chunk_content': ' 특성에 맞게 작물에 대한 생육 및 환경 데이터를 수집·가공·분석 중이며, \n이상 데이터 발생 시 즉시 대처할 수 있도록 실시간 모니터링을 시행\nAppendix 4. 국내 농업 분야 AI∙빅데이터 활용 사례\n[스마트팜 혁신밸리 빅데이터 센터 운영체제]\n※ “빅데이터센터 소개”(김제 스마트팜 혁신밸리 사이트)\n정부기관(농촌진흥청, 농림축산식품부) 주도 비즈니스 사례 \n',
#     'contextualized_content': '농림축산식품부에서 스마트팜 혁신밸리를 조성하여 스마트팜 기술을 실증하고 빅데이터를 수집, 관리하는 과정을 설명하는 부분입니다. \n'}],
#   'score': 0.03571428571428571,
#   'from_semantic': True,
#   'from_bm25': False},
#  {'chunk': [{'doc_id': 'doc_17',
#     'chunk_id': 'doc_17_chunk_4',
#     'chunk_content': '정을 지원\n•\n전자증거개시: 대량의 전자 문서, 이메일, 디지털 증거를 효율적으로 분석, 분류하여 전자증거개시\n•\n위험 평가 및 규정 준수: 법적 위험 식별 및 평가, 규정 준수를 모니터링하며위험 완화 조언 제공\n•\n챗봇 및 가상 비서: 일반적인 법률 문의에 즉각적으로 응답, 법률 절차 지원, 고객과의 소통 개선\n•\n문서 자동화: 법률 문서 작성시 오류 감소, 시간 절약, 문서 일관성 보장, 문서 생성 프로세스 간소화\n리테일 \n이커머스\n•\n개인화된 쇼핑 경험: 고객의 행동, 선호도, 구매 이력을 분석해 맞춤형 상품 제안\n•\n가격 최적화: 실시간 시장 상황, 경쟁사 가격, 고객 수요를 분석해 최적의 가격 전략 수립\n•\n재고 관리 및 수요 예측: 수요 패턴, 계절적 변동, 트렌드를 예측하여 재고 수준 최적화 지',
#     'contextualized_content': '본 텍스트는 문서의 "III. 산업별 비즈니스 AI 활용 현황" 섹션의 "법률"과 "리테일 이커머스" 산업에서 AI가 어떻게 활용되는지 설명하는 부분입니다. \n'}],
#   'score': 0.034482758620689655,
#   'from_semantic': True,
#   'from_bm25': False},
#  {'chunk': [{'doc_id': 'doc_3',
#     'chunk_id': 'doc_3_chunk_1',
#     'chunk_content': 'Contents\nI\n생성형 AI 생태계 구조: 공급자 측면\n3\nII\n생성형 AI 시장 전망 및 도입 현황: 수요자 측면\n10\nIII\n산업별 비즈니스 AI 활용 현황\n10개 산업(금융, 헬스케어, 제조(자동차, 화학) 등)으로 본 AI 활용사례\n14\nIV\n결론: 시사점\n61\n',
#     'contextualized_content': '본 텍스트는 생성형 AI 관련 문서의 목차입니다. \n'}],
#   'score': 0.03333333333333333,
#   'from_semantic': True,
#   'from_bm25': True},
#  {'chunk': [{'doc_id': 'doc_53',
#     'chunk_id': 'doc_53_chunk_4',
#     'chunk_content': '시간 날씨, 로컬 \n행사 등 데이터 분석\n• 맞춤 여행 설계\n• 렌터카 서비스 자동화\n• 택시/차량 호출\n• 맞춤 교통 루트 제공\n• 언어 번역, 챗봇\n• 스마트 객실(자동화)\n• 개인 맞춤형 추천\n• 고객 감정 분석\n체험\n• 실시간 여행 업데이트 \n및 추천\n• 스마트 쇼핑(편의시설, \n가격 등 비교)\n• 가상 여행 경험제공\n빅데이터 기반 항공 및 숙박 예약, 개인 맞춤형 여행 일정 설계, \n실시간 여행 정보 업데이트(챗봇) 중심으로 AI 多 활용 \n[10대 미래 유망관광기술 (한국문화관광연구원 발표 ’24)]\n① 실시간 정보 제공을 위한 생성형 관광 AI 기술\n⑥ 관광객 거래 효율화를 위한 혁신 결제 기술\n② 빅데이터 기반의 관광 디지털 큐레이션 기술\n⑦ 관광객 실감 경험을 확대하는 인터랙티브 기술\n③ 관',
#     'contextualized_content': '관광 산업에서 AI가 어떻게 활용될 수 있는지 보여주는 예시를 담고 있으며, 특히 정보 탐색/준비 단계와 체험 단계에서의 AI 활용 사례와 함께 10대 미래 유망 관광 기술을 소개하고 있다. \n'}],
#   'score': 0.03225806451612903,
#   'from_semantic': True,
#   'from_bm25': False},
#  {'chunk': [{'doc_id': 'doc_63',
#     'chunk_id': 'doc_63_chunk_2',
#     'chunk_content': '한단계 더 성장할 수 있는 여지가 많다. 따라서 산업별 또는 각 \n기업별로 AI기술의 도입 및 활용은 더욱 활발해 질 것으로 예상된다.\n[산업별 AI 도입 및 활용 수준]\n산업\nAI 도입 및 활용 수준*\n주 도입 \n목적\nAI 활용 현황 진단\n低\n高\n금융\n효율화\n고객 경험\n•\nRPA, 챗봇 서비스 중심으로 AI 활용도 높은 편이나\n•\n고객맞춤형 서비스, 사기 탐지, 리스크 대응 등 기타 기능의 AI \n도입 수준은 초기 단계\n헬스케어\n비용 절감\n개인화\n•\n신약개발을 위한 AI 도입은 본격화되었으나\n•\n안전성 및규제로 인해 기타 의료 활동(임상시험, 질병 치료등)\n의 도입 수준은 초기 단계\n제\n조\n자동차\n생산성\n비용 절감\n•\n자동화, 생산 공정 개선 중심으로 활용되는 중\n•\n디자인/설계 영역 중심으로 확대 적용 ',
#     'contextualized_content': '본 텍스트는 산업별 AI 도입 및 활용 수준에 대한 분석 결과를 요약하며, 특히 금융과 헬스케어 산업의 AI 도입 현황을 자세히 설명합니다. 또한, 산업 전반의 AI 활용 수준이 아직 낮지만 향후 AI를 통한 성장 가능성이 높다는 점을 강조합니다. \n'}],
#   'score': 0.03125,
#   'from_semantic': True,
#   'from_bm25': False},
#  {'chunk': [{'doc_id': 'doc_16',
#     'chunk_id': 'doc_16_chunk_4',
#     'chunk_content': '자동차 포함 \n제조 전반)\n•\n결함 감지: 실시간으로 이상 징후와 편차를 신속하게 감지하여 오경보와 수동 검사를 줄임\n•\n조립 라인 통합: 조립 프로세스를 간소화하여 사람의 개입을 최소화, 효율적이고 일관된 생산 보장\n•\n예측 분석: 센서 데이터와 유지보수 기록을 분석하여 다운타임 최소화, 유지보수 비용 절감, 생산 가동 \n시간 최적화\n•\n실시간 모니터링 및 분석: 다양한 소스에서 데이터를 수집하여 생산 라인을 실시간으로 모니터링\n•\n프로세스 최적화: 생산 데이터 기반으로 사이클 시간, 에너지 소비, 자재 사용 등 비효율적인 부분을 파악\n하여 제조 공정을 최적화\n제조(화학)\n•\nR&D 가속화: 분자 발견 및 인식, 공식화 등을 지원하며 R&D 프로세스의 속도 및 정확도 높임\n•\n예측분석: 화학 물질 생산에 ',
#     'contextualized_content': '본 텍스트는 "산업별 비즈니스 AI 활용 현황" 문서의 제조 부분으로 자동차를 포함한 제조 전반과 화학 제조 분야에서 AI가 활용되는 구체적인 사례들을 설명하고 있다. \n'}],
#   'score': 0.030303030303030304,
#   'from_semantic': True,
#   'from_bm25': False},
#  {'chunk': [{'doc_id': 'doc_61',
#     'chunk_id': 'doc_61_chunk_1',
#     'chunk_content': 'Samil PwC  l  Samil Insight\n60\n9. 법률: 비즈니스 AI 활용 현황 및 국내외 사례\nIII. 산업별 비즈니스 AI 활용 현황\n\uf06c법률 부문에서 AI는 일상적인 리스크 및 규정 준수 업무 등을 자동화하고, 고객 문의에 신속히 대응하며,\n문서 작성을 위한 텍스트를 생성하는 등 다양한 분야에서 활용될 수 있다. 이에 AI는 ① 법률 비즈니스의 \n효율성과 생산성을 높여, ② 변호사들의 전문성 가치를 높여줄 뿐만 아니라, ③ 법률 서비스에 대한 \n접근성을 높일 수 있는 효과적인 방안으로 떠오르고 있다. 따라서 향후 AI 활용으로 시간과 인력이 대폭 \n줄고 의사결정이 빨라져 로펌 시장 판도에도 큰 변화를 일으킬 것으로 전망된다.\n\uf0a7AI 활용으로 계약서 작성 시간은 평균 32% 단축되었고 퀄리티는',
#     'contextualized_content': '본 텍스트는 삼일PwC의 "Samil Insight" 보고서의 9장 "법률: 비즈니스 AI 활용 현황 및 국내외 사례"의 "III. 산업별 비즈니스 AI 활용 현황" 부분의 법률 분야 AI 활용에 대한 소개 및 효과를 설명하는 내용입니다. \n'}],
#   'score': 0.029411764705882353,
#   'from_semantic': True,
#   'from_bm25': True},
#  {'chunk': [{'doc_id': 'doc_56',
#     'chunk_id': 'doc_56_chunk_6',
#     'chunk_content': ' 도입하기 위한 기술 개발이 포함되어있으며, 이를통해 각종 실시간 문의사항에 대한 안내 \n서비스 제공 예정\n노보텔 앰배서더 \n(서울동대문)\n•\n국내최초 AI 서비스 도입한 호텔로, KT와 협업하여 음성인식 AI 솔루션 ‘기가지니’, AI 호텔 로봇 \n‘엔봇(N-bot)’ 서비스를 제공\n-엔봇은 호텔 엘리베이터와 통신해 스스로 승하차하며 이동. 호텔 객실의 AI 스피커로 객실 조명 등을 \n제어할 수 있으며, 심야 시간에 수건, 생수 같은 비품을 요청하면 로봇이 배송\n',
#     'contextualized_content': '본 텍스트는 국내 관광 산업의 AI 적용 사례를 소개하는 문서의 일부분으로, 교원투어와 노보텔 앰배서더 서울 동대문의 AI 활용 사례를 구체적으로 설명하고 있다. \n'}],
#   'score': 0.02857142857142857,
#   'from_semantic': True,
#   'from_bm25': False},
#  {'chunk': [{'doc_id': 'doc_23',
#     'chunk_id': 'doc_23_chunk_3',
#     'chunk_content': "태로 사용할 수 있는 ‘AI 신용\n평가모델'을 개발 중\n자산관리\n크래프트테크놀로지스\n•\n국내외 글로벌 금융기관들에 AI 기반 투자 전략 솔루션을 제공\n씨앤테크\n•\nAI 및 빅데이터 기반 365일 24시간 글로벌 자산관제서비스를 제공\n파운트\n•\nAI 로보어드바이저 서비스로 빅데이터 활용, 수익률 예측 제공하며 \n마이데이터를 활용해 고도화된 개인 맞춤형 자산관리 서비스 제공\n빅트리\n•\nAI 로보어드바이저 플랫폼과 금융 빅데이터 분석 엔진을 공급\n콴텍\n•\n로보어드바이저 기반 자산관리 솔루션 ‘큐-엔진’과 시장의 이상 징후를 \n감지, 자동으로 위험을 관리해주는 ‘큐-크라이시스 인덱스’ 서비스 제공\n디셈버앤컴퍼니\n•\n로보어드바이저 시장 점유율 1위를 기록하고 있는 '핀트' 운영. 하나증권, \n대신증권, KB증권 MO",
#     'contextualized_content': "본 텍스트는 한국 금융업계에서 인공지능(AI) 기술을 활용하는 기업들을 소개하는 문서의 일부이며, 특히 '자산관리' 분야에 AI 기술을 적용하는 기업들을 상세히 설명하고 있습니다. \n"}],
#   'score': 0.027777777777777776,
#   'from_semantic': True,
#   'from_bm25': True},
#  {'chunk': [{'doc_id': 'doc_63',
#     'chunk_id': 'doc_63_chunk_3',
#     'chunk_content': ' 수준은 초기 단계\n제\n조\n자동차\n생산성\n비용 절감\n•\n자동화, 생산 공정 개선 중심으로 활용되는 중\n•\n디자인/설계 영역 중심으로 확대 적용 중이며, 생산 최적화를 \n위한 디지털 트윈, 로봇 도입 시작\n화학\n품질 개선\n생산성\n•\n데이터 수집, 자동화, 공정 프로세스 검토 수준\n•\nR&D 영역에 확대 적용 중이며, 생산 공정 최적화, 품질 개선, \n에너지 절감을 위해 활용 중\n농업\n생산성\n•\n관련 데이터가 적어 AI 활용 수준 낮은 편이나\n•\n생산량 및 수확량 극대화, 농업 자동화를 위해 AI 확대 적용 \n중이며, 스마트팜 구축 활발히 진행 중\n물류\n효율화\n고객 경험\n•\n자동화, 배송 추적 및 모니터링기능에 활용 중\n•\n물류 프로세스의 완전 자동화 및 지능화를 위해 AI 로봇 도입 \n활발\n관광\n개인화\n고객 ',
#     'contextualized_content': '본 텍스트는 산업별 AI 도입 및 활용 수준 진단 결과를 보여주는 표의 일부분으로, 제조, 자동차, 화학, 농업, 물류, 관광 산업에 대한 AI 도입 및 활용 현황을 상세히 설명하고 있습니다. \n'}],
#   'score': 0.02702702702702703,
#   'from_semantic': True,
#   'from_bm25': False},
#  {'chunk': [{'doc_id': 'doc_36',
#     'chunk_id': 'doc_36_chunk_3',
#     'chunk_content': ' AI를 \n도입하는 추세도 늘어나는 중이다.\n[화학 산업에서는 생산 공정, 운영 관리 영역 중심으로 AI 多 활용 중]\n제품 생산\n제품제작\n공급망 관리\nR&D/디자인\n운영 관리 \n• 설계 자동화/맞춤화\n• 디자인 시뮬레이션\n• 디지털 트윈\n• 로봇\n• 제작 자동화\n• 시뮬레이션/ 테스트\n• 자동 품질 최적화\n• 생산 데이터 분석\n• 품질 및 수율 예측\n• 생산 물량/납기 관리\n• 자동화된 유틸리티 \n비용 관리\n• 실시간 공급망 \n모니터링\n• 수요 예측 및 생산 계획\n• 재고 관리 효율화\n• 물류 자동화\n• 프로세스 자동화(RPA)\n• 실시간 데이터 수집 및 \n분석\n• 설비 예지 보전\n• 이상 발생 감지\nAI 기반 품질 관리, 공정 개선, 고장 예측/예방, \n안전 모니터링 등 생산 단계를 최적화\n탄소배출량 관',
#     'contextualized_content': '화학 산업에서 AI 도입이 늘어나는 추세이며, 생산 공정과 운영 관리 영역에서 AI를 활용하는 구체적인 사례들을 소개하고 있다. \n'}],
#   'score': 0.02631578947368421,
#   'from_semantic': True,
#   'from_bm25': False},
#  {'chunk': [{'doc_id': 'doc_2',
#     'chunk_id': 'doc_2_chunk_2',
#     'chunk_content': ' 만만치 않은 점이 한 이유일 수 있을 것이다. 하지만, 각 기업들은 AI를 도입할 \n것인가? 어느 정도 도입할 것인가? 어떤 방식으로 도입할 것인가? 등에 대한 의사결정을 할 수 밖에 \n없는 단계에 있으며 이러한 결정에 앞서 동종업계든 이종업계든 다른 기업들이 어떻게 이를 시도하고 \n적용하고 있는지를 아는 것은 매우 유익할 것이다.\n이러한 관점에서 이 보고서의 주요 목적은 ‘산업별로 AI를 어떻게 활용하여 비즈니스 성과를 내고 \n있는지’를 구체적인 국내외 사례들을 통해 알아보고자 하는 것이다. 이를 위하여 보고서는 AI의 \n공급자와 수요자를 중심으로 이루어지는 생태계와 가치사슬을 집중 조명하였으며, 10개 산업별로 \n구체적인 비즈니스 활용 사례들을 정리하는 데 중점을 두었다. 특히, 금융분야의 JP 모건 ',
#     'contextualized_content': '생성형 AI 도입 초기 단계에 다양한 시도가 이루어지고 있지만, 성공 여부 판단은 어렵다는 내용과 함께 이 보고서의 목적이 산업별 AI 활용 사례를 통해 기업의 의사결정에 도움을 주는 것이라는 설명입니다. \n'}],
#   'score': 0.02564102564102564,
#   'from_semantic': True,
#   'from_bm25': False},
#  {'chunk': [{'doc_id': 'doc_56',
#     'chunk_id': 'doc_56_chunk_2',
#     'chunk_content': ' 생성형 AI를 도입해 챗봇, 예약, 일정 생성 \n등의 다양한 서비스를 제공 중이거나 서비스 고도화를 위해 다양한 시도를 하고 있다.\n[국내 관광업체들의 AI 적용 사례]\n※ 각 사, 언론종합, 삼일PwC경영연구원\n기업명\nAI 비즈니스 적용 사례\n하나투어\n•\n챗GPT를 적용한 AI 챗봇 서비스 ‘여행정보 AI’ 출시. 현지 상품, 날씨, 맛집, 명소 등을 대화형으로 \n여행객에 추천해주며, 기존 패키지 인기 명소를 토대로 현지 일정을 생성\n-이용자는 24/7 챗봇과 대화할 수 있으며, 이용자들 질문과 트렌드에 맞춰 필터링해 제공\n•\n업무 효율화를 위해 여행업 특화 AI 콜센터 운영할 계획. 상용화될 경우 직원 수 감축\n모두투어\n•\nAI를 기반으로 한 ‘차세대 시스템 개발’을 추진 중이며(’24년내 완료 목표)',
#     'contextualized_content': '국내 관광 산업의 디지털 전환 수준은 낮지만, 생성형 AI 도입으로 업계 성장성이 주목받고 있으며, 국내 기업들은 AI를 활용하여 업무 효율화 및 고객 맞춤형 서비스를 제공하고 있다.'}],
#   'score': 0.025,
#   'from_semantic': True,
#   'from_bm25': True},
#  {'chunk': [{'doc_id': 'doc_59',
#     'chunk_id': 'doc_59_chunk_4',
#     'chunk_content': '에 맞는 립스틱을 선정해\n주는 ‘컬러테일러’ 앱 출시\n•\nLG생활건강: 생성형 AI를 활용해 생활용품 및 화장품 패키지 디자인\n',
#     'contextualized_content': '뷰티∙화장품 산업에서 AI를 활용한 국내 기업들의 비즈니스 활용 사례를 보여주는 부분입니다. \n'}],
#   'score': 0.024390243902439025,
#   'from_semantic': True,
#   'from_bm25': False},
#  {'chunk': [{'doc_id': 'doc_36',
#     'chunk_id': 'doc_36_chunk_2',
#     'chunk_content': ' 있기 \n때문이다.\n\uf06c화학 산업에서의 AI 기술 활용은 금융 또는 운송 등에 비해 덜 일반적이었으나, 보다 엄격해진 품질 관리 \n프로토콜 및 ESG 추세에 따른 탄소 발자국 감축 어젠다를 이행하기 위해 화학 제조업체들은 AI의 잠재력에 \n주목하고 있다.\n\uf06c이에 현재 AI는 ① 품질 관리 및 고장 예측/예방 최적화를 위한 제품 생산 공정, 그리고 ② 화학 물질 위험성 \n및 품질 검토, 탄소 발생량 절감 등을 특히 중요시 여기는 업종 특성상 운영 관리 영역에 집중적으로 \n활용되고 있는 것으로 보인다. 최근에는 화학적 물질 분석, 신제품 설계 및 개발 등을 위해서도 생성형 AI를 \n도입하는 추세도 늘어나는 중이다.\n[화학 산업에서는 생산 공정, 운영 관리 영역 중심으로 AI 多 활용 중]\n제품 생산\n제품제작\n공급',
#     'contextualized_content': '화학 제조 산업에서 AI 활용이 덜 일반적이었지만, 엄격해진 품질 관리 및 ESG 추세로 인해 AI 활용의 잠재력에 주목하고 있다는 내용입니다. \n'}],
#   'score': 0.023809523809523808,
#   'from_semantic': True,
#   'from_bm25': True},
#  {'chunk': [{'doc_id': 'doc_2',
#     'chunk_id': 'doc_2_chunk_1',
#     'chunk_content': 'Samil PwC  l  Samil Insight\n1\n2022년 11월 OpenAI의 ChatGPT 출시 이후 엄청난 속도로 생성형 AI 산업이 전방위적으로 \n확장되고 있으며, 생성형 AI의 기능, 한계, 그에 대한 대책 등 다양한 분석이 이어지고 있다.\n다만, 총론적인 보고서들은 이미 많이 발표되고 있지만 산업별, 기업별로 AI가 구체적으로 어떻게 \n활용되고 있는지에 대한 적용 사례에 대한 보고는 아직 미진하다. 아마도 생성형 AI의 초기 단계이기 \n때문에 매일 다양한 시도가 나타났다 사라지고 있고 적용사례의 성공여부도 판가름하기 어려워 이를 \n체계적으로 정리하기가 만만치 않은 점이 한 이유일 수 있을 것이다. 하지만, 각 기업들은 AI를 도입할 \n것인가? 어느 정도 도입할 것인가? 어떤 방식으로 도입할 ',
#     'contextualized_content': '이 텍스트는 보고서의 서론 부분으로 생성형 AI 산업의 급속한 성장과 더불어 이 보고서의 목적과 필요성을 설명하고 있습니다. \n'}],
#   'score': 0.023255813953488372,
#   'from_semantic': True,
#   'from_bm25': True},
#  {'chunk': [{'doc_id': 'doc_64',
#     'chunk_id': 'doc_64_chunk_5',
#     'chunk_content': ' 물론 빅테크까지 합세하여 AI 기반 작물 \n데이터 수집/분석 플랫폼, 제초제 살포, 자원 최적화, 로봇 \n서비스 등 개발 중\n▲ 물류\n•\nAI 적용을 위한 실증 데이터가 부족하여 시스템 구축이 \n더딘 편, 유통 분야 중심으로 AI 활용 중\n•\nAI 스타트업과 더불어 국내 IT 서비스 기업들이 국내 \n스마트 물류 시장 공략 중\n•\n다양한 업무 영역에 AI를 도입하여 물류 운송의 생산성 \n향상 및 원가 절감을 실현 중\n•\nAI 기업들은 AI 기반 운영 관리 시스템은 물론 물류 자동\n화를 위한 로봇 및 드론까지 개발 중\n관광\n•\nAI 기반 업무 효율화 체계 구축 중이며, 생성형 AI를 \n도입해 예약, 일정 생성 등 다양한 서비스 제공 중 \n•\n빅테크의 IT 인프라를 활용하여 업무 효율화를 조기에 \n달성. 생성형',
#     'contextualized_content': '본문은 농업과 물류, 관광 산업에서 국내와 글로벌 AI 활용 현황을 비교 분석하는 내용입니다. 특히 농업 분야에서는 AI 기반 작물 데이터 수집, 제초제 살포, 자원 최적화 등 다양한 분야에서 활용되고 있으며, 빅테크 기업들의 참여가 증가하고 있다는 내용을 담고 있습니다. \n'}],
#   'score': 0.022727272727272728,
#   'from_semantic': True,
#   'from_bm25': False},
#  {'chunk': [{'doc_id': 'doc_23',
#     'chunk_id': 'doc_23_chunk_2',
#     'chunk_content': "테크 기업 중 최초로 AI를 도입하여 핀다 전용 챗GPT인 ‘핀다GPT’를 \n개발, 대출 중개 및 관리 서비스 제공\n어니스트펀드\n•\n대출 관련 데이터를 AI 알고리즘으로 학습, 분석해 금융기관 리스크 \n통제에 필요한 서비스를 제공하는 솔루션 '렌딩 인텔리전스'를 개발\n펀다\n•\n소상공인 전문 온라인투자연계금융기업. 최근 금융 AI 전문기업 씽크풀과 \n개발한 소상공인 대출 및 자동상환시스템 관련 특허 출원을 완료\n렌딧\n•\n개인화된 적정금리를 AI 기술을 통해 산출하여 제2금융권 대비 합리적인 \n대출금리를 제공\n피플펀드컴퍼니\n•\n금융기관이 SaaS(서비스형 소프트웨어) 형태로 사용할 수 있는 ‘AI 신용\n평가모델'을 개발 중\n자산관리\n크래프트테크놀로지스\n•\n국내외 글로벌 금융기관들에 AI 기반 투자 전략 솔루션을",
#     'contextualized_content': '본 텍스트는 국내 금융업에서 AI 기술을 활용하는 기업/스타트업을 소개하는 부분이며, 특히 신용평가/대출 분야에 대한 기술 활용 사례를 보여주는 내용입니다. \n'}],
#   'score': 0.022222222222222223,
#   'from_semantic': True,
#   'from_bm25': True},
#  {'chunk': [{'doc_id': 'doc_53',
#     'chunk_id': 'doc_53_chunk_2',
#     'chunk_content': '특히 관광 산업은 근본적으로 고객 및 서비스 지향적인 특성을 지니기에, AI 도입을 통한 방대한 고객 \n데이터 수집, 고객 여행 패턴 및 선호도 분석 등으로 개인 맞춤형 여행 서비스 설계가 가능해져 업계내 AI\n도입률은 향후 급증할 것으로 예상되고 있다. Maximize Market Research에 따르면 관광업계에 있어 \n생성형 AI 시장 규모는 ’23년 36억 달러에서 ’30년 113억 달러 수준으로 CAGR 17.5% 성장할 것으로 \n전망되고 있다. 또한 Oliver Wyman(’23)에 따르면, 84%의 여행자들이AI가 추천해준 여행에 전반적으로 \n만족하며,42%의 여행자들이 AI가 생성해준 여행 일정을 선호한다고 조사되었다.\n\uf06c현재 AI는 ① 빅데이터 분석 기반의 여행지, 항공 및 호텔 예약과, ',
#     'contextualized_content': '관광 산업의 비즈니스 AI 활용 현황을 설명하는 부분으로, AI 도입을 통한 고객 맞춤형 여행 서비스 설계 가능성과 시장 성장 전망, 현재 AI 활용 사례를 제시하고 있습니다. \n'}],
#   'score': 0.021739130434782608,
#   'from_semantic': True,
#   'from_bm25': True},
#  {'chunk': [{'doc_id': 'doc_51',
#     'chunk_id': 'doc_51_chunk_3',
#     'chunk_content': '구 풀필먼트센터는 진열, 포장, 분류 등 다양한 업무를 로봇(무인운반로봇, 분류로봇, \n무인지게차)을 활용하여 상품 피킹 및 분배 업무 자동화 \uf0e0업무강도 65% 감소, 생산성 향상\n•\n고객이 주문하면 AI의 실시간 데이터 분석을 기반으로 불과 몇 초 만에 상품의 배송트럭 내 적재 \n위치에 이르기까지 개별 상품이 거치게 될 최적 경로 제공\n•\nAI기반 수요예측으로 신선식품 재고 손실을 50% 이상 축소, 장비와 재고를 전방 배치해 휴일 등 \n피크 시간에도 안정적인 고객 경험 제공\nHMM\n•\n카카오 엔터프라이즈와 협력하여AI, 빅데이터 기술력을 바탕으로 해운·물류 관련 산업의 데이터\n를 확보, 분석을 진행하고, 데이터 기반의 영업·운영 전략 수립, 차별화된 디지털 해운·물류 \n사업모델 개발을 검토\n-메신저 업무',
#     'contextualized_content': '쿠팡의 AI 활용 사례를 설명하는 부분입니다. \n'}],
#   'score': 0.02127659574468085,
#   'from_semantic': True,
#   'from_bm25': False},
#  {'chunk': [{'doc_id': 'doc_55',
#     'chunk_id': 'doc_55_chunk_5',
#     'chunk_content': '요한 정보를 \n제공하고, 항공권 가격이 예상 최저점에 도달했을 때 알려줌\n-수백만 건의 항공편 가격 변동 데이터를 AI 알고리즘으로 분석해 소비자가 항공권 구매에 지불하는 \n비용을 최대 40% 절약해줌\nFlyr\n•\nAI 기반으로 항공사의 데이터를 수집하고 분석하여 판매, 예약 활동 및 기타 여행 요소들에 대해 정확히 \n예측해주는 ‘Cirrus’ 플랫폼 서비스 제공\n-여행사는 특정 항공편의 적재 수준을 예측하고 수요의 증가와 감소를 고려한 가격을 결정\nBetterTravel\n•\n여행지 선택에 도움을 주는 AI 기반 여행 서비스로, 출발지, 하고 싶은 활동, 여행 기간 등을 입력하면 \n자동으로 여행지를 추천해줌\nAccubits\n•\nAI 기반의 여행 일정 추천부터 원활한 예약에 이르기까지 맞춤형 여행 서비스를 제',
#     'contextualized_content': '해외 관광업 AI 기술 기업 중 Hopper, Flyr, BetterTravel, Accubits 등 4개 기업의 설명입니다. \n'}],
#   'score': 0.020833333333333332,
#   'from_semantic': False,
#   'from_bm25': True},
#  {'chunk': [{'doc_id': 'doc_43',
#     'chunk_id': 'doc_43_chunk_5',
#     'chunk_content': '로운 비즈니스 먹거리 확보\n이마트\n• 스마트팜 기업 엔씽과 협업하여 물류 센터 옆에 \n스마트팜 두어 채소를 재배해 현장에서 바로 \n채소를 뽑아 판매\n\uf0e0농작물 물류 이동 시간 및 비용 절감\n농심\n• 컨테이너형 스마트팜 자체 개발하여 ’22년에는 \n오만으로, ’23년 UAE, 사우디로 수출\n\uf0e0식품 사업을 넘어 농업으로 수익 모델 다변화  \nCJ프레시\n웨이\n• AI 기반 농업 데이터, 방제∙모니터링 제어 기능을 \n갖춘 ‘노지 스마트팜’ 기술을 활용하여 농작물을 \n재배하고외식 및 급식 고객사에 공급\n\uf0e0사업 모델 다변화, 수익성 도모\n',
#     'contextualized_content': '본 텍스트는 농업 분야에서 AI 활용 사례를 소개하는 문서의 일부로, 특히 식품/유통업체들의 AI 활용 사례를 보여줍니다. \n'}],
#   'score': 0.02040816326530612,
#   'from_semantic': True,
#   'from_bm25': False},
#  {'chunk': [{'doc_id': 'doc_53',
#     'chunk_id': 'doc_53_chunk_5',
#     'chunk_content': '관광객 거래 효율화를 위한 혁신 결제 기술\n② 빅데이터 기반의 관광 디지털 큐레이션 기술\n⑦ 관광객 실감 경험을 확대하는 인터랙티브 기술\n③ 관광형 첨단 모빌리티 기술\n⑧ 관광경영 고도화를 위한 지능형 운영 플랫폼 기술\n④ 지능형 관광이동 연계 서비스\n⑨ 관광 정보를 수집·분석하는 디지털 혁신 기술 \n⑤ 관광서비스를 지원하는 무인화·로보틱스 기술\n⑩ 실시간 관광객 안전을 위한 관광 환경 예측·분석 정밀 기술\n',
#     'contextualized_content': '본 문서는 관광 산업에서의 AI 활용 현황과 미래 유망 기술에 대한 내용을 담고 있습니다. 위 텍스트는 한국문화관광연구원이 발표한 10대 미래 유망 관광 기술 목록 중 일부입니다. \n'}],
#   'score': 0.02,
#   'from_semantic': True,
#   'from_bm25': False}]

# %%
reranker = LLM_Reranker()
rerank_results = reranker.rerank_results(query="금융권에서 생성형AI가 활용되는 사례에 대해서 설명해줘", results = retrieve_results, k = 5)

# %%
rerank_rag = []
for id, result in enumerate(rerank_results):
    print('#' * 25 + f' {id+1}번째 청크 ' + '#' * 25)
    print(f'{result['chunk'][0]['chunk_content']}')
    rerank_rag.append(result['chunk'][0]['chunk_content'])
# Out:
# ######################### 1번째 청크 #########################
# Samil PwC  l  Samil Insight
# 17
# 1-1. 금융: 비즈니스 AI 활용 현황
# III. 산업별 비즈니스 AI 활용 현황
# 금융업은 헬스케어,자동차 산업에 이어 AI영향력이 큰 업종 중 하나로,금융권의 수치,재무 등 방대한 정형
# 데이터를 기반으로 강력한 AI비즈니스 창출이 가능한 산업이다.
# 특히 ① 신속한 고객 문의 대응을 위한 챗봇/상담봇, ② 투자성향, 리스크 수준, 기대 수익률 등 자산관리 및
# 상품추천 정보를 제공하는 로보어드바이저(Robo-advisor), ③ 각종 서류를 자동으로 분석/분류하는 등
# 프로세스를 개선해주는 로봇 프로세스 자동화(Robotic Process Automation, RPA) 기능에
# 금융기관들은 주목하고 있다.
# 현재 국내외 금융기관들의 생성형 AI 도
# ######################### 2번째 청크 #########################
# 동화(Robotic Process Automation, RPA) 기능에
# 금융기관들은 주목하고 있다.
# 현재 국내외 금융기관들의 생성형 AI 도입 및 활용 방향성을 비추어 봤을때 특히 ‘마케팅/영업’과
# ‘고객관리’와 같이 개별 고객에 대한 정밀한 분석 기반의 1대1 맞춤형 서비스가 요구되는 영역을 중심으로
# 보다 고도화된 생성형 AI기술을 활용하고자 하는 니즈가 높아지고 있다.
# [금융 산업 밸류체인 -AI 적용 예시]
# 마케팅, 영업
# 상품, 서비스
# 고객관리
# 운영 관리
# 리스크 관리
# • 초개인화 고객 분석
# • 시장 분석/예측
# • 원격 지원
# • 잠재 고객 발굴
# • 챗봇
# • 고객 segment별
# 특화된 맞춤상품 추천
# • 신원인식(얼굴, 음성)
# • 컨설팅(투자, 보험,
# 절세 등)
# • 금융/비금융 연계
# 종합 플랫
# ######################### 3번째 청크 #########################
# 태로 사용할 수 있는 ‘AI 신용
# 평가모델'을 개발 중
# 자산관리
# 크래프트테크놀로지스
# •
# 국내외 글로벌 금융기관들에 AI 기반 투자 전략 솔루션을 제공
# 씨앤테크
# •
# AI 및 빅데이터 기반 365일 24시간 글로벌 자산관제서비스를 제공
# 파운트
# •
# AI 로보어드바이저 서비스로 빅데이터 활용, 수익률 예측 제공하며
# 마이데이터를 활용해 고도화된 개인 맞춤형 자산관리 서비스 제공
# 빅트리
# •
# AI 로보어드바이저 플랫폼과 금융 빅데이터 분석 엔진을 공급
# 콴텍
# •
# 로보어드바이저 기반 자산관리 솔루션 ‘큐-엔진’과 시장의 이상 징후를
# 감지, 자동으로 위험을 관리해주는 ‘큐-크라이시스 인덱스’ 서비스 제공
# 디셈버앤컴퍼니
# •
# 로보어드바이저 시장 점유율 1위를 기록하고 있는 '핀트' 운영. 하나증권,
# 대신증권, KB증권 MO
# ######################### 4번째 청크 #########################
# Samil PwC  l  Samil Insight
# 63
# 2. 시사점: 글로벌 활용 사례와의 비교
# IV. 결론: 시사점
# 국내 AI 활용 수준은 해외 대비 상대적으로 낮아 가시적 성과가 미미한 상황이다. 이는 인력, 공유 데이터,
# 플랫폼 인프라,투자,정책적 지원 등이 부족하여 산업내 AI활성화가 더딘 것에 기인한 것으로 판단된다.
# 제조업 강국임에도 불구, 국내 제조 산업의 보수적인 특성과 전문 인력에 대한 높은 의존도로 인해 AI
# 활용도가 아직 낮은 편으로 지속적인 글로벌 경쟁력을 확보하기 위해서는 관련 산업종사자들의 문제의식
# 및 적극적인 변화의 움직임이 필요해 보인다. 금융, 물류, 미디어, 법률 산업 또한 해외 대비 격차가
# 상대적으로 뚜렷한 편으로 서비스 부문에서도 변화가 절실한 상황이다.
# [산업별
# ######################### 5번째 청크 #########################
# 한단계 더 성장할 수 있는 여지가 많다. 따라서 산업별 또는 각
# 기업별로 AI기술의 도입 및 활용은 더욱 활발해 질 것으로 예상된다.
# [산업별 AI 도입 및 활용 수준]
# 산업
# AI 도입 및 활용 수준*
# 주 도입
# 목적
# AI 활용 현황 진단
# 低
# 高
# 금융
# 효율화
# 고객 경험
# •
# RPA, 챗봇 서비스 중심으로 AI 활용도 높은 편이나
# •
# 고객맞춤형 서비스, 사기 탐지, 리스크 대응 등 기타 기능의 AI
# 도입 수준은 초기 단계
# 헬스케어
# 비용 절감
# 개인화
# •
# 신약개발을 위한 AI 도입은 본격화되었으나
# •
# 안전성 및규제로 인해 기타 의료 활동(임상시험, 질병 치료등)
# 의 도입 수준은 초기 단계
# 제
# 조
# 자동차
# 생산성
# 비용 절감
# •
# 자동화, 생산 공정 개선 중심으로 활용되는 중
# •
# 디자인/설계 영역 중심으로 확대 적용

# %%
rag = "Contextual + (Semantic + BM25) + Reranker"
context = "\n\n".join(rerank_rag)
query = "금융권에서 생성형AI가 활용되는 사례에 대해서 설명해줘. 최대한 상세하게 설명해줘."

prompt = f""" 
Using only the CONTEXT below, provide an accurate answer to the QUESTION in Korean (Hangul).

Only use information provided in the CONTEXT for your answer.
Do not reference or incorporate any external information.
If the answer cannot be determined based on the CONTEXT, respond with "답변이 어렵습니다."
CONTEXT: {context}

QUESTION: {query}

ANSWER:
"""
client = genai.GenerativeModel(
    model_name='gemini-1.5-flash-latest'
)
response = client.generate_content(contents=prompt).text
print("#" * 40)
print(f"{rag}를 통한 RAG 결과")
print("-" * 40)
print(f"답변 : {response}\n")
# Out:
# ########################################
# Contextual + (Semantic + BM25) + Reranker를 통한 RAG 결과
# ----------------------------------------
# 답변 : 금융권에서는 생성형 AI를 주로 마케팅/영업과 고객관리 분야에서 활용하고 있습니다. 특히 개별 고객에 대한 정밀한 분석을 기반으로 1대1 맞춤형 서비스를 제공하는 데 유용하게 활용되고 있습니다.
#
# 예를 들어, 생성형 AI는 고객의 투자 성향, 리스크 수준, 기대 수익률 등을 분석하여 개인 맞춤형 상품 추천, 자산 관리 컨설팅, 금융/비금융 연계 종합 플랫폼 서비스를 제공할 수 있습니다. 또한, 고객 문의에 대한 신속하고 정확한 답변을 제공하는 챗봇, 고객의 신원을 인식하는 얼굴/음성 인식 시스템, 그리고 금융 사기 탐지 및 예방에도 활용될 수 있습니다.
#
# 생성형 AI는 고객에게 보다 개인화된 서비스를 제공하고 효율성을 높이는 데 크게 기여할 것으로 예상됩니다.

# %%
from IPython.display import Markdown
Markdown(response)
# Out:
# 금융권에서는 생성형 AI를 주로 마케팅/영업과 고객관리 분야에서 활용하고 있습니다. 특히 개별 고객에 대한 정밀한 분석을 기반으로 1대1 맞춤형 서비스를 제공하는 데 유용하게 활용되고 있습니다.
#
# 예를 들어, 생성형 AI는 고객의 투자 성향, 리스크 수준, 기대 수익률 등을 분석하여 개인 맞춤형 상품 추천, 자산 관리 컨설팅, 금융/비금융 연계 종합 플랫폼 서비스를 제공할 수 있습니다. 또한, 고객 문의에 대한 신속하고 정확한 답변을 제공하는 챗봇, 고객의 신원을 인식하는 얼굴/음성 인식 시스템, 그리고 금융 사기 탐지 및 예방에도 활용될 수 있습니다.
#
# 생성형 AI는 고객에게 보다 개인화된 서비스를 제공하고 효율성을 높이는 데 크게 기여할 것으로 예상됩니다.

# %%
rerank_inputs = [(query, result['chunk'][0]['chunk_content']) for result in retrieve_results]
# rerank_inputs

# %%
import gc
gc.collect()
# Out:
# 7

# %%
import torch
from transformers import AutoModelForSequenceClassification, AutoTokenizer
# model_name = "'BAAI/bge-reranker-v2-m3'"
model_name = "Dongjin-kr/ko-reranker"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForSequenceClassification.from_pretrained(model_name)
model.eval()

# pairs = [['what is panda?', 'hi'], ['what is panda?', 'The giant panda (Ailuropoda melanoleuca), sometimes called a panda bear or simply panda, is a bear species endemic to China.']]

with torch.no_grad():
    inputs = tokenizer(rerank_inputs, padding=True, truncation=True, return_tensors='pt', max_length=512)
    scores = model(**inputs, return_dict=True).logits.view(-1, ).float()
    print(scores)
# Out:
# tokenizer_config.json:   0%|          | 0.00/1.21k [00:00<?, ?B/s]
# c:\Users\LeeSeungYong\langchain\Lib\site-packages\huggingface_hub\file_download.py:157: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\LeeSeungYong\.cache\huggingface\hub\models--Dongjin-kr--ko-reranker. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to see activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# sentencepiece.bpe.model:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.1M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/963 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/802 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/2.24G [00:00<?, ?B/s]
# tensor([ 3.9907, -9.8244, -9.8245, -9.8247, -2.9951, -9.8244, -9.8163, -9.1662,
#         -3.9930, -4.3214, -9.8240, -8.2679,  3.9325, -8.2192, -3.3102, -2.4136,
#         -7.4922, -8.2801, -5.0900, -7.3276, -8.6552, -2.1247, -6.9939,  7.4474,
#         -3.3513, -4.1066,  0.2785, -6.7167, -9.7822,  1.4517, -5.3458, -4.4951,
#         -9.8067, -4.7634, -8.0718, -5.7102, -7.3095, -7.8747, -2.6332, -0.3856,
#         -6.7883, -1.2419, -4.9321, -3.3251, -2.8604, -6.1635, -7.9117, -9.6421,
#         -8.8281, -9.8176])

# %%
relevant_index_high = scores.numpy().argsort()[::-1]
relevant_index_high

import numpy as np
def sigmoid(x):
    return 1/(1+np.exp(-x))

relevance_scores = list(map(sigmoid, scores.numpy()))

reranked_results = [
    {
        "rerank_content" : rerank_inputs[idx][-1],
        "rerank_socre" : relevance_scores[idx],
        }
        for idx in relevant_index_high
        ]

# %%
baai_rag = [result['rerank_content'] for result in reranked_results[:5]]
sum([baai == rerank for rerank in rerank_rag for baai in baai_rag])
# Out:
# 2

# %%
rerank_rag
# Out:
# ['Samil PwC  l  Samil Insight\n17\n1-1. 금융: 비즈니스 AI 활용 현황\nIII. 산업별 비즈니스 AI 활용 현황\n\uf06c금융업은 헬스케어,자동차 산업에 이어 AI영향력이 큰 업종 중 하나로,금융권의 수치,재무 등 방대한 정형 \n데이터를 기반으로 강력한 AI비즈니스 창출이 가능한 산업이다.\n\uf06c특히 ① 신속한 고객 문의 대응을 위한 챗봇/상담봇, ② 투자성향, 리스크 수준, 기대 수익률 등 자산관리 및 \n상품추천 정보를 제공하는 로보어드바이저(Robo-advisor), ③ 각종 서류를 자동으로 분석/분류하는 등 \n프로세스를 개선해주는 로봇 프로세스 자동화(Robotic Process Automation, RPA) 기능에 \n금융기관들은 주목하고 있다.\n\uf06c현재 국내외 금융기관들의 생성형 AI 도',
#  '동화(Robotic Process Automation, RPA) 기능에 \n금융기관들은 주목하고 있다.\n\uf06c현재 국내외 금융기관들의 생성형 AI 도입 및 활용 방향성을 비추어 봤을때 특히 ‘마케팅/영업’과 \n‘고객관리’와 같이 개별 고객에 대한 정밀한 분석 기반의 1대1 맞춤형 서비스가 요구되는 영역을 중심으로 \n보다 고도화된 생성형 AI기술을 활용하고자 하는 니즈가 높아지고 있다.\n[금융 산업 밸류체인 -AI 적용 예시]\n마케팅, 영업\n상품, 서비스\n고객관리\n운영 관리\n리스크 관리\n• 초개인화 고객 분석\n• 시장 분석/예측\n• 원격 지원\n• 잠재 고객 발굴\n• 챗봇\n• 고객 segment별 \n특화된 맞춤상품 추천\n• 신원인식(얼굴, 음성)\n• 컨설팅(투자, 보험, \n절세 등)\n• 금융/비금융 연계 \n종합 플랫',
#  "태로 사용할 수 있는 ‘AI 신용\n평가모델'을 개발 중\n자산관리\n크래프트테크놀로지스\n•\n국내외 글로벌 금융기관들에 AI 기반 투자 전략 솔루션을 제공\n씨앤테크\n•\nAI 및 빅데이터 기반 365일 24시간 글로벌 자산관제서비스를 제공\n파운트\n•\nAI 로보어드바이저 서비스로 빅데이터 활용, 수익률 예측 제공하며 \n마이데이터를 활용해 고도화된 개인 맞춤형 자산관리 서비스 제공\n빅트리\n•\nAI 로보어드바이저 플랫폼과 금융 빅데이터 분석 엔진을 공급\n콴텍\n•\n로보어드바이저 기반 자산관리 솔루션 ‘큐-엔진’과 시장의 이상 징후를 \n감지, 자동으로 위험을 관리해주는 ‘큐-크라이시스 인덱스’ 서비스 제공\n디셈버앤컴퍼니\n•\n로보어드바이저 시장 점유율 1위를 기록하고 있는 '핀트' 운영. 하나증권, \n대신증권, KB증권 MO",
#  'Samil PwC  l  Samil Insight\n63\n2. 시사점: 글로벌 활용 사례와의 비교\nIV. 결론: 시사점\n\uf06c국내 AI 활용 수준은 해외 대비 상대적으로 낮아 가시적 성과가 미미한 상황이다. 이는 인력, 공유 데이터,\n플랫폼 인프라,투자,정책적 지원 등이 부족하여 산업내 AI활성화가 더딘 것에 기인한 것으로 판단된다.\n\uf06c제조업 강국임에도 불구, 국내 제조 산업의 보수적인 특성과 전문 인력에 대한 높은 의존도로 인해 AI\n활용도가 아직 낮은 편으로 지속적인 글로벌 경쟁력을 확보하기 위해서는 관련 산업종사자들의 문제의식 \n및 적극적인 변화의 움직임이 필요해 보인다. 금융, 물류, 미디어, 법률 산업 또한 해외 대비 격차가 \n상대적으로 뚜렷한 편으로 서비스 부문에서도 변화가 절실한 상황이다.\n[산업별 ',
#  '한단계 더 성장할 수 있는 여지가 많다. 따라서 산업별 또는 각 \n기업별로 AI기술의 도입 및 활용은 더욱 활발해 질 것으로 예상된다.\n[산업별 AI 도입 및 활용 수준]\n산업\nAI 도입 및 활용 수준*\n주 도입 \n목적\nAI 활용 현황 진단\n低\n高\n금융\n효율화\n고객 경험\n•\nRPA, 챗봇 서비스 중심으로 AI 활용도 높은 편이나\n•\n고객맞춤형 서비스, 사기 탐지, 리스크 대응 등 기타 기능의 AI \n도입 수준은 초기 단계\n헬스케어\n비용 절감\n개인화\n•\n신약개발을 위한 AI 도입은 본격화되었으나\n•\n안전성 및규제로 인해 기타 의료 활동(임상시험, 질병 치료등)\n의 도입 수준은 초기 단계\n제\n조\n자동차\n생산성\n비용 절감\n•\n자동화, 생산 공정 개선 중심으로 활용되는 중\n•\n디자인/설계 영역 중심으로 확대 적용 ']

# %%
baai_rag
# Out:
# ['동화(Robotic Process Automation, RPA) 기능에 \n금융기관들은 주목하고 있다.\n\uf06c현재 국내외 금융기관들의 생성형 AI 도입 및 활용 방향성을 비추어 봤을때 특히 ‘마케팅/영업’과 \n‘고객관리’와 같이 개별 고객에 대한 정밀한 분석 기반의 1대1 맞춤형 서비스가 요구되는 영역을 중심으로 \n보다 고도화된 생성형 AI기술을 활용하고자 하는 니즈가 높아지고 있다.\n[금융 산업 밸류체인 -AI 적용 예시]\n마케팅, 영업\n상품, 서비스\n고객관리\n운영 관리\n리스크 관리\n• 초개인화 고객 분석\n• 시장 분석/예측\n• 원격 지원\n• 잠재 고객 발굴\n• 챗봇\n• 고객 segment별 \n특화된 맞춤상품 추천\n• 신원인식(얼굴, 음성)\n• 컨설팅(투자, 보험, \n절세 등)\n• 금융/비금융 연계 \n종합 플랫',
#  '계와 가치사슬을 집중 조명하였으며, 10개 산업별로 \n구체적인 비즈니스 활용 사례들을 정리하는 데 중점을 두었다. 특히, 금융분야의 JP 모건 사례,\n헬스케어의 Roche 사례, 화학 분야의 BASF 사례, 물류산업의 DHL 사례는 눈여겨 볼 만 하다.\n생성형 AI 도입이 초기 단계인 만큼, 사례가 제한적인 점, 그리고 적용사례의 성공여부가 아직 \n판명되지 않은 점 등 제약적인 상황이지만 기업들이 어떻게 대응하고 있는지를 소개함으로써 AI의 \n도입을 검토하고 있는 후발주자들에게 길라잡이가 되었으면 한다. 동시에 ‘game changer’로서의 \n생성형 AI로 인해 기업들의 비즈니스 모델이 향후 얼마나 변해 있을지에 대해 이 보고서를 통해서 각자 \n상상을 펼쳐볼 수 있으면 좋겠다.\n들어가며\n',
#  'Samil PwC  l  Samil Insight\n17\n1-1. 금융: 비즈니스 AI 활용 현황\nIII. 산업별 비즈니스 AI 활용 현황\n\uf06c금융업은 헬스케어,자동차 산업에 이어 AI영향력이 큰 업종 중 하나로,금융권의 수치,재무 등 방대한 정형 \n데이터를 기반으로 강력한 AI비즈니스 창출이 가능한 산업이다.\n\uf06c특히 ① 신속한 고객 문의 대응을 위한 챗봇/상담봇, ② 투자성향, 리스크 수준, 기대 수익률 등 자산관리 및 \n상품추천 정보를 제공하는 로보어드바이저(Robo-advisor), ③ 각종 서류를 자동으로 분석/분류하는 등 \n프로세스를 개선해주는 로봇 프로세스 자동화(Robotic Process Automation, RPA) 기능에 \n금융기관들은 주목하고 있다.\n\uf06c현재 국내외 금융기관들의 생성형 AI 도',
#  'Contents\nI\n생성형 AI 생태계 구조: 공급자 측면\n3\nII\n생성형 AI 시장 전망 및 도입 현황: 수요자 측면\n10\nIII\n산업별 비즈니스 AI 활용 현황\n10개 산업(금융, 헬스케어, 제조(자동차, 화학) 등)으로 본 AI 활용사례\n14\nIV\n결론: 시사점\n61\n',
#  '이 적용되고 있는 것으로 \n파악되며, 산업별 특화된 기능을 수행하기 위한 AI 활용도는 전반적으로 ‘개발’ 또는 ‘파일럿’ 단계   \n\uf06c자산을 ‘데이터화’할 수 있는 산업이 초기 AI 경쟁력을 가질 것으로 판단되며, ‘창작’을 기반으로 \n비즈니스를 영위하는 산업은 생성형 AI를 통한 경제적 이득이 상당할 것\n\uf0a7\n상대적으로 AI 도입률이 높은 금융 및 IT 산업의 경우 기존에 보유하고 있는 데이터 규모가 방대하여 \nAI 모델을 통한 비즈니스 혁신이 용이. 현재 도입 초기 단계인 법률 산업의 경우 판례 등 데이터화가 \n가능해진다면 AI를 통한 성장세 상당할 것으로 예상\n\uf0a7\n헬스케어 산업의 경우 안전성과 더불어 의료 데이터 활용 및 권한을 둘러싼 규제적 제한으로 인해 AI \n기반 혁신이 더딘 상황이며, 제조 산업']

# %%
rag = "Contextual + (Semantic + BM25) + Reranker(BAAI)"
context = "\n\n".join(baai_rag)
query = "금융권에서 생성형AI가 활용되는 사례에 대해서 설명해줘. 최대한 상세하게 설명해줘."

prompt = f""" 
Using only the CONTEXT below, provide an accurate answer to the QUESTION in Korean (Hangul).

Only use information provided in the CONTEXT for your answer.
Do not reference or incorporate any external information.
CONTEXT: {context}

QUESTION: {query}

ANSWER:
"""
client = genai.GenerativeModel(
    model_name='gemini-1.5-flash-latest'
)
response = client.generate_content(contents=prompt).text
print("#" * 40)
print(f"{rag}를 통한 RAG 결과")
print("-" * 40)
print(f"답변 : {response}\n")
# Out:
# ########################################
# Contextual + (Semantic + BM25) + Reranker(BAAI)를 통한 RAG 결과
# ----------------------------------------
# 답변 : 금융권에서는 생성형 AI를 활용하여 고객에게 1대1 맞춤형 서비스를 제공하고 있습니다. 특히 마케팅/영업과 고객관리 분야에서 생성형 AI 기술을 활용하여 고객 분석, 상품 추천, 챗봇 등을 통해 고객 만족도를 높이고 있습니다.
#
# 예를 들어, 생성형 AI는 고객의 투자 성향, 리스크 수준, 기대 수익률 등을 분석하여 개인 맞춤형 자산 관리 및 상품 추천 서비스를 제공하는 로보어드바이저(Robo-advisor)에 활용될 수 있습니다. 또한, 고객 문의에 신속하게 응답하는 챗봇/상담봇으로 활용되어 고객 만족도를 높일 수 있습니다.
#
# 뿐만 아니라, 생성형 AI는 금융 문서 분석, 위험 관리, 사기 방지 등 다양한 분야에서 활용되어 업무 효율성을 높이고 있습니다.

# %%
rerank_context = "\n\n".join(rerank_rag)
baai_context = "\n\n".join(baai_rag)

prompt = f"""
너는 최고의 논리전문가이자 작문가야. 
아래 2개의 문맥(A Context, B Context)이 있는데, 
2개의 문맥 중 질문(query)에 대한 답변을 하기에 참고하기 더 적절한 문맥이 무엇인지 
선택해줘 답변은 A Context와 B Context 둘 중에서 하나를 고르고,
해당 문맥을 선택한 이유를 설명해주면돼(선택되지 않은 문맥보다 더 적합한 이유를 설명해줘)

A Context : {rerank_context}

B Context : {baai_context}

Question : {query}
"""

client = genai.GenerativeModel(
    model_name='gemini-1.5-flash-latest'
)
response = client.generate_content(
    contents=prompt,
    generation_config = genai.GenerationConfig(
        temperature = 0
    )).text

# %%
Markdown(response)
# Out:
# 답변: **A Context**가 질문에 대한 답변을 하기에 더 적절합니다.
#
# **이유:**
#
# * **A Context**는 금융 산업에서 생성형 AI가 활용되는 구체적인 사례와 함께, 밸류체인별 적용 예시를 제시하고 있습니다. 특히, 마케팅/영업, 고객관리, 자산관리 등 다양한 분야에서 생성형 AI가 어떻게 활용될 수 있는지 상세하게 설명하고 있습니다.
# * **B Context**는 생성형 AI 도입 초기 단계임을 언급하며, 금융 산업에서의 활용 사례를 구체적으로 다루기보다는, 생성형 AI가 금융 산업에 미칠 수 있는 잠재적 영향과 데이터 활용의 중요성을 강조하고 있습니다.
#
# 따라서 질문에서 요구하는 "금융권에서 생성형 AI가 활용되는 사례"에 대한 상세한 설명은 **A Context**에서 더 잘 제공됩니다. **A Context**는 챗봇/상담봇, 로보어드바이저, RPA 등 구체적인 생성형 AI 활용 사례와 함께, 각 사례가 어떤 방식으로 금융 서비스를 개선하는지 설명하고 있습니다.
